# %% [markdown]
# # Wetlands Insight Tool -DEWLP- 11/09/2019

# %% [markdown]
# ### import modules

# %%
import datacube
import datetime
import fiona
import geopandas as gpd
import numpy as np
import pandas as pd
import rasterio.mask
import rasterio.features
from shapely import geometry
import seaborn as sns
import sys
import xarray as xr

from datetime import datetime, timedelta
import matplotlib.dates as mdates
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from textwrap import wrap

from datacube.storage import masking
from datacube.utils import geometry
from digitalearthau.utils import wofs_fuser

sys.path.append('/g/data/r78/rjd547/jupyter_notebooks/dea-notebooks/10_Scripts')
import DEADataHandling, DEAPlotting, TasseledCapTools

dc = datacube.Datacube(app='wetlands insight tool')

global Output_dir
Output_dir = '/g/data/r78/rjd547/DEWLP-Vic_Project/WIT/WITv3/'

# %% [markdown]
# ### Set up polygon

# %% [markdown]
# ### change the path here if you want a different polygon

# %%
poly_path = '/g/data/r78/rjd547/DEWLP-Vic_Project/WetMAP_newest/WetMAP_polygons_18Jul19.shp'

# %%
gpd.read_file(poly_path)
# Out:
#     WETLAND_NO                                 NAME_MAIN  \
# 0        45267            Reedy Lagoon (Gunbower Forest)
# 1        46014                 Richardsons Lagoon part B
# 2        43187                       Little Lake Meering
# 3        12765                        Litle Heywood Lake
# 4            0                         Carapugna Wetland
# 5        19294                                Crow Swamp
# 6            0                  Neds Corner East Wetland
# 7            0               Neds Corner Central Wetland
# 8            0              Neds Corner Woolshed Wetland
# 9        12765                              Heywood Lake
# 10           0                           Nyah Floodplain
# 11       11360                           Kings Billabong
# 12       10620                Wallpolla-Horseshoe Lagoon
# 13       11439                         Cowanna Billabong
# 14       11207                           Margooya Lagoon
# 15           0                                  Vinifera
# 16       11443  Catish Lagoon (Horseshoe Bend Billabong)
# 17       11371                          Ducksfoot Lagoon
# 18       45260             Black Swamp (Gunbower Forest)
# 19       45357          Camerons Creek (Gunbower Forest)
# 20       45231                                Hird Swamp
# 21       45222                             Johnson Swamp
# 22       43224                 Wirra Lo Duck Creek North
# 23       43214               Wirra Lo Lignum Swamp North
# 24       46013                        Richardsons lagoon
# 25       43205                       Lake Murphy (North)
# 26       45216                           Mcdonalds Swamp
# 27       43161                              Cullens Lake
# 28           0                  Gannawarra Red Gum Swamp
# 29       42643                                Lake Yando
# 30       43190                            Lake Elizabeth
# 31       44745                           Tang Tang Swamp
# 32       63203                               Black Swamp
# 33       67053                              Moodie Swamp
# 34       63119                                Loch Garry
# 35           0                          Kanyapella Basin
# 36       41400                              Lake Lalbert
# 37       42638                            Woolshed Swamp
# 38       60101                            One Tree Swamp
# 39       62010                             Doctors Swamp
# 40       63206                         Kinnairds Wetland
# 41       63173              Reedy Swamp Wildlife Reserve
# 42       67401                             Sharps Lagoon
# 43       60714                  Hut Lake (Barmah Forest)
# 44       54577                                Reedy Lake
# 45       75207                    RRX (Ovens Floodplain)
# 46           0              Tarma Lagoon (Barmah Forest)
# 47           0              Bunyip Swamp (Barmah Forest)
# 48           0            Cucumber Gully (Barmah Forest)
# 49           0                   RR11 (Ovens Floodplain)
# 50           0              Peechalba (Ovens Floodplain)
# 51           0              Punt Paddock (Barmah Forest)
# 52           0                              Gaynor Swamp
# 53       43205                       Lake Murphy (South)
# 54           0               Wirra Lo Lignum Swamp South
#
#                                   WETLAND_TY  \
# 0   Temporary freshwater marshes and meadows
# 1                 Permanent freshwater lakes
# 2                                    Unknown
# 3                Temporary freshwater swamps
# 4                                       None
# 5                                    Unknown
# 6                                       None
# 7                                       None
# 8                                       None
# 9                Temporary freshwater swamps
# 10                                      None
# 11  Permanent freshwater marshes and meadows
# 12  Temporary freshwater marshes and meadows
# 13                Permanent freshwater lakes
# 14  Permanent freshwater marshes and meadows
# 15                                      None
# 16                                   Unknown
# 17                Permanent freshwater lakes
# 18                                   Unknown
# 19  Temporary freshwater marshes and meadows
# 20  Temporary freshwater marshes and meadows
# 21                                   Unknown
# 22               Temporary freshwater swamps
# 23               Temporary freshwater swamps
# 24                                   Unknown
# 25                                   Unknown
# 26                                   Unknown
# 27                    Temporary saline lakes
# 28                                      None
# 29                                   Unknown
# 30                    Permanent saline lakes
# 31               Temporary freshwater swamps
# 32               Temporary freshwater swamps
# 33  Temporary freshwater marshes and meadows
# 34               Temporary freshwater swamps
# 35                                      None
# 36               Temporary freshwater swamps
# 37                   Temporary saline swamps
# 38                                   Unknown
# 39  Temporary freshwater marshes and meadows
# 40               Temporary freshwater swamps
# 41               Temporary freshwater swamps
# 42                                   Unknown
# 43               Temporary freshwater swamps
# 44                                   Unknown
# 45                                   Unknown
# 46                                      None
# 47                                      None
# 48                                      None
# 49                                      None
# 50                                      None
# 51                                      None
# 52                                      None
# 53                                   Unknown
# 54                                      None
#
#                                           AQ_SYS AQ_SYS_CON  SAL_REGIME  \
# 0                                     Palustrine   Moderate       Fresh
# 1                                     Lacustrine   Moderate       Fresh
# 2   Palustrine or Lacustrine (unknown specifics)        n/a       Fresh
# 3                                     Palustrine   Moderate       Fresh
# 4                                           None       None        None
# 5                                     Palustrine   Moderate       Fresh
# 6                                           None       None        None
# 7                                           None       None        None
# 8                                           None       None        None
# 9                                     Palustrine   Moderate       Fresh
# 10                                          None       None        None
# 11                                    Palustrine   Moderate       Fresh
# 12                                    Palustrine   Moderate       Fresh
# 13                                    Lacustrine        Low       Fresh
# 14                                    Palustrine        Low       Fresh
# 15                                          None       None        None
# 16  Palustrine or Lacustrine (unknown specifics)        n/a       Fresh
# 17                                    Lacustrine       High       Fresh
# 18                                    Palustrine   Moderate       Fresh
# 19                                    Palustrine   Moderate       Fresh
# 20                                    Palustrine       High       Fresh
# 21                                    Palustrine   Moderate       Fresh
# 22                                    Palustrine   Moderate       Fresh
# 23                                    Palustrine   Moderate       Fresh
# 24  Palustrine or Lacustrine (unknown specifics)        n/a       Fresh
# 25                                    Palustrine   Moderate       Fresh
# 26                                    Palustrine   Moderate       Fresh
# 27                                    Lacustrine       High      Saline
# 28                                          None       None        None
# 29                                    Palustrine   Moderate       Fresh
# 30                                    Lacustrine       High  Mesosaline
# 31                                    Palustrine       High       Fresh
# 32                                    Palustrine   Moderate       Fresh
# 33                                    Palustrine   Moderate       Fresh
# 34                                    Palustrine   Moderate       Fresh
# 35                                          None       None        None
# 36                                    Palustrine       High       Fresh
# 37                                    Palustrine       High  Hyposaline
# 38                                    Palustrine   Moderate       Fresh
# 39                                    Palustrine       High       Fresh
# 40                                    Palustrine       High       Fresh
# 41                                    Palustrine       High       Fresh
# 42  Palustrine or Lacustrine (unknown specifics)        n/a       Fresh
# 43                                    Palustrine   Moderate       Fresh
# 44                                    Palustrine   Moderate  Hyposaline
# 45  Palustrine or Lacustrine (unknown specifics)        n/a       Fresh
# 46                                          None       None        None
# 47                                          None       None        None
# 48                                          None       None        None
# 49                                          None       None        None
# 50                                          None       None        None
# 51                                          None       None        None
# 52                                          None       None        None
# 53                                    Palustrine   Moderate       Fresh
# 54                                          None       None        None
#
#    SAL_REG_CO                                             WTRREG WTRREG_CON  \
# 0    Moderate  Periodically Inundated - Seasonal Or Intermittent   Moderate
# 1    Moderate                                          Permanent   Moderate
# 2    Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 3    Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 4        None                                               None       None
# 5    Moderate                  Periodically Inundated - Episodic   Moderate
# 6        None                                               None       None
# 7        None                                               None       None
# 8        None                                               None       None
# 9    Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 10       None                                               None       None
# 11   Moderate                                          Permanent   Moderate
# 12   Moderate              Periodically Inundated - Intermittent   Moderate
# 13   Moderate                                          Permanent   Moderate
# 14   Moderate                                          Permanent   Moderate
# 15       None                                               None       None
# 16   Moderate  Periodically Inundated - Seasonal Or Intermittent   Moderate
# 17   Moderate                                          Permanent   Moderate
# 18   Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 19   Moderate              Periodically Inundated - Intermittent   Moderate
# 20   Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 21   Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 22   Moderate                  Periodically Inundated - Episodic   Moderate
# 23   Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 24   Moderate                                          Permanent   Moderate
# 25   Moderate  Periodically Inundated - Seasonal Or Intermittent   Moderate
# 26   Moderate  Periodically Inundated - Seasonal Or Intermittent   Moderate
# 27   Moderate              Periodically Inundated - Intermittent   Moderate
# 28       None                                               None       None
# 29   Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 30   Moderate                                          Permanent       High
# 31   Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 32   Moderate  Periodically Inundated - Seasonal Or Intermittent   Moderate
# 33   Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 34   Moderate  Periodically Inundated - Seasonal Or Intermittent   Moderate
# 35       None                                               None       None
# 36   Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 37        Low      Periodically Inundated - Seasonal Or Episodic   Moderate
# 38   Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 39   Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 40   Moderate      Periodically Inundated - Seasonal Or Episodic   Moderate
# 41   Moderate              Periodically Inundated - Intermittent   Moderate
# 42   Moderate                                          Permanent   Moderate
# 43   Moderate  Periodically Inundated - Seasonal Or Intermittent   Moderate
# 44       High              Periodically Inundated - Intermittent   Moderate
# 45   Moderate  Periodically Inundated - Seasonal Or Intermittent   Moderate
# 46       None                                               None       None
# 47       None                                               None       None
# 48       None                                               None       None
# 49       None                                               None       None
# 50       None                                               None       None
# 51       None                                               None       None
# 52       None                                               None       None
# 53   Moderate  Periodically Inundated - Seasonal Or Intermittent   Moderate
# 54       None                                               None       None
#
#      SRC_TIDE  ...         SRC_ART SRC_ART_CO                 DOM_VEG  \
# 0   Non-tidal  ...      Artificial       High        Sedge/grass/forb
# 1   Non-tidal  ...      Artificial       High  No emergent vegetation
# 2   Non-tidal  ...      Artificial       High                 Unknown
# 3   Non-tidal  ...      Artificial       High         Forest/woodland
# 4        None  ...            None       None                    None
# 5   Non-tidal  ...  Not artificial   Moderate                 Unknown
# 6        None  ...            None       None                    None
# 7        None  ...            None       None                    None
# 8        None  ...            None       None                    None
# 9   Non-tidal  ...      Artificial       High         Forest/woodland
# 10       None  ...            None       None                    None
# 11  Non-tidal  ...      Artificial       High        Sedge/grass/forb
# 12  Non-tidal  ...  Not artificial   Moderate        Sedge/grass/forb
# 13  Non-tidal  ...      Artificial       High  No emergent vegetation
# 14  Non-tidal  ...      Artificial       High        Sedge/grass/forb
# 15       None  ...            None       None                    None
# 16  Non-tidal  ...      Artificial       High  No emergent vegetation
# 17  Non-tidal  ...  Not artificial   Moderate  No emergent vegetation
# 18  Non-tidal  ...      Artificial       High                 Unknown
# 19  Non-tidal  ...      Artificial       High        Sedge/grass/forb
# 20  Non-tidal  ...      Artificial       High        Sedge/grass/forb
# 21  Non-tidal  ...      Artificial       High                 Unknown
# 22  Non-tidal  ...  Not artificial   Moderate         Forest/woodland
# 23  Non-tidal  ...  Not artificial   Moderate         Forest/woodland
# 24  Non-tidal  ...      Artificial       High                 Unknown
# 25  Non-tidal  ...      Artificial       High                 Unknown
# 26  Non-tidal  ...      Artificial       High                 Unknown
# 27  Non-tidal  ...      Artificial       High  No emergent vegetation
# 28       None  ...            None       None                    None
# 29  Non-tidal  ...      Artificial       High                 Unknown
# 30  Non-tidal  ...      Artificial       High  No emergent vegetation
# 31  Non-tidal  ...  Not artificial   Moderate                   Shrub
# 32  Non-tidal  ...      Artificial       High         Forest/woodland
# 33  Non-tidal  ...  Not artificial   Moderate        Sedge/grass/forb
# 34  Non-tidal  ...  Not artificial   Moderate         Forest/woodland
# 35       None  ...            None       None                    None
# 36  Non-tidal  ...  Not artificial   Moderate                   Shrub
# 37  Non-tidal  ...  Not artificial   Moderate         Forest/woodland
# 38  Non-tidal  ...  Not artificial   Moderate                 Unknown
# 39  Non-tidal  ...      Artificial       High        Sedge/grass/forb
# 40  Non-tidal  ...      Artificial       High         Forest/woodland
# 41  Non-tidal  ...      Artificial       High         Forest/woodland
# 42  Non-tidal  ...  Not artificial   Moderate                 Unknown
# 43  Non-tidal  ...      Artificial       High         Forest/woodland
# 44  Non-tidal  ...      Artificial       High       Coastal saltmarsh
# 45  Non-tidal  ...  Not artificial   Moderate                 Unknown
# 46       None  ...            None       None                    None
# 47       None  ...            None       None                    None
# 48       None  ...            None       None                    None
# 49       None  ...            None       None                    None
# 50       None  ...            None       None                    None
# 51       None  ...            None       None                    None
# 52       None  ...            None       None                    None
# 53  Non-tidal  ...      Artificial       High                 Unknown
# 54       None  ...            None       None                    None
#
#    DOM_VEG_CO  HECTARES Wetland_Co  CMA_1   Latitude   Longitude  \
# 0        High   41.0700       RELG  NCCMA -35.726506  144.207380
# 1        High   12.2500     RILA_B  NCCMA -36.035788  144.570589
# 2         n/a   27.2400       LLME  NCCMA -35.854040  143.815220
# 3        High  201.5200       LLHE   MCMA -34.794880  143.205330
# 4        None   43.8328       CARA   WCMA -36.106700  142.738200
# 5         n/a    5.8200       CRSW   WCMA -36.187920  142.107660
# 6        None    0.0000       NECE   MCMA -34.181100  141.506800
# 7        None    0.0000       NECC   MCMA -34.169705  141.484935
# 8        None    0.0000       NEWS   MCMA -34.169705  141.315370
# 9        High  201.5200       LAHE   MCMA -34.794880  143.205330
# 10       None  725.5210       NYFL   MCMA -35.137720  143.369360
# 11       High  171.5200       KIBI   MCMA -34.237440  142.225190
# 12       High   34.6700       WAHO   MCMA -34.141100  141.840530
# 13       High   12.5400       COBI   MCMA -34.132430  142.032590
# 14   Moderate   34.0000       MARG   MCMA -34.631220  142.850360
# 15       None  402.1250       VINI   MCMA -35.204080  143.406860
# 16   Moderate   27.4100       CATF   MCMA -34.140430  142.063450
# 17       High   16.4300       DULA   MCMA -34.227100  142.237210
# 18        n/a   37.1800       BLS2  NCCMA -35.716420  144.181170
# 19       High    1.9500       CAMC  NCCMA -35.959210  144.466950
# 20       High  345.2600       HISW  NCCMA -35.859080  144.094700
# 21        n/a  411.0700       JOSW  NCCMA -35.814020  144.073410
# 22       High   37.5300    WILO_DC  NCCMA -35.503360  143.872700
# 23       High   10.3500   WILO_LSN  NCCMA -35.508800  143.870400
# 24        n/a   24.8700       RILA  NCCMA -36.032650  144.558830
# 25        n/a  167.8600       LAMU  NCCMA -35.806840  143.865060
# 26        n/a  141.8000       McSW  NCCMA -35.700710  144.065730
# 27       High  629.0000       LACU  NCCMA -35.640180  143.772920
# 28       None  147.7000       GRGS  NCCMA -35.689240  144.072920
# 29        n/a   82.9500       LAYA  NCCMA -36.041550  143.784380
# 30       High   93.6700       LAEL  NCCMA -35.696980  143.820640
# 31       High  102.6500       TATA  NCCMA -36.364200  144.296480
# 32       High   27.5100       BLSW  GBCMA -36.140880  145.454020
# 33       High  181.4100       MOSW  GBCMA -36.227800  145.791560
# 34       High  327.9200       LOGA  GBCMA -36.219860  145.314670
# 35       None   57.9356       KABA  GBCMA -36.143680  144.917040
# 36       High  686.5200       LALA  NCCMA -35.667610  143.338600
# 37       High  351.6100       WOSW  NCCMA -36.171940  143.723730
# 38        n/a  631.3000       ONTS  GBCMA -36.526230  144.895140
# 39       High  224.5800       DOSW  GBCMA -36.616990  145.180760
# 40       High  100.3000       KIWE  GBCMA -36.081540  145.468380
# 41       High  130.5200       RESW  GBCMA -36.341200  145.364600
# 42        n/a    9.3700       SHAR  GBCMA -35.969330  145.907540
# 43       High   37.7700       HULA  GBCMA -35.912750  144.994570
# 44       High  847.6600       RELA   CCMA -38.206120  144.421760
# 45        n/a    2.9500        RRX  NECMA -36.215150  146.256260
# 46       None    0.0000       TALA  GBCMA -35.906800  145.041900
# 47       None    0.0000       BUSW  GBCMA -35.932090  145.038590
# 48       None    0.0000       CUGU  GBCMA -35.933060  144.999260
# 49       None    0.0000       RR11  NECMA -36.204148  146.257576
# 50       None    0.0000       PEEC  NECMA -36.133123  146.215904
# 51       None    0.0000       PUNT  GBCMA -35.829645  145.085740
# 52       None    0.0000       GASW  GBCMA -36.515980  144.826380
# 53        n/a  167.8600       LAMU  NCCMA -35.806840  143.865060
# 54       None    0.0000   WILO_LSS  NCCMA -35.513013  143.872643
#
#                                              geometry
# 0   POLYGON ((144.2028312250001 -35.72175684199999...
# 1   POLYGON ((144.571166208 -36.032063833, 144.571...
# 2   POLYGON ((143.811780491 -35.85603984099998, 14...
# 3   POLYGON ((143.2136285930001 -34.792458125, 143...
# 4   POLYGON ((142.7341568858985 -36.10537389657287...
# 5   POLYGON ((142.107360468 -36.18711435799997, 14...
# 6   POLYGON ((141.5071632366709 -34.18425026989376...
# 7   POLYGON ((141.485216282167 -34.16639180212071,...
# 8   (POLYGON ((141.3192499903608 -34.1403344036283...
# 9   POLYGON ((143.2149189330001 -34.79379433299999...
# 10  POLYGON ((143.3507009250001 -35.11449649099995...
# 11  POLYGON ((142.229318475 -34.216594767, 142.229...
# 12  POLYGON ((141.852528325 -34.13963480799998, 14...
# 13  POLYGON ((142.029755617 -34.12673211699996, 14...
# 14  POLYGON ((142.8487192580001 -34.62618157499998...
# 15  POLYGON ((143.3866610920001 -35.18225733299994...
# 16  POLYGON ((142.055608292 -34.14223743399998, 14...
# 17  POLYGON ((142.236540474 -34.22640941699996, 14...
# 18  POLYGON ((144.1860404250001 -35.71220241599997...
# 19  POLYGON ((144.4708630344543 -35.96058132806473...
# 20  POLYGON ((144.1025905080002 -35.85556319999989...
# 21  POLYGON ((144.0783824490095 -35.81071919990916...
# 22  POLYGON ((143.871027601 -35.50135440799994, 14...
# 23  POLYGON ((143.8700075320002 -35.50661828299991...
# 24  POLYGON ((144.563813908 -36.02796261699996, 14...
# 25  (POLYGON ((143.8745390765026 -35.8052808517192...
# 26  POLYGON ((144.0644628580001 -35.71260017499992...
# 27  POLYGON ((143.7660455215084 -35.62480454295473...
# 28  POLYGON ((144.080415 -35.69544199999996, 144.0...
# 29  POLYGON ((143.7832165250001 -36.03605838299995...
# 30  POLYGON ((143.822238167 -35.70419909099996, 14...
# 31  POLYGON ((144.291594175 -36.36558612499999, 14...
# 32  POLYGON ((145.4528830550922 -36.13924384905812...
# 33  POLYGON ((145.7987134670001 -36.22862484999996...
# 34  POLYGON ((145.314716892 -36.215169291, 145.315...
# 35  POLYGON ((144.9226512127245 -36.14890788455119...
# 36  POLYGON ((143.338324551 -35.65541390099997, 14...
# 37  POLYGON ((143.7226735830001 -36.15957188299996...
# 38  POLYGON ((144.9015678750001 -36.51290847599995...
# 39  POLYGON ((145.1901867830001 -36.61916438399999...
# 40  POLYGON ((145.467010083 -36.069800708, 145.467...
# 41  POLYGON ((145.3621420318948 -36.33319203440948...
# 42  POLYGON ((145.91052485 -35.97213886699996, 145...
# 43  POLYGON ((144.9967639300567 -35.91738621766797...
# 44  POLYGON ((144.4367544090321 -38.21087379114169...
# 45  POLYGON ((146.253039357 -36.21552270799998, 14...
# 46  POLYGON ((145.0454634370058 -35.90708897659567...
# 47  POLYGON ((145.0384578967297 -35.93180178559516...
# 48  POLYGON ((145.0015107168175 -35.93402697821267...
# 49  POLYGON ((146.2571158473224 -36.20541010120377...
# 50  POLYGON ((146.2137330859612 -36.12884480433155...
# 51  POLYGON ((145.088248918654 -35.82793921512712,...
# 52  POLYGON ((144.8246122713527 -36.50702977220783...
# 53  POLYGON ((143.8711291443317 -35.80257288656998...
# 54  (POLYGON ((143.8700272183988 -35.5102269284429...
#
# [55 rows x 25 columns]

# %%
def get_WetMAP_polyName(feature):
    'function just for the WetMAP polygons'
    ID = feature['properties']['FID_1']
    if feature['properties']['LU_NAME']is not None:
        NAME = '_'.join(feature['properties']['LU_NAME'].split(' ')).replace("'","_").replace("/","_") 
        print(NAME)
    elif feature['properties']['NAME_MAIN'] is not None:
        NAME = f'_'.join(feature['properties']['NAME_MAIN'].split(' ')).replace("'","_").replace("/","_") 
    else:     
        NAME = 'WetMAP_polygon'  
    polyName = f'{ID}_{NAME}'
    print(f'processing polygon {polyName}')
    return(polyName)

# %%
#open the polygon and manually select your favourite polygon the lazy way
with fiona.open(poly_path) as shapes:
        crs = geometry.CRS(shapes.crs_wkt)
        for feature in shapes:
            #if feature['properties']['NAME_MAIN']=='Reedy_Lake':
            polyName = "Reedy_Lake"
            feature_of_interest = feature
            feature_of_interest_geometry = feature_of_interest['geometry']
            geom = geometry.Geometry(feature_of_interest_geometry, crs=crs)

# %%
def get_masked_ls578_data(query, geom):
    '''create a function that takes in the masked proportion, query and geometry and returns the fully masked surface reflectance data'''
    ## Set up datasets
    #set cloudmasking threshold and load landsat nbart data
    landsat_masked_prop = 0.90
    ls578_ds = DEADataHandling.load_clearlandsat(dc=dc, query=query, product='nbart',
            masked_prop=landsat_masked_prop)

    ### mask the data with our original polygon to remove extra data 

    data = ls578_ds
    mask = rasterio.features.geometry_mask([geom.to_crs(data.geobox.crs)for geoms in [geom]],
                                               out_shape=data.geobox.shape,
                                               transform=data.geobox.affine,
                                               all_touched=False,
                                               invert=False)

    #for some reason xarray is not playing nicely with our old masking function
    mask_xr = xr.DataArray(mask, dims = ('y','x'))
    ls578_ds = data.where(mask_xr==False)
    return ls578_ds, mask_xr

# %%
def get_masked_tcw(sr_data, mask, threshold=-350):
    '''uses TasseledCapTools and an input threshold (defaults to -350) to create masked over-threshold tasseled cap '''

    #transform the nbart into tci
    tci = TasseledCapTools.thresholded_tasseled_cap(ls578_ds,wetness_threshold=-350, drop=True , drop_tc_bands=True)

    #select only finite values (over threshold values)
    tcw = xr.ufuncs.isfinite(tci.wetness_thresholded)

    # #reapply the polygon mask
    tcw = tcw.where(mask_xr==False)

    return tcw

# %% [markdown]
# ### Set up query

# %%
query = {'geopolygon': geom,
         #'time': ('1991-01-01', '1994-01-01')
         }

# %% [markdown]
# ### Load data sets, where 90% of data is unmasked

# %% [markdown]
# #### Landsat data

# %%
#load and mask data. selecting data with more than 90% clear for the geobox around the polygon... #FIXME
ls578_ds, mask_xr= get_masked_ls578_data(query,geom)
# Out:
# Loading ls5
#     Loading 336 filtered ls5 timesteps
# Loading ls7
#     Ignoring SLC-off observations for ls7
#     Loading 83 filtered ls7 timesteps
# Loading ls8
#     Loading 128 filtered ls8 timesteps
# Combining and sorting ls5, ls7, ls8 data
#     Replacing invalid -999 values with NaN (data will be coerced to float64)

# %%
#calculate tasselled cap wetness within masked AOI
tcw = get_masked_tcw(ls578_ds, mask_xr, threshold=-350)

# %%
#wofls = dc.load(product = 'wofs_albers', like=ls578_ds, fuse_func=wofs_fuser)
wofls = dc.load(product = 'wofs_albers',fuse_func=wofs_fuser, **query)

# %% [markdown]
# #first, match tcw and wofs

# %%
wofls = wofls.where(wofls.time==tcw.time)

# %%
# #reapply the polygon mask
wofls = wofls.where(mask_xr==False)

# %%
wet_wofs = wofls.where(wofls.water==128)

# %%
shadow_wofs = wofls.where(wofls.water== 136) #use bit values for wet (128) and terrain/low-angle (8)

# %%
sea_wofs = wofls.where(wofls.water==132) #bit values for wet (128) and sea (4)
sea_shadow_wofs = wofls.where(wofls.water==140)# bit values for wet (128) and sea (4) and terrain/low-angle (8)

# %% [markdown]
# ## load in fractional cover data

# %%
#load the data according to our query
#choose a mask proportion to look for a clear timestep
fc_ds = DEADataHandling.load_clearlandsat(dc, query,product='fc',masked_prop=0.90)
# Out:
# Loading ls5
#     Loading 336 filtered ls5 timesteps
# Loading ls7
#     Ignoring SLC-off observations for ls7
#     Loading 83 filtered ls7 timesteps
# Loading ls8
#     Loading 128 filtered ls8 timesteps
# Combining and sorting ls5, ls7, ls8 data
#     Replacing invalid -999 values with NaN (data will be coerced to float64)

# %% [markdown]
# ### mask FC with polygon

# %%
fc_ds = fc_ds.where(mask_xr==False)

# %% [markdown]
# ### mask FC with wetness

# %%
fc_ds_noTCW=fc_ds.where(tcw==False)
#match timesteps
fc_ds_noTCW= fc_ds_noTCW.where(fc_ds_noTCW.time==tcw.time)

# %% [markdown]
# ### Calculate the dominant fraction for each pixel in Fractional Cover

# %%
#drop data percentage and Unmixing Error
fc_tester = fc_ds_noTCW.drop(['data_perc','UE'])

#following robbi's advice, cast the dataset to a dataarray
maxFC = fc_tester.to_array(dim='variable', name='maxFC')

#turn FC array into integer only as nanargmax doesn't seem to handle floats the way we want it to
FC_int = maxFC.astype('int8')

#use numpy.nanargmax to get the index of the maximum value along the variable dimension
#BSPVNPV=np.nanargmax(FC_int, axis=0)
BSPVNPV=FC_int.argmax(dim='variable')

FC_mask=xr.ufuncs.isfinite(maxFC).all(dim='variable')

# #re-mask with nans to remove no-data
BSPVNPV=BSPVNPV.where(FC_mask)

# %% [markdown]
# ### Calculate number of pixels in area of interest

# %%
#number of pixels in area of interest
pixels = (mask_xr==0).sum(dim=['x','y'])

# %%
#count number of tcw pixels
tcw_pixel_count = tcw.sum(dim=['x','y'])

# %%
FC_dominant = xr.Dataset({
    'BS': (BSPVNPV==0).where(FC_mask),
    'PV': (BSPVNPV==1).where(FC_mask),
    'NPV': (BSPVNPV==2).where(FC_mask),
})

# %%
#number of pixels in area of interest
pixels = (mask_xr==0).sum(dim=['x','y'])

# %%
#count number of wofs pixels
wofs_pixels = (wet_wofs.water.count(dim=['x','y'])+shadow_wofs.water.count(dim=['x','y']) +
sea_wofs.water.count(dim=['x','y'])+sea_shadow_wofs.water.count(dim=['x','y']))
# Out:
# <xarray.DataArray 'water' (time: 545)>
# array([6795, 6478, 6750, ...,    0,    0, 1340])
# Coordinates:
#   * time     (time) datetime64[ns] 1986-08-19T23:30:42.500000 ... 2019-08-15T00:09:22

# %%
#count percentage of area of wofs
wofs_area_percent = (wofs_pixels/pixels)*100
#wofs_area_percent

# %%
#count number of tcw pixels
tcw_pixel_count = tcw.sum(dim=['x','y'])

# %%
#calculate percentage area wet
tcw_area_percent = (tcw_pixel_count/pixels)*100

# %%
#calculate wet not wofs
tcw_less_wofs = tcw_area_percent-wofs_area_percent

# %%
#drop data percentage and Unmixing Error
fc_tester = fc_ds_noTCW.drop(['data_perc','UE'])

# %%
#following robbi's advice, cast the dataset to a dataarray
maxFC = fc_tester.to_array(dim='variable', name='maxFC')

# %%
#turn FC array into integer only as nanargmax doesn't seem to handle floats the way we want it to
FC_int = maxFC.astype('int8')

# %%
#use numpy.nanargmax to get the index of the maximum value along the variable dimension
#BSPVNPV=np.nanargmax(FC_int, axis=0)
BSPVNPV=FC_int.argmax(dim='variable')

# %%
#work out where we have actual values!
FC_mask=xr.ufuncs.isfinite(maxFC).all(dim='variable')

# #re-mask with nans to remove no-data
BSPVNPV=BSPVNPV.where(FC_mask)

# %%
#restack the Fractional cover dataset all together
FC_dominant = xr.Dataset({
    'BS': (BSPVNPV==0).where(FC_mask),
    'PV': (BSPVNPV==1).where(FC_mask),
    'NPV': (BSPVNPV==2).where(FC_mask),
})

# %%
FC_count = FC_dominant.sum(dim=['x','y'])

# %%
#Fractional cover pixel count method
#Get number of FC pixels, divide by total number of pixels per polygon
#Work out the number of nodata pixels in the data, so that we can graph the variables by number of observed pixels.

Bare_soil_percent=(FC_count.BS/pixels)*100

Photosynthetic_veg_percent=(FC_count.PV/pixels)*100

NonPhotosynthetic_veg_percent=(FC_count.NPV/pixels)*100

NoData = 100 - wofs_area_percent- tcw_less_wofs - Photosynthetic_veg_percent - NonPhotosynthetic_veg_percent - Bare_soil_percent

# %%
NoDataPixels = (NoData/100) * pixels

# %%
#Fractional cover pixel count method
#Get number of FC pixels, divide by total number of pixels per polygon

Bare_soil_percent2=(FC_count.BS/(pixels - NoDataPixels))*100

Photosynthetic_veg_percent2=(FC_count.PV/(pixels- NoDataPixels))*100

NonPhotosynthetic_veg_percent2=(FC_count.NPV/(pixels- NoDataPixels))*100

# %%
#count percentage of area of wofs
wofs_area_percent2 = (wofs_pixels/(pixels - NoDataPixels))*100
#wofs_area_percent

# %%
#count number of tcw pixels
tcw_pixel_count2 = tcw.sum(dim=['x','y'])

# %%
#calculate percentage area wet
tcw_area_percent2 = (tcw_pixel_count2/(pixels - NoDataPixels))*100

# %%
#calculate wet not wofs
tcw_less_wofs2 = tcw_area_percent2-wofs_area_percent2

# %%
#last check for timestep matching before we plot
wofs_area_percent2=wofs_area_percent2.where(wofs_area_percent2.time==Bare_soil_percent2.time)
Bare_soil_percent2=Bare_soil_percent2.where(Bare_soil_percent2.time==wofs_area_percent2.time)
Photosynthetic_veg_percent2=Photosynthetic_veg_percent2.where(Photosynthetic_veg_percent2.time==wofs_area_percent2.time)
NonPhotosynthetic_veg_percent2=NonPhotosynthetic_veg_percent2.where(NonPhotosynthetic_veg_percent2.time==wofs_area_percent2.time)

# %%
#set up color palette
pal = [sns.xkcd_rgb["cobalt blue"],
       sns.xkcd_rgb["neon blue"],
       sns.xkcd_rgb["grass"],
       sns.xkcd_rgb["beige"],
       sns.xkcd_rgb["brown"]]       

#make a stacked area plot
plt.clf()
fig= plt.figure(figsize = (12,4))
plt.stackplot(wofs_area_percent.time.values, 
              wofs_area_percent2, 
              tcw_less_wofs2, 
              Photosynthetic_veg_percent2, 
              NonPhotosynthetic_veg_percent2,
              Bare_soil_percent2,
              labels=['open water',
                      'wet',
                      'green veg',
                      'dry veg',
                      'bare soil',
                     ], colors=pal, alpha = 0.6)



#set axis limits to the min and max
plt.axis(xmin = wofs_area_percent2.time[0].data, xmax = wofs_area_percent2.time[-1].data, ymin = 0, ymax = 100)

#add a legend and a tight plot box
plt.legend(loc='lower left', framealpha=0.6)
#plt.tight_layout()

#create rectangle borders for no-data times (SLC-off only)
LS5_8_gap_start = datetime(2011,11,1)
LS5_8_gap_end = datetime(2013,4,1)

# convert to matplotlib date representation
gap_start = mdates.date2num(LS5_8_gap_start)
gap_end = mdates.date2num(LS5_8_gap_end)
gap = gap_end - gap_start


#set date ticks every year
years = mdates.YearLocator(2)
yearsFmt = mdates.DateFormatter('%Y')
ax = plt.gca()
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(yearsFmt)
#ax.yaxis.set_ticks(np.arange(0,110,10))
ax.set_xlabel(f'The Fractional Cover algorithm developed by the Joint Remote'
f' Sensing Research Program and \n the Water Observations from Space algorithm '
f'developed by Geoscience Australia are used in the production of this data',style='italic')


#set up rectangle
slc_rectangle= Rectangle((gap_start,0), gap, 100,alpha = 0.5, facecolor=sns.xkcd_rgb['white'],
             edgecolor=sns.xkcd_rgb['white'], hatch="////",linewidth=2)
ax.add_patch(slc_rectangle)
#fig.autofmt_xdate()


#polyName='test a really really really stupidly extremely long name that is far too long and I can\'t even what the blah blah blah blah blah '

polyName=polyName.replace("'","\\'")
title=ax.set_title("\n".join(wrap(f'Percentage of area WOfS, Wetness, Fractional Cover for {polyName}')))
fig.tight_layout()
title.set_y(1.05)

#save the figure
plt.savefig(f'{Output_dir}{polyName}.png')#, transparent=True)
plt.show()
print(f'plot created for {polyName}')
# Out:
# plot created for Reedy_Lake

# %%
#make a new dataframe using the data from the xarray of wofs area for the polygon

### start setup of dataframe by adding only one dataset
WOFS_df = pd.DataFrame(data=wofs_area_percent2.data, index=wofs_area_percent2.time.values,columns=['wofs_area_percent'])

#add data into pandas dataframe for export
WOFS_df['wet_percent']=tcw_less_wofs2.data
WOFS_df['green_veg_percent']=Photosynthetic_veg_percent2.data
WOFS_df['dry_veg_percent']=NonPhotosynthetic_veg_percent2.data
WOFS_df['bare_soil_percent']=Bare_soil_percent2.data

#call the composite dataframe something sensible, like PolyDrill
PolyDrill_df = WOFS_df.round(2)

#save the csv of the output data used to create the stacked plot for the polygon drill
PolyDrill_df.to_csv(f'{Output_dir}{polyName}.csv')
print(f'wrote output data to file {Output_dir}{polyName}.csv')
# Out:
# wrote output data to file /g/data/r78/rjd547/DEWLP-Vic_Project/WIT/Reedy_Lake.csv

# %% [markdown]
# ## test area plot

# %%
import matplotlib as mpl
#set up color palette for just the fractional cover
fc_colors = [sns.xkcd_rgb["brown"], #0
       sns.xkcd_rgb["grass"], #1
       sns.xkcd_rgb["beige"]] #2
fc_norm=mpl.colors.BoundaryNorm([0,1,2,3],3)

# %%
#thresholded TCW is boolean type, so need a two-step color map with transparent and a color
tcw_colors = ('#00000000',sns.xkcd_rgb["neon blue"]) #neon blue to transparent
#we use "NoNorm" because our data should only come in 0 and 1s
tcw_norm = mpl.colors.NoNorm(0,1)

# %%
#thresholded wofs is boolean type, so need a two-step color map with transparent and a color
wofs_colors = ('#00000000',sns.xkcd_rgb["cobalt blue"]) #cobalt blue to transparent
#use the same Norm as tcw
wofs_norm = tcw_norm

# %%
import datetime
scene=-10
scene_day= np.datetime_as_string(tcw.isel(time=scene).time.values, unit='D')

# %%
### plot the results to check they look roughly like what we are expecting
plt.clf()
plt.imshow(BSPVNPV[scene],cmap=mpl.colors.ListedColormap(colors=fc_colors), norm=fc_norm, alpha =0.7)

###us numpy to turn data into a float so the colormap doesn't break
plt.imshow(tcw.isel(time=scene).astype(np.float32), cmap=mpl.colors.ListedColormap(colors=tcw_colors), norm=tcw_norm, alpha =0.6)
plt.imshow(wet_wofs.water.isel(time=scene),cmap=mpl.colors.ListedColormap(colors =wofs_colors), norm = wofs_norm, alpha =0.5 )
#note shadow wofs not plotted here!!!!!!! #FIXME
plt.tick_params(
    axis= 'both', #both x and y
    which = 'both', # both major and minor ticks
    bottom = False, #turn off ticks on bottom
    left = False, # turn off ticks on left
    labelbottom = False, #turn off ticklabels on the bottom
    labelleft = False        #turn of ticklabels on the left
    )
plt.title(f'WOfS, Wetness, Fractional Cover for {scene_day}')
plt.tight_layout()
plt.savefig(f'/{Output_dir}{polyName}{scene_day}.png')
