# %% [markdown]
# # Introduction to products

# %% [markdown]
# **Notebook currently compatible with the `NCI`|`DEA Sandbox` environment only**

# %% [markdown]
# ### General advice (delete this cell before submitting for review)
#
# - When choosing a location for your analysis, **select an area that has data on both the `NCI` and `DEA Sandbox`** to allow your code to be run on both environments.
# For example, you can check this for Landsat using the [DEA Explorer](https://explorer.sandbox.dea.ga.gov.au/ga_ls5t_ard_3/1990) (use the drop-down menu to view all products).
# As of September 2019, the `DEA Sandbox` has a single year of continental Landsat data for 2015-16, and the full 1987-onward time-series for three locations (Perth WA, Brisbane QLD, and western NSW).
# - When writing in Markdown cells, start each sentence is on a **new line**.
# This makes it easy to see changes through git commits.
# - Use Australian English in markdown cells and code comments.
# - Use the [PEP8 standard](https://www.python.org/dev/peps/pep-0008/) for code. To make sure all code in the notebook is consistent, you can use the `jupyterlab_code_formatter` tool: select each code cell, then click `Edit` and then one of the `Apply X Formatter` options (`YAPF` or `Black` are recommended). This will reformat the code in the cell to a consistent style.
# - In the final notebook cell, include a set of relevant tags which are used to build the DEA User Guide's [Tag Index](https://docs.dea.ga.gov.au/genindex.html).
# Use all lower-case, seperate words with spaces, and where possible re-use existing tags.
# Ensure the tags cell below is in `Raw` format, rather than `Markdown` or `Code`.

# %% [markdown]
# ### Background
# An *optional* overview of the scientific, economic or environmental management issue or challenge being addressed by Digital Earth Australia.
# For `Beginners_Guide` or `Frequently_Used_Code` notebooks, this may include information about why the particular technique or approach is useful or required.
# If you need to cite a scientific paper or link to a website, use a persistent DOI link if possible and link in-text (e.g. [Dhu et al. 2017](https://doi.org/10.1080/20964471.2017.1402490)).

# %% [markdown]
# ### Description
# A _compulsory_ description of the notebook, including a brief overview of how Digital Earth Australia helps to address the problem set out above, and a run-down of the tools/methods being demonstrated below.

# %% [markdown]
# ### Prerequisites

# %% [markdown]
# ### Technical details
# * **Products used:** `product_name`, `product_name`, `product_name`
# * **Analyses used:** NDWI water index, geomedian compositing, pixel drill
# * **Special requirements:** An _optional_ description of any special requirements, e.g. If running on the [NCI](https://nci.org.au/), ensure that `module load otps` is run prior to launching this notebook

# %% [markdown]
# ## Getting started
# Provide any particular instructions that the user might need, e.g. To run this analysis, run all the cells in the notebook, starting with the "Load packages" cell.

# %% [markdown]
# ### Load packages
# Use standard import commands; some are shown below.
# Begin with any `iPython` magic commands, followed by standard Python packages, then any additional functionality you need from the `Scripts` directory.

# %%
# %matplotlib inline

# import datacube
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import sys
# import xarray as xr

# sys.path.append("../Scripts")

# %%
# %matplotlib inline

# import sys

# sys.path.append("../Scripts")
# from dea_plotting import rgb
# from dea_plotting import display_map
# from dea_plotting import map_shapefile

# %% [markdown]
# ### Connect to the datacube
# Give your datacube app a unique name that is consistent with the purpose of the notebook.

# %%
import datacube

# Temporary solution to account for Collection 3 data being in a different
# database on the NCI
try:
    dc = datacube.Datacube(app="Introduction_to_products", env="c3-samples")
except:
    dc = datacube.Datacube(app="Introduction_to_products")

# %% [markdown]
# ### Analysis parameters - COPY CELL FROM INTRO TO PLOTTING
#
# An *optional* section to inform the user of any parameters they'll need to configure to run the notebook:
# * `param_name_1`: Simple description (e.g. `example_value`). Advice about appropriate values to choose for this parameter.
# * `param_name_2`: Simple description (e.g. `example_value`). Advice about appropriate values to choose for this parameter.

# %%
lat_range = (-27.58, -27.666)
lon_range = (153.3, 153.4)
time_range = ("2015", "2016")

# %% [markdown]
# ## List products

# %% [markdown]
# Use markdown text for detailed, descriptive text explaining what the code below does and why it is needed.

# %%
dc.

# %%
products = dc.list_products()

# %%
products
# Out:
#                                 name  \
# id
# 10       fc_percentile_albers_annual
# 11     fc_percentile_albers_seasonal
# 33                     ga_ls5t_ard_3
# 34                     ga_ls7e_ard_3
# 35                     ga_ls8c_ard_3
# 46           ga_s2a_ard_nbar_granule
# 47           ga_s2b_ard_nbar_granule
# 6                 high_tide_comp_20p
# 27                           item_v2
# 28                      item_v2_conf
# 9               landsat_barest_earth
# 7                  low_tide_comp_20p
# 4                      ls5_fc_albers
# 3         ls5_nbart_geomedian_annual
# 41                     ls7_fc_albers
# 2         ls7_nbart_geomedian_annual
# 8            ls8_barest_earth_albers
# 5                      ls8_fc_albers
# 1         ls8_nbart_geomedian_annual
# 12                    mangrove_cover
# 30  multi_scale_topographic_position
# 13                             nidem
# 40            s1_gamma0_geotif_scene
# 38                   s2a_ard_granule
# 14                   s2a_l1c_aws_pds
# 36               s2a_level1c_granule
# 16                   s2a_nrt_granule
# 39                   s2b_ard_granule
# 15                   s2b_l1c_aws_pds
# 37               s2b_level1c_granule
# 17                   s2b_nrt_granule
# 20                sentinel2_wofs_nrt
# 29              weathering_intensity
# 21                       wofs_albers
# 24               wofs_annual_summary
# 25              wofs_apr_oct_summary
# 22             wofs_filtered_summary
# 26              wofs_nov_mar_summary
# 23                      wofs_summary
#
#                                           description  cloud_cover  \
# id
# 10  Landsat Fractional Cover percentile 25 metre, ...          NaN
# 11  Landsat Fractional Cover percentile 25 metre, ...          NaN
# 33                                      Landsat 5 ARD          NaN
# 34                                      Landsat 7 ARD          NaN
# 35                                      Landsat 8 ARD          NaN
# 46  Sentinel-2A MSI Definitive ARD - NBAR and Pixe...          NaN
# 47  Sentinel-2B MSI Definitive ARD - NBAR and Pixe...          NaN
# 6     High tide 20 percentage composites 25m v. 2.0.0          NaN
# 27                             Relative Extents Model          NaN
# 28  Average ndwi Standard Deviation, the Confidenc...          NaN
# 9   Landsat-5/Landsat-7/Landsat-8 combined Barest ...          NaN
# 7      Low tide 20 percentage composites 25m v. 2.0.0          NaN
# 4   Landsat 5 Fractional Cover 25 metre, 100km til...          NaN
# 3   Surface Reflectance Geometric Median 25 metre,...          NaN
# 41  Landsat 7 Fractional Cover 25 metre, 100km til...          NaN
# 2   Surface Reflectance Geometric Median 25 metre,...          NaN
# 8   Landsat-8 Barest Earth pixel composite albers ...          NaN
# 5   Landsat 8 Fractional Cover 25 metre, 100km til...          NaN
# 1   Surface Reflectance Geometric Median 25 metre,...          NaN
# 12  Mangrove Cover, Australian Albers Equal Area p...          NaN
# 30             Multi-scale Topographic Position Image          NaN
# 13  National Intertidal Digital Elevation Model 25...          NaN
# 40  Sentinel-1A/B SAR Gamma0 scenes, processed to ...          NaN
# 38  Sentinel-2A MSI ARD - NBAR NBART and Pixel Qua...          NaN
# 14                      Sentinel-2A MSI L1C - AWS PDS          NaN
# 36  Sentinel-2A Level1C - Ortho Rectified Top of A...          NaN
# 16  Sentinel-2A MSI NRT - NBAR NBART and Pixel Qua...          NaN
# 39  Sentinel-2B MSI ARD - NBAR NBART and Pixel Qua...          NaN
# 15                      Sentinel-2B MSI L1C - AWS PDS          NaN
# 37  Sentinel-2B Level1C - Ortho Rectified Top of A...          NaN
# 17  Sentinel-2B MSI NRT - NBAR NBART and Pixel Qua...          NaN
# 20       Sentinel 2 NRT Water Observations from Space          NaN
# 29                         Weathering Intensity Model          NaN
# 21  Historic Flood Mapping Water Observations from...          NaN
# 24    Water Observations from Space Annual Statistics          NaN
# 25  Water Observations from Space April to October...          NaN
# 22  Water Observations from Space Statistics confi...          NaN
# 26  Water Observations from Space November to Marc...          NaN
# 23           Water Observations from Space Statistics          NaN
#
#     gqa_stddev_y  gqa_abs_iterative_mean_x  fmask_water  \
# id
# 10           NaN                       NaN          NaN
# 11           NaN                       NaN          NaN
# 33           NaN                       NaN          NaN
# 34           NaN                       NaN          NaN
# 35           NaN                       NaN          NaN
# 46           NaN                       NaN          NaN
# 47           NaN                       NaN          NaN
# 6            NaN                       NaN          NaN
# 27           NaN                       NaN          NaN
# 28           NaN                       NaN          NaN
# 9            NaN                       NaN          NaN
# 7            NaN                       NaN          NaN
# 4            NaN                       NaN          NaN
# 3            NaN                       NaN          NaN
# 41           NaN                       NaN          NaN
# 2            NaN                       NaN          NaN
# 8            NaN                       NaN          NaN
# 5            NaN                       NaN          NaN
# 1            NaN                       NaN          NaN
# 12           NaN                       NaN          NaN
# 30           NaN                       NaN          NaN
# 13           NaN                       NaN          NaN
# 40           NaN                       NaN          NaN
# 38           NaN                       NaN          NaN
# 14           NaN                       NaN          NaN
# 36           NaN                       NaN          NaN
# 16           NaN                       NaN          NaN
# 39           NaN                       NaN          NaN
# 15           NaN                       NaN          NaN
# 37           NaN                       NaN          NaN
# 17           NaN                       NaN          NaN
# 20           NaN                       NaN          NaN
# 29           NaN                       NaN          NaN
# 21           NaN                       NaN          NaN
# 24           NaN                       NaN          NaN
# 25           NaN                       NaN          NaN
# 22           NaN                       NaN          NaN
# 26           NaN                       NaN          NaN
# 23           NaN                       NaN          NaN
#
#     gqa_abs_iterative_mean_y  product_family creation_time  \
# id
# 10                       NaN             NaN          None
# 11                       NaN             NaN          None
# 33                       NaN             NaN          None
# 34                       NaN             NaN          None
# 35                       NaN             NaN          None
# 46                       NaN             NaN          None
# 47                       NaN             NaN          None
# 6                        NaN             NaN          None
# 27                       NaN             NaN          None
# 28                       NaN             NaN          None
# 9                        NaN             NaN          None
# 7                        NaN             NaN          None
# 4                        NaN             NaN          None
# 3                        NaN             NaN          None
# 41                       NaN             NaN          None
# 2                        NaN             NaN          None
# 8                        NaN             NaN          None
# 5                        NaN             NaN          None
# 1                        NaN             NaN          None
# 12                       NaN             NaN          None
# 30                       NaN             NaN          None
# 13                       NaN             NaN          None
# 40                       NaN             NaN          None
# 38                       NaN             NaN          None
# 14                       NaN             NaN          None
# 36                       NaN             NaN          None
# 16                       NaN             NaN          None
# 39                       NaN             NaN          None
# 15                       NaN             NaN          None
# 37                       NaN             NaN          None
# 17                       NaN             NaN          None
# 20                       NaN             NaN          None
# 29                       NaN             NaN          None
# 21                       NaN             NaN          None
# 24                       NaN             NaN          None
# 25                       NaN             NaN          None
# 22                       NaN             NaN          None
# 26                       NaN             NaN          None
# 23                       NaN             NaN          None
#
#                                product_type  ...  fmask_cloud_shadow  gqa  \
# id                                           ...
# 10     fractional_cover_statistical_summary  ...                 NaN  NaN
# 11        fractional_cover_seasonal_summary  ...                 NaN  NaN
# 33                                      NaN  ...                 NaN  NaN
# 34                                      NaN  ...                 NaN  NaN
# 35                                      NaN  ...                 NaN  NaN
# 46                            S2MSIARD_NBAR  ...                 NaN  NaN
# 47                            S2MSIARD_NBAR  ...                 NaN  NaN
# 6                           tidal_composite  ...                 NaN  NaN
# 27                              item_v2.0.0  ...                 NaN  NaN
# 28                              item_v2.0.0  ...                 NaN  NaN
# 9                      landsat_barest_earth  ...                 NaN  NaN
# 7                           tidal_composite  ...                 NaN  NaN
# 4                          fractional_cover  ...                 NaN  NaN
# 3   surface_reflectance_statistical_summary  ...                 NaN  NaN
# 41                         fractional_cover  ...                 NaN  NaN
# 2   surface_reflectance_statistical_summary  ...                 NaN  NaN
# 8              landsat8_barest_earth_mosaic  ...                 NaN  NaN
# 5                          fractional_cover  ...                 NaN  NaN
# 1   surface_reflectance_statistical_summary  ...                 NaN  NaN
# 12                    mangrove_extent_cover  ...                 NaN  NaN
# 30                        topographic_model  ...                 NaN  NaN
# 13                             nidem_v1.0.0  ...                 NaN  NaN
# 40                                   gamma0  ...                 NaN  NaN
# 38                                 S2MSIARD  ...                 NaN  NaN
# 14                                   level1  ...                 NaN  NaN
# 36                                  S2MSI1C  ...                 NaN  NaN
# 16                                      ard  ...                 NaN  NaN
# 39                                 S2MSIARD  ...                 NaN  NaN
# 15                                   level1  ...                 NaN  NaN
# 37                                  S2MSI1C  ...                 NaN  NaN
# 17                                      ard  ...                 NaN  NaN
# 20                                     wofs  ...                 NaN  NaN
# 29                                    model  ...                 NaN  NaN
# 21                                     wofs  ...                 NaN  NaN
# 24                      wofs_annual_summary  ...                 NaN  NaN
# 25                     wofs_apr_oct_summary  ...                 NaN  NaN
# 22                    wofs_filtered_summary  ...                 NaN  NaN
# 26                     wofs_nov_mar_summary  ...                 NaN  NaN
# 23                 wofs_statistical_summary  ...                 NaN  NaN
#
#     gqa_iterative_stddev_x  eo_sun_elevation gqa_iterative_mean_y region_code  \
# id
# 10                     NaN               NaN                  NaN         NaN
# 11                     NaN               NaN                  NaN         NaN
# 33                     NaN               NaN                  NaN         NaN
# 34                     NaN               NaN                  NaN         NaN
# 35                     NaN               NaN                  NaN         NaN
# 46                     NaN               NaN                  NaN         NaN
# 47                     NaN               NaN                  NaN         NaN
# 6                      NaN               NaN                  NaN         NaN
# 27                     NaN               NaN                  NaN         NaN
# 28                     NaN               NaN                  NaN         NaN
# 9                      NaN               NaN                  NaN         NaN
# 7                      NaN               NaN                  NaN         NaN
# 4                      NaN               NaN                  NaN         NaN
# 3                      NaN               NaN                  NaN         NaN
# 41                     NaN               NaN                  NaN         NaN
# 2                      NaN               NaN                  NaN         NaN
# 8                      NaN               NaN                  NaN         NaN
# 5                      NaN               NaN                  NaN         NaN
# 1                      NaN               NaN                  NaN         NaN
# 12                     NaN               NaN                  NaN         NaN
# 30                     NaN               NaN                  NaN         NaN
# 13                     NaN               NaN                  NaN         NaN
# 40                     NaN               NaN                  NaN         NaN
# 38                     NaN               NaN                  NaN         NaN
# 14                     NaN               NaN                  NaN         NaN
# 36                     NaN               NaN                  NaN         NaN
# 16                     NaN               NaN                  NaN         NaN
# 39                     NaN               NaN                  NaN         NaN
# 15                     NaN               NaN                  NaN         NaN
# 37                     NaN               NaN                  NaN         NaN
# 17                     NaN               NaN                  NaN         NaN
# 20                     NaN               NaN                  NaN         NaN
# 29                     NaN               NaN                  NaN         NaN
# 21                     NaN               NaN                  NaN         NaN
# 24                     NaN               NaN                  NaN         NaN
# 25                     NaN               NaN                  NaN         NaN
# 22                     NaN               NaN                  NaN         NaN
# 26                     NaN               NaN                  NaN         NaN
# 23                     NaN               NaN                  NaN         NaN
#
#           crs                               resolution             tile_size  \
# id
# 10  EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
# 11  EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
# 33        NaN                                      NaN                   NaN
# 34        NaN                                      NaN                   NaN
# 35        NaN                                      NaN                   NaN
# 46        NaN                                      NaN                   NaN
# 47        NaN                                      NaN                   NaN
# 6   EPSG:3577                                (-25, 25)                  None
# 27  EPSG:3577                                (-25, 25)                  None
# 28  EPSG:3577                                (-25, 25)                  None
# 9   EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
# 7   EPSG:3577                                (-25, 25)                  None
# 4   EPSG:3577                                (-25, 25)                  None
# 3   EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
# 41  EPSG:3577                                (-25, 25)                  None
# 2   EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
# 8   EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
# 5   EPSG:3577                                (-25, 25)                  None
# 1   EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
# 12  EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
# 30  EPSG:4326  (-0.000833333333347, 0.000833333333347)            (1.0, 1.0)
# 13  EPSG:3577                                (-25, 25)                  None
# 40        NaN                                      NaN                   NaN
# 38        NaN                                      NaN                   NaN
# 14        NaN                                      NaN                   NaN
# 36        NaN                                      NaN                   NaN
# 16        NaN                                      NaN                   NaN
# 39        NaN                                      NaN                   NaN
# 15        NaN                                      NaN                   NaN
# 37        NaN                                      NaN                   NaN
# 17        NaN                                      NaN                   NaN
# 20        NaN                                      NaN                   NaN
# 29  EPSG:4326  (-0.000833333333347, 0.000833333333347)      (1200.0, 1200.0)
# 21  EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
# 24  EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
# 25  EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
# 22  EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
# 26  EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
# 23  EPSG:3577                                (-25, 25)  (100000.0, 100000.0)
#
#        spatial_dimensions
# id
# 10                 (y, x)
# 11                 (y, x)
# 33                    NaN
# 34                    NaN
# 35                    NaN
# 46                    NaN
# 47                    NaN
# 6                  (y, x)
# 27                 (y, x)
# 28                 (y, x)
# 9                  (y, x)
# 7                  (y, x)
# 4                  (y, x)
# 3                  (y, x)
# 41                 (y, x)
# 2                  (y, x)
# 8                  (y, x)
# 5                  (y, x)
# 1                  (y, x)
# 12                 (y, x)
# 30  (latitude, longitude)
# 13                 (y, x)
# 40                    NaN
# 38                    NaN
# 14                    NaN
# 36                    NaN
# 16                    NaN
# 39                    NaN
# 15                    NaN
# 37                    NaN
# 17                    NaN
# 20                    NaN
# 29  (latitude, longitude)
# 21                 (y, x)
# 24                 (y, x)
# 25                 (y, x)
# 22                 (y, x)
# 26                 (y, x)
# 23                 (y, x)
#
# [39 rows x 50 columns]

# %%
products.name.tolist()
# Out:
# ['fc_percentile_albers_annual',
#  'fc_percentile_albers_seasonal',
#  'ga_ls5t_ard_3',
#  'ga_ls7e_ard_3',
#  'ga_ls8c_ard_3',
#  'ga_s2a_ard_nbar_granule',
#  'ga_s2b_ard_nbar_granule',
#  'high_tide_comp_20p',
#  'item_v2',
#  'item_v2_conf',
#  'landsat_barest_earth',
#  'low_tide_comp_20p',
#  'ls5_fc_albers',
#  'ls5_nbart_geomedian_annual',
#  'ls7_fc_albers',
#  'ls7_nbart_geomedian_annual',
#  'ls8_barest_earth_albers',
#  'ls8_fc_albers',
#  'ls8_nbart_geomedian_annual',
#  'mangrove_cover',
#  'multi_scale_topographic_position',
#  'nidem',
#  's1_gamma0_geotif_scene',
#  's2a_ard_granule',
#  's2a_l1c_aws_pds',
#  's2a_level1c_granule',
#  's2a_nrt_granule',
#  's2b_ard_granule',
#  's2b_l1c_aws_pds',
#  's2b_level1c_granule',
#  's2b_nrt_granule',
#  'sentinel2_wofs_nrt',
#  'weathering_intensity',
#  'wofs_albers',
#  'wofs_annual_summary',
#  'wofs_apr_oct_summary',
#  'wofs_filtered_summary',
#  'wofs_nov_mar_summary',
#  'wofs_summary']

# %%
products.columns.tolist()
# Out:
# ['name',
#  'description',
#  'cloud_cover',
#  'gqa_stddev_y',
#  'gqa_abs_iterative_mean_x',
#  'fmask_water',
#  'gqa_abs_iterative_mean_y',
#  'product_family',
#  'creation_time',
#  'product_type',
#  'gqa_cep90',
#  'eo_gsd',
#  'fmask_snow',
#  'gqa_abs_y',
#  'platform',
#  'label',
#  'gqa_mean_x',
#  'gqa_ref_source',
#  'gqa_final_gcp_count',
#  'gqa_abs_iterative_mean_xy',
#  'gqa_final_qa_count',
#  'lat',
#  'gqa_stddev_xy',
#  'time',
#  'format',
#  'instrument',
#  'gqa_stddev_x',
#  'gqa_iterative_mean_xy',
#  'gqa_iterative_stddev_y',
#  'dataset_maturity',
#  'gqa_abs_xy',
#  'gqa_error_message',
#  'gqa_abs_x',
#  'gqa_iterative_stddev_xy',
#  'fmask_clear',
#  'lon',
#  'gqa_mean_y',
#  'eo_sun_azimuth',
#  'gqa_mean_xy',
#  'gqa_iterative_mean_x',
#  'fmask_cloud_shadow',
#  'gqa',
#  'gqa_iterative_stddev_x',
#  'eo_sun_elevation',
#  'gqa_iterative_mean_y',
#  'region_code',
#  'crs',
#  'resolution',
#  'tile_size',
#  'spatial_dimensions']

# %%
display_columns = ['name', 'description', 'product_family', 'product_type', 'platform', 'label', 'format', 'instrument', 'dataset_maturity', 'crs', 'resolution', 'tile_size', 'spatial_dimensions']
display_products = products[products][display_columns].dropna()
display_products
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2a26b0082da6> in <module>
#       1 display_columns = ['name', 'description', 'product_family', 'product_type', 'platform', 'label', 'format', 'instrument', 'dataset_maturity', 'crs', 'resolution', 'tile_size', 'spatial_dimensions']
# ----> 2 display_products = products[products][display_columns].dropna()
#       3 display_products
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2912         # Do we have a (boolean) DataFrame?
#    2913         if isinstance(key, DataFrame):
# -> 2914             return self._getitem_frame(key)
#    2915
#    2916         # Do we have a (boolean) 1d indexer?
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _getitem_frame(self, key)
#    3007     def _getitem_frame(self, key):
#    3008         if key.values.size and not is_bool_dtype(key.values):
# -> 3009             raise ValueError('Must pass DataFrame with boolean values only')
#    3010         return self.where(key)
#    3011
#
# ValueError: Must pass DataFrame with boolean values only

# %% [markdown]
# ### Subheading 1
# Use subheadings to break up steps within a single section.

# %%
# Use code comments for low-level documentation of code
b = 2

# %% [markdown]
# ## Heading 2
# Use markdown text for detailed, descriptive text explaining what the code below does and why it is needed.

# %%
# Use code comments for low-level documentation of code
c = 3

# %% [markdown]
# ## Additional information

# %% [markdown]
# **License:** The code in this notebook is licensed under the [Apache License, Version 2.0](https://www.apache.org/licenses/LICENSE-2.0).
# Digital Earth Australia data is licensed under the [Creative Commons by Attribution 4.0](https://creativecommons.org/licenses/by/4.0/) license.
#
# **Contact:** If you need assistance, please post a question on the [Open Data Cube Slack channel](http://slack.opendatacube.org/) or on the [GIS Stack Exchange](https://gis.stackexchange.com/questions/ask?tags=open-data-cube) using the `open-data-cube` tag (you can view previously asked questions [here](https://gis.stackexchange.com/questions/tagged/open-data-cube)).
# If you would like to report an issue with this notebook, you can file one on [Github](https://github.com/GeoscienceAustralia/dea-notebooks).
#
# **Last modified:** September 2019
#
# **Compatible `datacube` version:**

# %%
print(datacube.__version__)
# Out:
# 1.7+43.gc873f3ea

# %% [markdown]
# ## Tags
# Browse all available tags on the DEA User Guide's [Tags Index](https://docs.dea.ga.gov.au/genindex.html)

# %% [raw]
# **Tags**: :index:`sandbox_compatible`, :index:`nci_compatible`, :index:`template`, :index:`dc.load`, :index:`plotting`, :index:`landsat8`, :index:`pixeldrill`
