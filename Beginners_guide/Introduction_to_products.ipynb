# %% [markdown]
# # Introduction to products and measurements

# %% [markdown]
# **Notebook currently compatible with the `NCI`|`DEA Sandbox` environment only**

# %% [markdown]
# ## Background
# A datacube is a digital information architechture that specialises in hosting and cataloguing spatial information.
# The DEA specialises in storing remotely sensed data, particularly from earth observation satellites such as the Landsat and Sentinel sensors.
#
# The DEA datacube not only stores the processed raw data but also compiles all the product derivatives of that data.
# Furthermore, the data products themselves are often composed of a range of measurements such as the suite of band values or statistical product summaries.
#
# Therefore, before running a data query to the datacube, it is useful to know what it contains.
# A straightforward way to see the product and measurement contents of a datacube is described in this notebook.

# %% [markdown]
# ## Prerequisites
# Users of this notebook should have a basic understanding of:
#  - [How to run a Jupyter Notebook](link to Intro_to_Jupyter notebook)
#  - [Satellite band naming and data processing naming conventions](link to Intro_to_DEA notebook)

# %% [markdown]
# ## Description
# This notebook demonstrates how to connect to a datacube and interrogate the available products and measurements stored within.
#
# Topics covered include:
# * How to connect to a datacube
# * How to list all the products
# * How to list all the product measurements

# %% [markdown]
# ## Technical details
# * **Products used:** `ga_ls5t_ard_3`
# * **Analyses used:** load products, load measurements

# %% [markdown]
# ## Getting started
# To run this analysis, run all the cells in the notebook, starting with the "Load packages" cell.

# %% [markdown]
# ### Load packages

# %%
import pandas as pd

# %% [markdown]
# ### Connect to the datacube
#
# To connect to a datacube, users first need to import the datacube module then provide an app name.
# This name is generated by the user and is used to track down problems with database queries.
# Create a short name that is consistent with the purpose of your notebook such as the way "Intro_to_products_and_measurements" has been used as the app name in this notebook.

# %%
import datacube

# Temporary solution to account for Collection 3 data being in a different
# database on the NCI
try:
    dc = datacube.Datacube(app="Intro_to_products_and_measurements", env="c3-samples")
except:
    dc = datacube.Datacube(app="Intro_to_products_and_measurements")

# %% [markdown]
# ## List products

# %% [markdown]
# Once a datacube instance has been created, users can explore the products and measurements stored within.
#
# The following cell lists all products that are currently available in the DEA datacube.
#
# Products listed under *name* in the following table represent the product options available to you when querying the datacube.
# There is a brief product description provided below for each product but for a comprehensive product description and access to product metadata, users are directed to the Geoscience Australia [Content Management Interface](https://cmi.ga.gov.au)

# %%
products = dc.list_products()
display_columns = [
    "name",
    "description",
    "product_type",
    "platform",
    "instrument",
    "crs",
    "resolution",
]
pd.set_option("max_colwidth", 250)
products[display_columns].sort_index()
# Out:
#                                 name  \
# id
# 1         ls8_nbart_geomedian_annual
# 2         ls7_nbart_geomedian_annual
# 3         ls5_nbart_geomedian_annual
# 4                      ls5_fc_albers
# 5                      ls8_fc_albers
# 6                 high_tide_comp_20p
# 7                  low_tide_comp_20p
# 8            ls8_barest_earth_albers
# 9               landsat_barest_earth
# 10       fc_percentile_albers_annual
# 11     fc_percentile_albers_seasonal
# 12                    mangrove_cover
# 13                             nidem
# 14                   s2a_l1c_aws_pds
# 15                   s2b_l1c_aws_pds
# 16                   s2a_nrt_granule
# 17                   s2b_nrt_granule
# 20                sentinel2_wofs_nrt
# 21                       wofs_albers
# 22             wofs_filtered_summary
# 23                      wofs_summary
# 24               wofs_annual_summary
# 25              wofs_apr_oct_summary
# 26              wofs_nov_mar_summary
# 27                           item_v2
# 28                      item_v2_conf
# 29              weathering_intensity
# 30  multi_scale_topographic_position
# 33                     ga_ls5t_ard_3
# 34                     ga_ls7e_ard_3
# 35                     ga_ls8c_ard_3
# 36               s2a_level1c_granule
# 37               s2b_level1c_granule
# 38                   s2a_ard_granule
# 39                   s2b_ard_granule
# 40            s1_gamma0_geotif_scene
# 41                     ls7_fc_albers
# 46           ga_s2a_ard_nbar_granule
# 47           ga_s2b_ard_nbar_granule
#
#                                                                                                                                                                                   description  \
# id
# 1                                                                              Surface Reflectance Geometric Median 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 2                                                                              Surface Reflectance Geometric Median 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 3                                                                              Surface Reflectance Geometric Median 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 4                                                                                        Landsat 5 Fractional Cover 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 5                                                                                        Landsat 8 Fractional Cover 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 6                                                                                                                                             High tide 20 percentage composites 25m v. 2.0.0
# 7                                                                                                                                              Low tide 20 percentage composites 25m v. 2.0.0
# 8                                                                     Landsat-8 Barest Earth pixel composite albers 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 9                                        Landsat-5/Landsat-7/Landsat-8 combined Barest Earth pixel composite albers 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 10                                                                              Landsat Fractional Cover percentile 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 11                                                                              Landsat Fractional Cover percentile 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 12                                                                                                                        Mangrove Cover, Australian Albers Equal Area projection (EPSG:3577)
# 13                                                                                                                                      National Intertidal Digital Elevation Model 25m 1.0.0
# 14                                                                                                                                                              Sentinel-2A MSI L1C - AWS PDS
# 15                                                                                                                                                              Sentinel-2B MSI L1C - AWS PDS
# 16                                                                                                                                         Sentinel-2A MSI NRT - NBAR NBART and Pixel Quality
# 17                                                                                                                                         Sentinel-2B MSI NRT - NBAR NBART and Pixel Quality
# 20                                                                                                                                               Sentinel 2 NRT Water Observations from Space
# 21                                                                                                                                       Historic Flood Mapping Water Observations from Space
# 22                                                                                                                               Water Observations from Space Statistics confidence filtered
# 23                                                                                                                                                   Water Observations from Space Statistics
# 24                                                                                                                                            Water Observations from Space Annual Statistics
# 25                                                                                                                                  Water Observations from Space April to October Statistics
# 26                                                                                                                                 Water Observations from Space November to March Statistics
# 27                                                                                                                                                                     Relative Extents Model
# 28                                                                                                                                      Average ndwi Standard Deviation, the Confidence Layer
# 29                                                                                                                                                                 Weathering Intensity Model
# 30                                                                                                                                                     Multi-scale Topographic Position Image
# 33                                                                                                                                                                              Landsat 5 ARD
# 34                                                                                                                                                                              Landsat 7 ARD
# 35                                                                                                                                                                              Landsat 8 ARD
# 36                                                                                                                        Sentinel-2A Level1C - Ortho Rectified Top of Atmosphere Reflectance
# 37                                                                                                                        Sentinel-2B Level1C - Ortho Rectified Top of Atmosphere Reflectance
# 38                                                                                                                                         Sentinel-2A MSI ARD - NBAR NBART and Pixel Quality
# 39                                                                                                                                         Sentinel-2B MSI ARD - NBAR NBART and Pixel Quality
# 40  Sentinel-1A/B SAR Gamma0 scenes, processed to the CEOS ARD standard - Orbit updates, GRD border noise, thermal noise, radiometric calibration and terrain correction, orthorectification.
# 41                                                                                       Landsat 7 Fractional Cover 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 46                                                                                                                                    Sentinel-2A MSI Definitive ARD - NBAR and Pixel Quality
# 47                                                                                                                                    Sentinel-2B MSI Definitive ARD - NBAR and Pixel Quality
#
#                                product_type                       platform  \
# id
# 1   surface_reflectance_statistical_summary                      LANDSAT_8
# 2   surface_reflectance_statistical_summary                      LANDSAT_7
# 3   surface_reflectance_statistical_summary                      LANDSAT_5
# 4                          fractional_cover                      LANDSAT_5
# 5                          fractional_cover                      LANDSAT_8
# 6                           tidal_composite                           None
# 7                           tidal_composite                           None
# 8              landsat8_barest_earth_mosaic                      LANDSAT_8
# 9                      landsat_barest_earth  LANDSAT_5,LANDSAT_7,LANDSAT_8
# 10     fractional_cover_statistical_summary  LANDSAT_5,LANDSAT_7,LANDSAT_8
# 11        fractional_cover_seasonal_summary  LANDSAT_5,LANDSAT_7,LANDSAT_8
# 12                    mangrove_extent_cover  LANDSAT_5,LANDSAT_7,LANDSAT_8
# 13                             nidem_v1.0.0                           None
# 14                                   level1                    SENTINEL_2A
# 15                                   level1                    SENTINEL_2B
# 16                                      ard                    SENTINEL_2A
# 17                                      ard                    SENTINEL_2B
# 20                                     wofs                           None
# 21                                     wofs                           None
# 22                    wofs_filtered_summary  LANDSAT_5,LANDSAT_7,LANDSAT_8
# 23                 wofs_statistical_summary  LANDSAT_5,LANDSAT_7,LANDSAT_8
# 24                      wofs_annual_summary  LANDSAT_5,LANDSAT_7,LANDSAT_8
# 25                     wofs_apr_oct_summary  LANDSAT_5,LANDSAT_7,LANDSAT_8
# 26                     wofs_nov_mar_summary  LANDSAT_5,LANDSAT_7,LANDSAT_8
# 27                              item_v2.0.0                           None
# 28                              item_v2.0.0                           None
# 29                                    model                        unknown
# 30                        topographic_model                           None
# 33                                      NaN                           None
# 34                                      NaN                           None
# 35                                      NaN                           None
# 36                                  S2MSI1C                    Sentinel-2A
# 37                                  S2MSI1C                    Sentinel-2B
# 38                                 S2MSIARD                    SENTINEL_2A
# 39                                 S2MSIARD                    SENTINEL_2B
# 40                                   gamma0                     SENTINEL_1
# 41                         fractional_cover                      LANDSAT_7
# 46                            S2MSIARD_NBAR                    SENTINEL_2A
# 47                            S2MSIARD_NBAR                    SENTINEL_2B
#
#      instrument        crs                               resolution
# id
# 1           OLI  EPSG:3577                                (-25, 25)
# 2           ETM  EPSG:3577                                (-25, 25)
# 3            TM  EPSG:3577                                (-25, 25)
# 4            TM  EPSG:3577                                (-25, 25)
# 5      OLI_TIRS  EPSG:3577                                (-25, 25)
# 6          None  EPSG:3577                                (-25, 25)
# 7          None  EPSG:3577                                (-25, 25)
# 8           OLI  EPSG:3577                                (-25, 25)
# 9   TM,ETM+,OLI  EPSG:3577                                (-25, 25)
# 10  TM,ETM+,OLI  EPSG:3577                                (-25, 25)
# 11  TM,ETM+,OLI  EPSG:3577                                (-25, 25)
# 12  TM,ETM+,OLI  EPSG:3577                                (-25, 25)
# 13         None  EPSG:3577                                (-25, 25)
# 14          MSI        NaN                                      NaN
# 15          MSI        NaN                                      NaN
# 16          MSI        NaN                                      NaN
# 17          MSI        NaN                                      NaN
# 20          MSI        NaN                                      NaN
# 21         None  EPSG:3577                                (-25, 25)
# 22  TM,ETM+,OLI  EPSG:3577                                (-25, 25)
# 23  TM,ETM+,OLI  EPSG:3577                                (-25, 25)
# 24   TM,ETM,OLI  EPSG:3577                                (-25, 25)
# 25   TM,ETM,OLI  EPSG:3577                                (-25, 25)
# 26   TM,ETM,OLI  EPSG:3577                                (-25, 25)
# 27         None  EPSG:3577                                (-25, 25)
# 28         None  EPSG:3577                                (-25, 25)
# 29         STRM  EPSG:4326  (-0.000833333333347, 0.000833333333347)
# 30         None  EPSG:4326  (-0.000833333333347, 0.000833333333347)
# 33         None        NaN                                      NaN
# 34         None        NaN                                      NaN
# 35         None        NaN                                      NaN
# 36          MSI        NaN                                      NaN
# 37          MSI        NaN                                      NaN
# 38          MSI        NaN                                      NaN
# 39          MSI        NaN                                      NaN
# 40          SAR        NaN                                      NaN
# 41          ETM  EPSG:3577                                (-25, 25)
# 46          MSI        NaN                                      NaN
# 47          MSI        NaN                                      NaN

# %% [markdown]
# ## List measurements

# %% [markdown]
# Most products are associated with a range of available measurements.
#
# From the *name* column of products listed above, let's interrogate the measurements associated with the ga_ls5t_ard_3 product.
# That is, the Geoscience Australia Landsat 5 Analysis-ready data Collection 3 product.
#
# Change the `product` name below and re-run the following cell to explore available measurements associated with other products.

# %%
product = "ga_ls8c_ard_3"

measurements = dc.list_measurements()
display_columns = ["units", "nodata", "aliases"]
measurements[display_columns].loc[product]
# Out:
#                            units nodata         aliases
# measurement
# nbar_coastal_aerosol           1   -999   [nbar_band01]
# nbar_blue                      1   -999   [nbar_band02]
# nbar_green                     1   -999   [nbar_band03]
# nbar_red                       1   -999   [nbar_band04]
# nbar_nir                       1   -999   [nbar_band05]
# nbar_swir_1                    1   -999   [nbar_band06]
# nbar_swir_2                    1   -999   [nbar_band07]
# nbar_panchromatic              1   -999   [nbar_band08]
# nbart_coastal_aerosol          1   -999  [nbart_band01]
# nbart_blue                     1   -999  [nbart_band02]
# nbart_green                    1   -999  [nbart_band03]
# nbart_red                      1   -999  [nbart_band04]
# nbart_nir                      1   -999  [nbart_band05]
# nbart_swir_1                   1   -999  [nbart_band06]
# nbart_swir_2                   1   -999  [nbart_band07]
# nbart_panchromatic             1   -999  [nbart_band08]
# oa_fmask                       1      0         [fmask]
# oa_nbar_contiguity             1    255             NaN
# oa_nbart_contiguity            1    255             NaN
# oa_azimuthal_exiting           1    NaN             NaN
# oa_azimuthal_incident          1    NaN             NaN
# oa_combined_terrain_shadow     1   -999             NaN
# oa_exiting_angle               1    NaN             NaN
# oa_incident_angle              1    NaN             NaN
# oa_relative_azimuth            1    NaN             NaN
# oa_relative_slope              1    NaN             NaN
# oa_satellite_azimuth           1    NaN             NaN
# oa_satellite_view              1    NaN             NaN
# oa_solar_azimuth               1    NaN             NaN
# oa_solar_zenith                1    NaN             NaN
# oa_time_delta                  1    NaN             NaN

# %% [markdown]
# ## Recommended next steps
#
# To continue following the introductory notebooks in the beginners guide, users are recommended to continue with:
# - [Introduction_to_querying](link to notebook)
# - [Introduction_to_plotting](link to notebook)
# - [Run_a_basic_analysis](link to notebook)
#
# Advanced users are recommended to explore the [DEA_datasets](https://github.com/GeoscienceAustralia/dea-notebooks/tree/develop/DEA_datasets) part of the repository.
# Here you can explore DEA products in depth.
# Continue exploring some with some [real world applications](https://github.com/GeoscienceAustralia/dea-notebooks/tree/develop/Real_world_examples)

# %% [markdown]
# ## Additional information

# %% [markdown]
# **License:** The code in this notebook is licensed under the [Apache License, Version 2.0](https://www.apache.org/licenses/LICENSE-2.0).
# Digital Earth Australia data is licensed under the [Creative Commons by Attribution 4.0](https://creativecommons.org/licenses/by/4.0/) license.
#
# **Contact:** If you need assistance, please post a question on the [Open Data Cube Slack channel](http://slack.opendatacube.org/) or on the [GIS Stack Exchange](https://gis.stackexchange.com/questions/ask?tags=open-data-cube) using the `open-data-cube` tag (you can view previously asked questions [here](https://gis.stackexchange.com/questions/tagged/open-data-cube)).
# If you would like to report an issue with this notebook, you can file one on [Github](https://github.com/GeoscienceAustralia/dea-notebooks).
#
# **Last modified:** October 2019
#
# **Compatible `datacube` version:**

# %%
print(datacube.__version__)
# Out:
# 1.7+43.gc873f3ea.dirty

# %% [markdown]
# ## Tags
# Browse all available tags on the DEA User Guide's [Tags Index](https://docs.dea.ga.gov.au/genindex.html)

# %% [raw]
# **Tags**: :index:`sandbox_compatible`, :index:`nci_compatible`, :index:`dc.load`, :index:`products`, :index:`measurements`
