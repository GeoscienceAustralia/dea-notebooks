# %% [markdown]
# # Introduction to products and measurements <img align="right" src="../Supplementary_data/dea_logo.jpg">
#
# * **Compatability:** Notebook currently compatible with both the `NCI` and `DEA Sandbox` environments
# * **Products used:**
# [ga_ls5t_ard_3](https://explorer.sandbox.dea.ga.gov.au/ga_ls5t_ard_3)
# * **Prerequisites:** Users of this notebook should have a basic understanding of:
#     * How to run a [Jupyter notebook](01_Jupyter_notebooks.ipynb)
#     * The basic structure of the DEA [satellite datasets](02_DEA.ipynb)

# %% [markdown]
# ## Background
# A "datacube" is a digital information architecture that specialises in hosting and cataloguing spatial information.
# [Digital Earth Australia (DEA)](https://www.ga.gov.au/dea) is based on the [Open Data Cube](https://www.opendatacube.org/) infrastructure, and specialises in storing remotely sensed data, particularly from Earth Observation satellites such as [Landsat](https://landsat.gsfc.nasa.gov/) and [Sentinel-2](https://www.copernicus.eu/en/about-copernicus/infrastructure/discover-our-satellites).
#
# The DEA datacube contains both raw satellite data and derivative data "products".
# These data products are often composed of a range of "measurements" such as the suite of remote sensing band values or statistical product summaries. Before running a query to load data from the datacube, it is useful to know what it contains.
# This notebook demonstrates several straightforward ways to inspect the product and measurement contents of a datacube.

# %% [markdown]
# ## Description
# This notebook demonstrates how to connect to a datacube and interrogate the available products and measurements stored within.
# Topics covered include:
#
# * How to connect to a datacube
# * How to list all the products
# * How to list all the product measurements
# * How to interactively visualise data in the datacube
#
# ***

# %% [markdown]
# ## Getting started
# To run this introduction to products and measurements, run all the cells in the notebook starting with the "Load packages" cell. For help with running notebook cells, refer back to the [Jupyter Notebooks notebook](01_Jupyter_notebooks.ipynb).

# %% [markdown]
# ### Load packages
# The `datacube` package is required to access and work with available data.
# The `pandas` package is required to format tables.
# The `DcViewer` utility provides an interface for interactively exploring the products available in the datacube.

# %%
import datacube
import pandas as pd
from odc.ui import DcViewer

# Set some configurations for displaying tables nicely
pd.set_option('display.max_colwidth', 200)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Connect to the datacube
#
# After importing the `datacube` package, users need to specify a name for their session, known as the app name.
#
# This name is generated by the user and is used to track down issues with database queries.
# It does not have any effect on the analysis.
# Use a short name that is consistent with the purpose of your notebook such as the way `03_Products_and_measurements` has been used as the app name in this notebook.
#
# The resulting `dc` object provides access to all the data contained within the Digital Earth Australia datacube.

# %%
dc = datacube.Datacube(app="03_Products_and_measurements")

# %% [markdown]
# ## List products

# %% [markdown]
# Once a datacube instance has been created, users can explore the products and measurements stored within.
#
# The following cell lists all products that are currently available in the DEA datacube by using the `dc.list_products()` function.
#
# Products listed under **name** in the following table represent the product options available when querying the datacube.
# The table below provides some useful information about each product, including a brief product **description**, the **instrument** and **platform** the data originated from (e.g. Landsat 8 OLI), and the product's default **crs** (coordinate reference system) and **resolution** if applicable.
#
# > For a comprehensive product description and access to complete product metadata, users are directed to the Geoscience Australia [Content Management Interface](https://cmi.ga.gov.au)

# %%
products = dc.list_products()

display_columns = ["name",
                   "description",
                   "platform",
                   "instrument",
                   "crs",
                   "resolution"]

products[display_columns].sort_index()
# Out:
#                              name  \
# id
# 1    ls5_satellite_telemetry_data
# 2                ls5_level1_scene
# 3                  ls5_nbar_scene
# 4                 ls5_nbart_scene
# 5                    ls5_pq_scene
# 6                 ls5_nbar_albers
# 8    ls7_satellite_telemetry_data
# 9                ls7_level1_scene
# 10                 ls7_nbar_scene
# 11                ls7_nbart_scene
# 12                   ls7_pq_scene
# 13   ls8_satellite_telemetry_data
# 14               ls8_level1_scene
# 15                 ls8_nbar_scene
# 16                ls8_nbart_scene
# 17                   ls8_pq_scene
# 19                ls8_nbar_albers
# 20                  ls8_pq_albers
# 21                ls7_nbar_albers
# 22                  ls7_pq_albers
# 23                  ls5_pq_albers
# 26               ls5_nbart_albers
# 28               ls8_nbart_albers
# 29               ls7_nbart_albers
# 32                       dsm1sv10
# 36             bom_rainfall_grids
# 40           ls8_level1_oli_scene
# 53                      gamma_ray
# 56                 srtm_dem1sv1_0
# 57             ls8_nbar_oli_scene
# 58            ls8_nbart_oli_scene
# 59               ls8_pq_oli_scene
# 60            ls8_nbar_oli_albers
# 61           ls8_nbart_oli_albers
# 63             high_tide_comp_20p
# 64           high_tide_comp_count
# 65              low_tide_comp_20p
# 66            low_tide_comp_count
# 67                        item_v2
# 68                   item_v2_conf
# 69                  ls5_fc_albers
# 70                  ls7_fc_albers
# 71                  ls8_fc_albers
# 73            ls8_pq_legacy_scene
# 74        ls8_pq_legacy_oli_scene
# 75            ls5_pq_legacy_scene
# 76            ls7_pq_legacy_scene
# 77                    wofs_albers
# 78        pq_count_annual_summary
# 79               pq_count_summary
# 80              ls8_pq_oli_albers
# 81     ls8_nbart_geomedian_annual
# 82     ls7_nbart_geomedian_annual
# 83     ls5_nbart_geomedian_annual
# 84                   wofs_summary
# 85          wofs_filtered_summary
# 86                          mrvbf
# 87                          modis
# 88                            dsm
# 89                    urban_areas
# 90                s2a_ard_granule
# 91                s2b_ard_granule
# 92            s2a_level1c_granule
# 93            s2b_level1c_granule
# 94                  ls5_usgs_l2c1
# 95                  ls7_usgs_l2c1
# 96                  ls8_usgs_l2c1
# 97            wofs_annual_summary
# 98        ls8_barest_earth_mosaic
# 99    fc_percentile_albers_annual
# 100          wofs_apr_oct_summary
# 101          wofs_nov_mar_summary
# 102         ls8_nbart_tmad_annual
# 103         ls7_nbart_tmad_annual
# 104         ls5_nbart_tmad_annual
# 105  mangrove_extent_cover_albers
# 106                     s2_tsmask
# 107          landsat_barest_earth
# 108            usgs_ls5t_level1_1
# 109            usgs_ls7e_level1_1
# 110            usgs_ls8c_level1_1
# 111                 ga_ls5t_ard_3
# 112                 ga_ls7e_ard_3
# 113                 ga_ls8c_ard_3
# 114              ga_ls5t_level1_3
# 115              ga_ls7e_level1_3
# 116              ga_ls8c_level1_3
#
#                                                                                                                                                                                                  description  \
# id
# 1                                                                                                                                                                         Landsat 5 Satellite Telemetry Data
# 2                                                                                                                                                              Landsat 5 Level 1 At-sensor Radiance 25 metre
# 3                                                                                                                                                                                    Landsat 5 NBAR 25 metre
# 4                                                                                                                                                                                   Landsat 5 NBART 25 metre
# 5                                                                                                                                                                                      Landsat 5 PQ 25 metre
# 6                                                                                               Landsat 5 Surface Reflectance NBAR 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 8                                                                                                                                                                         Landsat 7 Satellite Telemetry Data
# 9                                                                                                                                                              Landsat 7 Level 1 At-sensor Radiance 25 metre
# 10                                                                                                                                                                                   Landsat 7 NBAR 25 metre
# 11                                                                                                                                                                                  Landsat 7 NBART 25 metre
# 12                                                                                                                                                                                     Landsat 7 PQ 25 metre
# 13                                                                                                                                                                        Landsat 8 Satellite Telemetry Data
# 14                                                                                                                                                    Landsat 8 Level 1 OLI-TIRS At-sensor Radiance 25 metre
# 15                                                                                                                                                                                   Landsat 8 NBAR 25 metre
# 16                                                                                                                                                                                  Landsat 8 NBART 25 metre
# 17                                                                                                                                                                                     Landsat 8 PQ 25 metre
# 19                                                                                              Landsat 8 Surface Reflectance NBAR 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 20                                                                                                         Landsat 8 Pixel Quality 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 21                                                                                              Landsat 7 Surface Reflectance NBAR 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 22                                                                                                         Landsat 7 Pixel Quality 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 23                                                                                                         Landsat 5 Pixel Quality 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 26                                                                                             Landsat 5 Surface Reflectance NBART 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 28                                                                                             Landsat 8 Surface Relfectance NBART 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 29                                                                                             Landsat 7 Surface Reflectance NBART 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 32                                                                                                                                                                                      DSM 1sec Version 1.0
# 36                                                                                                                                         Interpolated Rain Gauge Precipitation 1-Day Australia 5km Gridded
# 40                                                                                                                                                         Landsat 8 OLI Level 1 At-sensor Radiance 25 metre
# 53                                                                                                                                                       The 2015 radiometric or gamma-ray grid of Australia
# 56                                                                                                                                                                                      DEM 1sec Version 1.0
# 57                                                                                                                                                                               Landsat 8 OLI NBAR 25 metre
# 58                                                                                                                                                                              Landsat 8 OLI NBART 25 metre
# 59                                                                                                                                                                                 Landsat 8 OLI PQ 25 metre
# 60                                                                                              Landsat 8 Surface Reflectance NBAR 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 61                                                                                             Landsat 8 Surface Relfectance NBART 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 63                                                                                                                                                   High Tide 20 percentage composites for entire coastline
# 64                                                                                                                                                                       High Tide 20 percentage pixel count
# 65                                                                                                                                                    Low Tide 20 percentage composites for entire coastline
# 66                                                                                                                                                                        Low Tide 20 percentage pixel count
# 67                                                                                                                                                                                  Intertidal Extents Model
# 68                                                                                                                                                                           Average ndwi Standard Deviation
# 69                                                                                                      Landsat 5 Fractional Cover 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 70                                                                                                      Landsat 7 Fractional Cover 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 71                                                                                                      Landsat 8 Fractional Cover 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 73                                                                                                                                                                              Landsat 8 PQ Legacy 25 metre
# 74                                                                                                                                                                          Landsat 8 OLI PQ Legacy 25 metre
# 75                                                                                                                                                                              Landsat 5 PQ Legacy 25 metre
# 76                                                                                                                                                                              Landsat 7 PQ Legacy 25 metre
# 77                                                                                                                                                      Historic Flood Mapping Water Observations from Space
# 78                                                                                                                                                                              Pixel Quality Statistics 25m
# 79                                                                                                                                                                              Pixel Quality Statistics 25m
# 80                                                                                                         Landsat 8 Pixel Quality 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 81                                                                                            Surface Reflectance Geometric Median 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 82                                                                                            Surface Reflectance Geometric Median 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 83                                                                                            Surface Reflectance Geometric Median 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 84                                                                                                                                                                  Water Observations from Space Statistics
# 85                                                                                                                                              Water Observations from Space Statistics confidence filtered
# 86                                                                                                                                                                  MrVBF ancillary data for wofs confidence
# 87                                                                                                                                                                  Modis ancillary data for wofs confidence
# 88                                                                                                    dsm ancillary data for wofs confidence, 25 metre, 100km tiles, Australian Albers Equal Area projection
# 89                                                                                                                                                             urbanAreas ancillary data for wofs confidence
# 90                                                                                                                                                        Sentinel-2A MSI ARD - NBAR NBART and Pixel Quality
# 91                                                                                                                                                        Sentinel-2B MSI ARD - NBAR NBART and Pixel Quality
# 92                                                                                                                                       Sentinel-2A Level1C - Ortho Rectified Top of Atmosphere Reflectance
# 93                                                                                                                                       Sentinel-2B Level1C - Ortho Rectified Top of Atmosphere Reflectance
# 94                                                                                                                                         Landsat 5 Thematic Mapper (TM) USGS Analysis Ready Data 30m scene
# 95                                                                                                                                     Landsat 7 Enhanced Thematic Mapper Plus (ETM+) USGS ARD 30 metre tile
# 96                                                                                             Landsat 8 Operational Land Imager (OLI) and Thermal Infrared Sensor (TIRS) USGS Analysis Ready Data 30m scene
# 97                                                                                                                                                           Water Observations from Space Annual Statistics
# 98                                                                                    Landsat-8 Barest Earth pixel composite mosaic 25 metre, 25km tile, Australian Albers Equal Area projection (EPSG:3577)
# 99                                                                                             Landsat Fractional Cover percentile 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 100                                                                                                                                                Water Observations from Space April to October Statistics
# 101                                                                                                                                               Water Observations from Space November to March Statistics
# 102                                                                           Surface Reflectance Triple Median Absolute Deviation 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 103                                                                           Surface Reflectance Triple Median Absolute Deviation 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 104                                                                           Surface Reflectance Triple Median Absolute Deviation 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 105                                                                                            Mangroves conver extent and classes 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 106  Time series cloud and cloud shadow detection for Sentinel-2A and Sentinel-2B surface reflectance data.\n\nTSmask classifies a pixel as one of the following four categories: no observation, clear, ...
# 107                                                     Landsat-5/Landsat-7/Landsat-8 combined Barest Earth pixel composite albers 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 108                                                                                                                                                                  Landsat 5 TM Level 1, USGS Collection 1
# 109                                                                                                                                                                Landsat 7 ETM+ Level 1, USGS Collection 1
# 110                                                                                                                                                            Landsat 8 OLI-TIRS Level 1, USGS Collection 1
# 111                                                                                                                                                                        Landsat 5 TM ARD, GA Collection 3
# 112                                                                                                                                                                      Landsat 7 ETM+ ARD, GA Collection 3
# 113                                                                                                                                                                  Landsat 8 OLI-TIRS ARD, GA Collection 3
# 114                                                                                                                                                                    Landsat 5 TM Level 1, GA Collection 3
# 115                                                                                                                                                                  Landsat 7 ETM+ Level 1, GA Collection 3
# 116                                                                                                                                                              Landsat 8 OLI-TIRS Level 1, GA Collection 3
#
#                           platform              instrument  \
# id
# 1                        LANDSAT_5                      TM
# 2                        LANDSAT_5                      TM
# 3                        LANDSAT_5                      TM
# 4                        LANDSAT_5                      TM
# 5                        LANDSAT_5                      TM
# 6                        LANDSAT_5                      TM
# 8                        LANDSAT_7                     ETM
# 9                        LANDSAT_7                     ETM
# 10                       LANDSAT_7                     ETM
# 11                       LANDSAT_7                     ETM
# 12                       LANDSAT_7                     ETM
# 13                       LANDSAT_8                    None
# 14                       LANDSAT_8                OLI_TIRS
# 15                       LANDSAT_8                OLI_TIRS
# 16                       LANDSAT_8                OLI_TIRS
# 17                       LANDSAT_8                OLI_TIRS
# 19                       LANDSAT_8                OLI_TIRS
# 20                       LANDSAT_8                OLI_TIRS
# 21                       LANDSAT_7                     ETM
# 22                       LANDSAT_7                     ETM
# 23                       LANDSAT_5                      TM
# 26                       LANDSAT_5                      TM
# 28                       LANDSAT_8                OLI_TIRS
# 29                       LANDSAT_7                     ETM
# 32                            SRTM                     SIR
# 36                             BoM              rain gauge
# 40                       LANDSAT_8                     OLI
# 53                        aircraft  gamma_ray spectrometer
# 56         Space Shuttle Endeavour                     SIR
# 57                       LANDSAT_8                     OLI
# 58                       LANDSAT_8                     OLI
# 59                       LANDSAT_8                     OLI
# 60                       LANDSAT_8                     OLI
# 61                       LANDSAT_8                     OLI
# 63                            None                    None
# 64                            None                    None
# 65                            None                    None
# 66                            None                    None
# 67                            None                    None
# 68                            None                    None
# 69                       LANDSAT_5                      TM
# 70                       LANDSAT_7                     ETM
# 71                       LANDSAT_8                OLI_TIRS
# 73                       LANDSAT_8                OLI_TIRS
# 74                       LANDSAT_8                     OLI
# 75                       LANDSAT_5                      TM
# 76                       LANDSAT_7                     ETM
# 77                            None                    None
# 78                            None                    None
# 79                            None                    None
# 80                       LANDSAT_8                     OLI
# 81                       LANDSAT_8                     OLI
# 82                       LANDSAT_7                     ETM
# 83                       LANDSAT_5                      TM
# 84   LANDSAT_5,LANDSAT_7,LANDSAT_8             TM,ETM+,OLI
# 85   LANDSAT_5,LANDSAT_7,LANDSAT_8             TM,ETM+,OLI
# 86                            None                    None
# 87                            None                    None
# 88                            None                    None
# 89                            None                    None
# 90                     SENTINEL_2A                     MSI
# 91                     SENTINEL_2B                     MSI
# 92                     Sentinel-2A                     MSI
# 93                     Sentinel-2B                     MSI
# 94                       LANDSAT_5                      TM
# 95                       LANDSAT_7                     ETM
# 96                       LANDSAT_8                OLI_TIRS
# 97   LANDSAT_5,LANDSAT_7,LANDSAT_8              TM,ETM,OLI
# 98                       LANDSAT_8                     OLI
# 99   LANDSAT_5,LANDSAT_7,LANDSAT_8             TM,ETM+,OLI
# 100  LANDSAT_5,LANDSAT_7,LANDSAT_8              TM,ETM,OLI
# 101  LANDSAT_5,LANDSAT_7,LANDSAT_8              TM,ETM,OLI
# 102                      LANDSAT_8                     OLI
# 103                      LANDSAT_7                    ETM+
# 104                      LANDSAT_5                      TM
# 105  LANDSAT_5,LANDSAT_7,LANDSAT_8             TM,ETM+,OLI
# 106        SENTINEL_2A,SENTINEL_2B                     MSI
# 107  LANDSAT_5,LANDSAT_7,LANDSAT_8             TM,ETM+,OLI
# 108                           None                    None
# 109                           None                    None
# 110                           None                    None
# 111                           None                    None
# 112                           None                    None
# 113                           None                    None
# 114                           None                    None
# 115                           None                    None
# 116                           None                    None
#
#                                                                                                                                                         crs  \
# id
# 1                                                                                                                                                       NaN
# 2                                                                                                                                                       NaN
# 3                                                                                                                                                       NaN
# 4                                                                                                                                                       NaN
# 5                                                                                                                                                       NaN
# 6                                                                                                                                                 EPSG:3577
# 8                                                                                                                                                       NaN
# 9                                                                                                                                                       NaN
# 10                                                                                                                                                      NaN
# 11                                                                                                                                                      NaN
# 12                                                                                                                                                      NaN
# 13                                                                                                                                                      NaN
# 14                                                                                                                                                      NaN
# 15                                                                                                                                                      NaN
# 16                                                                                                                                                      NaN
# 17                                                                                                                                                      NaN
# 19                                                                                                                                                EPSG:3577
# 20                                                                                                                                                EPSG:3577
# 21                                                                                                                                                EPSG:3577
# 22                                                                                                                                                EPSG:3577
# 23                                                                                                                                                EPSG:3577
# 26                                                                                                                                                EPSG:3577
# 28                                                                                                                                                EPSG:3577
# 29                                                                                                                                                EPSG:3577
# 32                                                                                                                                                EPSG:4326
# 36                                                                                                                                                EPSG:4326
# 40                                                                                                                                                      NaN
# 53   GEOGCS["GEOCENTRIC DATUM of AUSTRALIA",DATUM["GDA94",SPHEROID["GRS80",6378137,298.257222101]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433]]
# 56                                                                                                                                                EPSG:4326
# 57                                                                                                                                                      NaN
# 58                                                                                                                                                      NaN
# 59                                                                                                                                                      NaN
# 60                                                                                                                                                EPSG:3577
# 61                                                                                                                                                EPSG:3577
# 63                                                                                                                                                EPSG:3577
# 64                                                                                                                                                EPSG:3577
# 65                                                                                                                                                EPSG:3577
# 66                                                                                                                                                EPSG:3577
# 67                                                                                                                                                EPSG:3577
# 68                                                                                                                                                EPSG:3577
# 69                                                                                                                                                EPSG:3577
# 70                                                                                                                                                EPSG:3577
# 71                                                                                                                                                EPSG:3577
# 73                                                                                                                                                      NaN
# 74                                                                                                                                                      NaN
# 75                                                                                                                                                      NaN
# 76                                                                                                                                                      NaN
# 77                                                                                                                                                EPSG:3577
# 78                                                                                                                                                EPSG:3577
# 79                                                                                                                                                EPSG:3577
# 80                                                                                                                                                EPSG:3577
# 81                                                                                                                                                EPSG:3577
# 82                                                                                                                                                EPSG:3577
# 83                                                                                                                                                EPSG:3577
# 84                                                                                                                                                EPSG:3577
# 85                                                                                                                                                EPSG:3577
# 86                                                                                                                                                EPSG:3577
# 87                                                                                                                                                EPSG:3577
# 88                                                                                                                                                EPSG:3577
# 89                                                                                                                                                EPSG:3577
# 90                                                                                                                                                      NaN
# 91                                                                                                                                                      NaN
# 92                                                                                                                                                      NaN
# 93                                                                                                                                                      NaN
# 94                                                                                                                                                      NaN
# 95                                                                                                                                                      NaN
# 96                                                                                                                                                      NaN
# 97                                                                                                                                                EPSG:3577
# 98                                                                                                                                                EPSG:3577
# 99                                                                                                                                                EPSG:3577
# 100                                                                                                                                               EPSG:3577
# 101                                                                                                                                               EPSG:3577
# 102                                                                                                                                               EPSG:3577
# 103                                                                                                                                               EPSG:3577
# 104                                                                                                                                               EPSG:3577
# 105                                                                                                                                               EPSG:3577
# 106                                                                                                                                                     NaN
# 107                                                                                                                                               EPSG:3577
# 108                                                                                                                                                     NaN
# 109                                                                                                                                                     NaN
# 110                                                                                                                                                     NaN
# 111                                                                                                                                                     NaN
# 112                                                                                                                                                     NaN
# 113                                                                                                                                                     NaN
# 114                                                                                                                                                     NaN
# 115                                                                                                                                                     NaN
# 116                                                                                                                                                     NaN
#
#                                 resolution
# id
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                (-25, 25)
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 19                               (-25, 25)
# 20                               (-25, 25)
# 21                               (-25, 25)
# 22                               (-25, 25)
# 23                               (-25, 25)
# 26                               (-25, 25)
# 28                               (-25, 25)
# 29                               (-25, 25)
# 32   (-0.00027777777778, 0.00027777777778)
# 36                           (-0.05, 0.05)
# 40                                     NaN
# 53                         (-0.001, 0.001)
# 56   (-0.00027777777778, 0.00027777777778)
# 57                                     NaN
# 58                                     NaN
# 59                                     NaN
# 60                               (-25, 25)
# 61                               (-25, 25)
# 63                               (-25, 25)
# 64                               (-25, 25)
# 65                               (-25, 25)
# 66                               (-25, 25)
# 67                               (-25, 25)
# 68                               (-25, 25)
# 69                               (-25, 25)
# 70                               (-25, 25)
# 71                               (-25, 25)
# 73                                     NaN
# 74                                     NaN
# 75                                     NaN
# 76                                     NaN
# 77                               (-25, 25)
# 78                               (-25, 25)
# 79                               (-25, 25)
# 80                               (-25, 25)
# 81                               (-25, 25)
# 82                               (-25, 25)
# 83                               (-25, 25)
# 84                               (-25, 25)
# 85                               (-25, 25)
# 86                               (-25, 25)
# 87                               (-25, 25)
# 88                               (-25, 25)
# 89                               (-25, 25)
# 90                                     NaN
# 91                                     NaN
# 92                                     NaN
# 93                                     NaN
# 94                                     NaN
# 95                                     NaN
# 96                                     NaN
# 97                               (-25, 25)
# 98                               (-25, 25)
# 99                               (-25, 25)
# 100                              (-25, 25)
# 101                              (-25, 25)
# 102                              (-25, 25)
# 103                              (-25, 25)
# 104                              (-25, 25)
# 105                              (-25, 25)
# 106                                    NaN
# 107                              (-25, 25)
# 108                                    NaN
# 109                                    NaN
# 110                                    NaN
# 111                                    NaN
# 112                                    NaN
# 113                                    NaN
# 114                                    NaN
# 115                                    NaN
# 116                                    NaN

# %% [markdown]
# ## List measurements

# %% [markdown]
# Most products are associated with a range of available measurements.
# These can be individual satellite bands (e.g. Landsat's near-infrared band) or statistical product summaries.
#
# The `dc.list_measurements()` function can be used to interrogate the measurements associated with a given product (specified by the **name** column from the table above).
# For example, `ga_ls5t_ard_3` refers to the Geoscience Australia Landsat 5 Analysis-ready data Collection 3 product.
#
# The table below includes a range of technical information about each band in the `ga_ls5t_ard_3` dataset, including any **aliases** which can be used to load the data, the data type or **dtype**, any **flags_definition** that are associated with the measurement (this information is used for tasks like cloud masking), and the measurement's **nodata** value.
#
# Change the `product` name below and re-run the following cell to explore available measurements associated with other products.

# %%
product = "ga_ls5t_ard_3"

measurements = dc.list_measurements()
measurements.loc[product]
# Out:
#                                                   name    dtype units nodata  \
# measurement
# nbar_blue                                    nbar_blue    int16     1   -999
# nbar_green                                  nbar_green    int16     1   -999
# nbar_red                                      nbar_red    int16     1   -999
# nbar_nir                                      nbar_nir    int16     1   -999
# nbar_swir_1                                nbar_swir_1    int16     1   -999
# nbar_swir_2                                nbar_swir_2    int16     1   -999
# nbart_blue                                  nbart_blue    int16     1   -999
# nbart_green                                nbart_green    int16     1   -999
# nbart_red                                    nbart_red    int16     1   -999
# nbart_nir                                    nbart_nir    int16     1   -999
# nbart_swir_1                              nbart_swir_1    int16     1   -999
# nbart_swir_2                              nbart_swir_2    int16     1   -999
# oa_fmask                                      oa_fmask    uint8     1      0
# oa_nbar_contiguity                  oa_nbar_contiguity    uint8     1    255
# oa_nbart_contiguity                oa_nbart_contiguity    uint8     1    255
# oa_azimuthal_exiting              oa_azimuthal_exiting  float32     1    NaN
# oa_azimuthal_incident            oa_azimuthal_incident  float32     1    NaN
# oa_combined_terrain_shadow  oa_combined_terrain_shadow    uint8     1    255
# oa_exiting_angle                      oa_exiting_angle  float32     1    NaN
# oa_incident_angle                    oa_incident_angle  float32     1    NaN
# oa_relative_azimuth                oa_relative_azimuth  float32     1    NaN
# oa_relative_slope                    oa_relative_slope  float32     1    NaN
# oa_satellite_azimuth              oa_satellite_azimuth  float32     1    NaN
# oa_satellite_view                    oa_satellite_view  float32     1    NaN
# oa_solar_azimuth                      oa_solar_azimuth  float32     1    NaN
# oa_solar_zenith                        oa_solar_zenith  float32     1    NaN
# oa_time_delta                            oa_time_delta  float32     1    NaN
#
#                                                   aliases  \
# measurement
# nbar_blue                                   [nbar_band01]
# nbar_green                                  [nbar_band02]
# nbar_red                                    [nbar_band03]
# nbar_nir                                    [nbar_band04]
# nbar_swir_1                                 [nbar_band05]
# nbar_swir_2                                 [nbar_band07]
# nbart_blue                           [nbart_band01, blue]
# nbart_green                         [nbart_band02, green]
# nbart_red                             [nbart_band03, red]
# nbart_nir                             [nbart_band04, nir]
# nbart_swir_1                [nbart_band05, swir_1, swir1]
# nbart_swir_2                [nbart_band07, swir_2, swir2]
# oa_fmask                                          [fmask]
# oa_nbar_contiguity                      [nbar_contiguity]
# oa_nbart_contiguity                    [nbart_contiguity]
# oa_azimuthal_exiting                  [azimuthal_exiting]
# oa_azimuthal_incident                [azimuthal_incident]
# oa_combined_terrain_shadow      [combined_terrain_shadow]
# oa_exiting_angle                          [exiting_angle]
# oa_incident_angle                        [incident_angle]
# oa_relative_azimuth                    [relative_azimuth]
# oa_relative_slope                        [relative_slope]
# oa_satellite_azimuth                  [satellite_azimuth]
# oa_satellite_view                        [satellite_view]
# oa_solar_azimuth                          [solar_azimuth]
# oa_solar_zenith                            [solar_zenith]
# oa_time_delta                                [time_delta]
#
#                                                                                                                                                                                   flags_definition  \
# measurement
# nbar_blue                                                                                                                                                                                      NaN
# nbar_green                                                                                                                                                                                     NaN
# nbar_red                                                                                                                                                                                       NaN
# nbar_nir                                                                                                                                                                                       NaN
# nbar_swir_1                                                                                                                                                                                    NaN
# nbar_swir_2                                                                                                                                                                                    NaN
# nbart_blue                                                                                                                                                                                     NaN
# nbart_green                                                                                                                                                                                    NaN
# nbart_red                                                                                                                                                                                      NaN
# nbart_nir                                                                                                                                                                                      NaN
# nbart_swir_1                                                                                                                                                                                   NaN
# nbart_swir_2                                                                                                                                                                                   NaN
# oa_fmask                    {'fmask': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'nodata', '1': 'valid', '2': 'cloud', '3': 'shadow', '4': 'snow', '5': 'water'}, 'description': 'Fmask'}}
# oa_nbar_contiguity                                                                                                                {'contiguous': {'bits': [0], 'values': {'0': False, '1': True}}}
# oa_nbart_contiguity                                                                                                               {'contiguous': {'bits': [0], 'values': {'0': False, '1': True}}}
# oa_azimuthal_exiting                                                                                                                                                                           NaN
# oa_azimuthal_incident                                                                                                                                                                          NaN
# oa_combined_terrain_shadow                                                                                                                                                                     NaN
# oa_exiting_angle                                                                                                                                                                               NaN
# oa_incident_angle                                                                                                                                                                              NaN
# oa_relative_azimuth                                                                                                                                                                            NaN
# oa_relative_slope                                                                                                                                                                              NaN
# oa_satellite_azimuth                                                                                                                                                                           NaN
# oa_satellite_view                                                                                                                                                                              NaN
# oa_solar_azimuth                                                                                                                                                                               NaN
# oa_solar_zenith                                                                                                                                                                                NaN
# oa_time_delta                                                                                                                                                                                  NaN
#
#                            spectral_definition number
# measurement
# nbar_blue                                  NaN    NaN
# nbar_green                                 NaN    NaN
# nbar_red                                   NaN    NaN
# nbar_nir                                   NaN    NaN
# nbar_swir_1                                NaN    NaN
# nbar_swir_2                                NaN    NaN
# nbart_blue                                 NaN    NaN
# nbart_green                                NaN    NaN
# nbart_red                                  NaN    NaN
# nbart_nir                                  NaN    NaN
# nbart_swir_1                               NaN    NaN
# nbart_swir_2                               NaN    NaN
# oa_fmask                                   NaN    NaN
# oa_nbar_contiguity                         NaN    NaN
# oa_nbart_contiguity                        NaN    NaN
# oa_azimuthal_exiting                       NaN    NaN
# oa_azimuthal_incident                      NaN    NaN
# oa_combined_terrain_shadow                 NaN    NaN
# oa_exiting_angle                           NaN    NaN
# oa_incident_angle                          NaN    NaN
# oa_relative_azimuth                        NaN    NaN
# oa_relative_slope                          NaN    NaN
# oa_satellite_azimuth                       NaN    NaN
# oa_satellite_view                          NaN    NaN
# oa_solar_azimuth                           NaN    NaN
# oa_solar_zenith                            NaN    NaN
# oa_time_delta                              NaN    NaN

# %% [markdown]
# ## Visualising available data
# The interactive `DcViewer` utility provides a more visual way of exploring the data that is available within the Digital Earth Australia datacube.
#
# After running the cell below, select a product from the drop-down menu on the top-right of the map to show the areas where data are available in blue.
# Use the back and forward buttons above the map to toggle through time.
#
# The utility is only able to visualise a limited number of datasets at one time.
# If the available data footprints do not appear, either press the "show" button on the top right, or zoom in on the map.

# %%
DcViewer(dc=dc, 
         time='2015', 
         width='800px',
         center=(-27.48, 153.10),
         zoom=7)
# Out:
# VBox(children=(HBox(children=(Dropdown(layout=Layout(flex='0 1 auto', width='10em'), options=('bom_rainfall_gr…

# %% [markdown]
# ### DEA Explorer sites
# Another way to view the available data within a datacube is to visit the DEA Datacube Explorer sites.
# These webpages visualise the data that is available for every product in DEA.
#
# There is a different Datacube Explorer page for both the NCI and DEA Sandbox environments to account for the different datasets that are available in each of these datacubes:
#
# * [NCI DEA Datacube Explorer](http://explorer.dea.ga.gov.au)
# * [DEA Sandbox Datacube Explorer](http://explorer.sandbox.dea.ga.gov.au)
#
# ![DEA Explorer](../Supplementary_data/03_Products_and_measurements/DEAExplorer.JPG)

# %% [markdown]
# ## Recommended next steps
#
# To continue working through the notebooks in this beginner's guide, the following notebooks are designed to be worked through in the following order:
#
# 1. [Jupyter Notebooks](01_Jupyter_notebooks.ipynb)
# 2. [Digital Earth Australia](02_DEA.ipynb)
# 3. **Products and measurements (this notebook)**
# 4. [Loading data](04_Loading_data.ipynb)
# 5. [Plotting](05_Plotting.ipynb)
# 6. [Performing a basic analysis](06_Basic_analysis.ipynb)
# 7. [Parallel processing with Dask](07_Parallel_processing_with_Dask.ipynb)
#
# Once you have worked through the beginner's guide, you can join advanced users by exploring:
#
# * The "DEA datasets" directory in the repository, where you can explore DEA products in depth.
# * The "Frequently used code" directory, which contains a recipe book of common techniques and methods for analysing DEA data.
# * The "Real-world examples" directory, which provides more complex workflows and analysis case studies.

# %% [markdown]
# ***
# ## Additional information
# **License:** The code in this notebook is licensed under the [Apache License, Version 2.0](https://www.apache.org/licenses/LICENSE-2.0).
# Digital Earth Australia data is licensed under the [Creative Commons by Attribution 4.0](https://creativecommons.org/licenses/by/4.0/) license.
#
# **Contact:** If you need assistance, please post a question on the [Open Data Cube Slack channel](http://slack.opendatacube.org/) or on the [GIS Stack Exchange](https://gis.stackexchange.com/questions/ask?tags=open-data-cube) using the `open-data-cube` tag (you can view previously asked questions [here](https://gis.stackexchange.com/questions/tagged/open-data-cube)).
# If you would like to report an issue with this notebook, you can file one on [Github](https://github.com/GeoscienceAustralia/dea-notebooks).
#
# **Last modified:** June 2020
#
# **Compatible datacube version:**

# %%
print(datacube.__version__)
# Out:
# 1.8.0

# %% [markdown]
# ## Tags
# Browse all available tags on the DEA User Guide's [Tags Index](https://docs.dea.ga.gov.au/genindex.html)

# %% [raw]
# **Tags**: :index:`sandbox compatible`, :index:`NCI compatible`, :index:`dc.list_products`, :index:`dc.list_measurements`, :index:`products`, :index:`measurements`, :index:`landsat 5`, :index:`datacube explorer`, :index:`DcViewer`
