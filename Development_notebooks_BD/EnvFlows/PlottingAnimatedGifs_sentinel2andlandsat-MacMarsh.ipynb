# %% [markdown]
# # Sentinel 2 + Landsat animation with hydrograph

# %%
# Import modules
import datacube 
import sys
import xarray as xr
import numpy as np
import calendar
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.patheffects as PathEffects
import matplotlib.patches as patches
import matplotlib.dates as mdates
import matplotlib.lines as mlines
from skimage import exposure
from datacube.utils import geometry
from datacube.utils.geometry import CRS
from datetime import datetime, timedelta

# Import external dea-notebooks functions using relative link to Scripts directory
sys.path.append('../../10_Scripts')
import DEADataHandling
import DEAPlotting

# Set up datacube instances
dc = datacube.Datacube(app='Time series animation')
#s2dc = datacube.Datacube(config='/g/data/r78/dc_configs/sentinel2.conf')

# Study area name used for output file
study_area = 'macmarsh'

# Thresholds used for cloud masking (Sentinel 2 is more aggressive)
landsat_masked_prop = 0.99
sentinel_masked_prop = 0.90

# Set up analysis data query using a buffer around a lat-long point
lat, lon, buffer = -30.72360833, 147.53250000, 5000
x, y = geometry.point(lon, lat, CRS('WGS84')).to_crs(CRS('EPSG:3577')).points[0]
query = {'x': (x - buffer, x + buffer),
         'y': (y - buffer, y + buffer),    
         'time': ('2015-01-01', '2018-07-30'),
         'crs': 'EPSG:3577'}

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Extract cloud-free clear Landsat and Sentinel observations
# Use the `load_clearlandsat` function to load Landsat observations and PQ data for multiple sensors (i.e. ls5, ls7, ls8), and return a single xarray dataset containing only observations that contain greater than a specified proportion of clear pixels.
#
# Load in Sentinel data for S2A and S2B.

# %%
# Custom mask that includes only cloudy or cloud shadowed pixels with data for all bands
custom_mask = {'cloud_acca': 'no_cloud', 
               'cloud_fmask': 'no_cloud', 
               'cloud_shadow_acca': 'no_cloud_shadow',
               'cloud_shadow_fmask': 'no_cloud_shadow',
               'contiguous': True}

# Load in data
ls578_ds = DEADataHandling.load_clearlandsat(dc=dc, query=query, product='nbart', 
                                        bands_of_interest=['green', 'nir', 'swir1', 'red'], 
                                        masked_prop=landsat_masked_prop, mask_dict=custom_mask)#, apply_mask=False)  

# Remove problematic timesteps
problem_times = ['2015-08-02', '2015-08-18', '2016-03-13', '2016-04-30', '2017-05-03', '2015-04-28','2016-08-22']
times_to_drop = [ls578_ds.time.loc[i].values for i in problem_times]

# Remove timesteps
ls578_ds = ls578_ds.drop(np.concatenate(times_to_drop), dim="time")
# Out:
# Loading ls5 pixel quality
#     Skipping ls5; no valid data for query
# Ignoring SLC-off observations for ls7
# Loading ls7 pixel quality
#     Loading 0 filtered ls7 timesteps
# Loading ls8 pixel quality
#     Loading 59 filtered ls8 timesteps
# Combining and sorting ls7, ls8 data
#     Replacing invalid -999 values with NaN (data will be coerced to float64)

# %% [markdown]
# ## Import Sentinel 2

# %%
problem_times = ['2015-08-02', '2015-08-18', '2016-03-13', '2016-04-30', '2017-05-03', '2015-04-28','2016-08-22']
times_to_drop = [ls578_ds.time.loc[i].values for i in problem_times]

# %%
dc.list_measurements()
# Out:
#                                                                                      aliases  \
# product               measurement
# bom_rainfall_grids    rainfall                                                           NaN
# dsm                   elevation                                                          NaN
#                       slope                                                              NaN
# dsm1sv10              elevation                                                          NaN
# gamma_ray             rad_air_dose_rate_unfiltered                                       NaN
#                       rad_k_equiv_conc_unfiltered                                        NaN
#                       rad_u_equiv_conc_unfiltered                                        NaN
#                       rad_th_equiv_conc_unfiltered                                       NaN
#                       rad_air_dose_rate_filtered                                         NaN
#                       rad_k_equiv_conc_filtered                                          NaN
#                       rad_u_equiv_conc_filtered                                          NaN
#                       rad_th_equiv_conc_filtered                                         NaN
#                       rad_ratio_tk                                                       NaN
#                       rad_ratio_u2t                                                      NaN
#                       rad_ratio_uk                                                       NaN
#                       rad_ratio_ut                                                       NaN
# high_tide_comp_20p    blue                                                               NaN
#                       green                                                              NaN
#                       red                                                                NaN
#                       nir                                                                NaN
#                       swir1                                                              NaN
#                       swir2                                                              NaN
# high_tide_comp_count  count_observations                                                 NaN
# item_v2               relative                                                           NaN
# item_v2_conf          stddev                                                             NaN
# low_tide_comp_20p     blue                                                               NaN
#                       green                                                              NaN
#                       red                                                                NaN
#                       nir                                                                NaN
#                       swir1                                                              NaN
# ...                                                                                      ...
# s2b_ard_granule       nbart_nir_1                    [nbart_band_08, nbart_B08, nbart_Band8]
#                       nbart_nir_2                   [nbart_band_8A, nbart_B8A, nbart_Band8A]
#                       nbart_swir_2                  [nbart_band_11, nbart_B11, nbart_Band11]
#                       nbart_swir_3                  [nbart_band_12, nbart_B12, nbart_Band12]
# s2b_level1c_granule   B01                                              [band_01, B01, Band1]
#                       B02                                              [band_02, B02, Band2]
#                       B03                                              [band_03, B03, Band3]
#                       B04                                              [band_04, B04, Band4]
#                       B05                                              [band_05, B05, Band5]
#                       B06                                              [band_06, B06, Band6]
#                       B07                                              [band_07, B07, Band7]
#                       B08                                              [band_08, B08, Band8]
#                       B8A                                             [band_8A, B8A, Band8A]
#                       B09                                              [band_09, B09, Band9]
#                       B10                                             [band_10, B10, Band10]
#                       B11                                             [band_11, B11, Band11]
#                       B12                                             [band_12, B12, Band12]
# srtm_dem1sv1_0        dem                                                                NaN
#                       dem_s                                                              NaN
#                       dem_h                                                              NaN
# urban_areas           band1                                                              NaN
# wofs_albers           water                                                              NaN
# wofs_annual_summary   count_wet                                                          NaN
#                       count_clear                                                        NaN
#                       frequency                                                          NaN
# wofs_filtered_summary confidence                                                         NaN
#                       wofs_filtered_summary                                              NaN
# wofs_summary          count_wet                                                          NaN
#                       count_clear                                                        NaN
#                       frequency                                                          NaN
#
#                                                       dtype  \
# product               measurement
# bom_rainfall_grids    rainfall                      float32
# dsm                   elevation                     float32
#                       slope                         float32
# dsm1sv10              elevation                     float32
# gamma_ray             rad_air_dose_rate_unfiltered  float32
#                       rad_k_equiv_conc_unfiltered   float32
#                       rad_u_equiv_conc_unfiltered   float32
#                       rad_th_equiv_conc_unfiltered  float32
#                       rad_air_dose_rate_filtered    float32
#                       rad_k_equiv_conc_filtered     float32
#                       rad_u_equiv_conc_filtered     float32
#                       rad_th_equiv_conc_filtered    float32
#                       rad_ratio_tk                  float32
#                       rad_ratio_u2t                 float32
#                       rad_ratio_uk                  float32
#                       rad_ratio_ut                  float32
# high_tide_comp_20p    blue                          float32
#                       green                         float32
#                       red                           float32
#                       nir                           float32
#                       swir1                         float32
#                       swir2                         float32
# high_tide_comp_count  count_observations              int16
# item_v2               relative                        int16
# item_v2_conf          stddev                        float32
# low_tide_comp_20p     blue                          float32
#                       green                         float32
#                       red                           float32
#                       nir                           float32
#                       swir1                         float32
# ...                                                     ...
# s2b_ard_granule       nbart_nir_1                     int16
#                       nbart_nir_2                     int16
#                       nbart_swir_2                    int16
#                       nbart_swir_3                    int16
# s2b_level1c_granule   B01                            uint16
#                       B02                            uint16
#                       B03                            uint16
#                       B04                            uint16
#                       B05                            uint16
#                       B06                            uint16
#                       B07                            uint16
#                       B08                            uint16
#                       B8A                            uint16
#                       B09                            uint16
#                       B10                            uint16
#                       B11                            uint16
#                       B12                            uint16
# srtm_dem1sv1_0        dem                           float32
#                       dem_s                         float32
#                       dem_h                         float32
# urban_areas           band1                           uint8
# wofs_albers           water                           int16
# wofs_annual_summary   count_wet                       int16
#                       count_clear                     int16
#                       frequency                     float32
# wofs_filtered_summary confidence                    float32
#                       wofs_filtered_summary         float32
# wofs_summary          count_wet                       int16
#                       count_clear                     int16
#                       frequency                     float32
#
#                                                                                      flags_definition  \
# product               measurement
# bom_rainfall_grids    rainfall                                                                    NaN
# dsm                   elevation                                                                   NaN
#                       slope                                                                       NaN
# dsm1sv10              elevation                                                                   NaN
# gamma_ray             rad_air_dose_rate_unfiltered                                                NaN
#                       rad_k_equiv_conc_unfiltered                                                 NaN
#                       rad_u_equiv_conc_unfiltered                                                 NaN
#                       rad_th_equiv_conc_unfiltered                                                NaN
#                       rad_air_dose_rate_filtered                                                  NaN
#                       rad_k_equiv_conc_filtered                                                   NaN
#                       rad_u_equiv_conc_filtered                                                   NaN
#                       rad_th_equiv_conc_filtered                                                  NaN
#                       rad_ratio_tk                                                                NaN
#                       rad_ratio_u2t                                                               NaN
#                       rad_ratio_uk                                                                NaN
#                       rad_ratio_ut                                                                NaN
# high_tide_comp_20p    blue                                                                        NaN
#                       green                                                                       NaN
#                       red                                                                         NaN
#                       nir                                                                         NaN
#                       swir1                                                                       NaN
#                       swir2                                                                       NaN
# high_tide_comp_count  count_observations                                                          NaN
# item_v2               relative                                                                    NaN
# item_v2_conf          stddev                                                                      NaN
# low_tide_comp_20p     blue                                                                        NaN
#                       green                                                                       NaN
#                       red                                                                         NaN
#                       nir                                                                         NaN
#                       swir1                                                                       NaN
# ...                                                                                               ...
# s2b_ard_granule       nbart_nir_1                                                                 NaN
#                       nbart_nir_2                                                                 NaN
#                       nbart_swir_2                                                                NaN
#                       nbart_swir_3                                                                NaN
# s2b_level1c_granule   B01                                                                         NaN
#                       B02                                                                         NaN
#                       B03                                                                         NaN
#                       B04                                                                         NaN
#                       B05                                                                         NaN
#                       B06                                                                         NaN
#                       B07                                                                         NaN
#                       B08                                                                         NaN
#                       B8A                                                                         NaN
#                       B09                                                                         NaN
#                       B10                                                                         NaN
#                       B11                                                                         NaN
#                       B12                                                                         NaN
# srtm_dem1sv1_0        dem                                                                         NaN
#                       dem_s                                                                       NaN
#                       dem_h                                                                       NaN
# urban_areas           band1                                                                       NaN
# wofs_albers           water                         {'dry': {'bits': [7, 6, 5, 4, 3, 1, 0], 'value...
# wofs_annual_summary   count_wet                                                                   NaN
#                       count_clear                                                                 NaN
#                       frequency                                                                   NaN
# wofs_filtered_summary confidence                                                                  NaN
#                       wofs_filtered_summary                                                       NaN
# wofs_summary          count_wet                                                                   NaN
#                       count_clear                                                                 NaN
#                       frequency                                                                   NaN
#
#                                                                             name  \
# product               measurement
# bom_rainfall_grids    rainfall                                          rainfall
# dsm                   elevation                                        elevation
#                       slope                                                slope
# dsm1sv10              elevation                                        elevation
# gamma_ray             rad_air_dose_rate_unfiltered  rad_air_dose_rate_unfiltered
#                       rad_k_equiv_conc_unfiltered    rad_k_equiv_conc_unfiltered
#                       rad_u_equiv_conc_unfiltered    rad_u_equiv_conc_unfiltered
#                       rad_th_equiv_conc_unfiltered  rad_th_equiv_conc_unfiltered
#                       rad_air_dose_rate_filtered      rad_air_dose_rate_filtered
#                       rad_k_equiv_conc_filtered        rad_k_equiv_conc_filtered
#                       rad_u_equiv_conc_filtered        rad_u_equiv_conc_filtered
#                       rad_th_equiv_conc_filtered      rad_th_equiv_conc_filtered
#                       rad_ratio_tk                                  rad_ratio_tk
#                       rad_ratio_u2t                                rad_ratio_u2t
#                       rad_ratio_uk                                  rad_ratio_uk
#                       rad_ratio_ut                                  rad_ratio_ut
# high_tide_comp_20p    blue                                                  blue
#                       green                                                green
#                       red                                                    red
#                       nir                                                    nir
#                       swir1                                                swir1
#                       swir2                                                swir2
# high_tide_comp_count  count_observations                      count_observations
# item_v2               relative                                          relative
# item_v2_conf          stddev                                              stddev
# low_tide_comp_20p     blue                                                  blue
#                       green                                                green
#                       red                                                    red
#                       nir                                                    nir
#                       swir1                                                swir1
# ...                                                                          ...
# s2b_ard_granule       nbart_nir_1                                    nbart_nir_1
#                       nbart_nir_2                                    nbart_nir_2
#                       nbart_swir_2                                  nbart_swir_2
#                       nbart_swir_3                                  nbart_swir_3
# s2b_level1c_granule   B01                                                    B01
#                       B02                                                    B02
#                       B03                                                    B03
#                       B04                                                    B04
#                       B05                                                    B05
#                       B06                                                    B06
#                       B07                                                    B07
#                       B08                                                    B08
#                       B8A                                                    B8A
#                       B09                                                    B09
#                       B10                                                    B10
#                       B11                                                    B11
#                       B12                                                    B12
# srtm_dem1sv1_0        dem                                                    dem
#                       dem_s                                                dem_s
#                       dem_h                                                dem_h
# urban_areas           band1                                                band1
# wofs_albers           water                                                water
# wofs_annual_summary   count_wet                                        count_wet
#                       count_clear                                    count_clear
#                       frequency                                        frequency
# wofs_filtered_summary confidence                                      confidence
#                       wofs_filtered_summary                wofs_filtered_summary
# wofs_summary          count_wet                                        count_wet
#                       count_clear                                    count_clear
#                       frequency                                        frequency
#
#                                                                                       nodata  \
# product               measurement
# bom_rainfall_grids    rainfall                                                          -999
# dsm                   elevation                                                          255
#                       slope                                                              255
# dsm1sv10              elevation                                                          NaN
# gamma_ray             rad_air_dose_rate_unfiltered                                    -99999
#                       rad_k_equiv_conc_unfiltered                                     -99999
#                       rad_u_equiv_conc_unfiltered                                     -99999
#                       rad_th_equiv_conc_unfiltered                                    -99999
#                       rad_air_dose_rate_filtered                                      -99999
#                       rad_k_equiv_conc_filtered                                       -99999
#                       rad_u_equiv_conc_filtered                                       -99999
#                       rad_th_equiv_conc_filtered                                      -99999
#                       rad_ratio_tk                                                    -99999
#                       rad_ratio_u2t                                                   -99999
#                       rad_ratio_uk                                                    -99999
#                       rad_ratio_ut                                                    -99999
# high_tide_comp_20p    blue                                                              -999
#                       green                                                             -999
#                       red                                                               -999
#                       nir                                                               -999
#                       swir1                                                             -999
#                       swir2                                                             -999
# high_tide_comp_count  count_observations                                                   0
# item_v2               relative                                                             0
# item_v2_conf          stddev                                                           -6666
# low_tide_comp_20p     blue                                                              -999
#                       green                                                             -999
#                       red                                                               -999
#                       nir                                                               -999
#                       swir1                                                             -999
# ...                                                                                      ...
# s2b_ard_granule       nbart_nir_1                                                       -999
#                       nbart_nir_2                                                       -999
#                       nbart_swir_2                                                      -999
#                       nbart_swir_3                                                      -999
# s2b_level1c_granule   B01                                                                  0
#                       B02                                                                  0
#                       B03                                                                  0
#                       B04                                                                  0
#                       B05                                                                  0
#                       B06                                                                  0
#                       B07                                                                  0
#                       B08                                                                  0
#                       B8A                                                                  0
#                       B09                                                                  0
#                       B10                                                                  0
#                       B11                                                                  0
#                       B12                                                                  0
# srtm_dem1sv1_0        dem                           -340282350000000000000000000000000000000
#                       dem_s                         -340282350000000000000000000000000000000
#                       dem_h                         -340282350000000000000000000000000000000
# urban_areas           band1                                                              255
# wofs_albers           water                                                                1
# wofs_annual_summary   count_wet                                                           -1
#                       count_clear                                                         -1
#                       frequency                                                           -1
# wofs_filtered_summary confidence                                                          -1
#                       wofs_filtered_summary                                               -1
# wofs_summary          count_wet                                                           -1
#                       count_clear                                                         -1
#                       frequency                                                           -1
#
#                                                    number  \
# product               measurement
# bom_rainfall_grids    rainfall                        NaN
# dsm                   elevation                       NaN
#                       slope                           NaN
# dsm1sv10              elevation                       NaN
# gamma_ray             rad_air_dose_rate_unfiltered    NaN
#                       rad_k_equiv_conc_unfiltered     NaN
#                       rad_u_equiv_conc_unfiltered     NaN
#                       rad_th_equiv_conc_unfiltered    NaN
#                       rad_air_dose_rate_filtered      NaN
#                       rad_k_equiv_conc_filtered       NaN
#                       rad_u_equiv_conc_filtered       NaN
#                       rad_th_equiv_conc_filtered      NaN
#                       rad_ratio_tk                    NaN
#                       rad_ratio_u2t                   NaN
#                       rad_ratio_uk                    NaN
#                       rad_ratio_ut                    NaN
# high_tide_comp_20p    blue                            NaN
#                       green                           NaN
#                       red                             NaN
#                       nir                             NaN
#                       swir1                           NaN
#                       swir2                           NaN
# high_tide_comp_count  count_observations              NaN
# item_v2               relative                        NaN
# item_v2_conf          stddev                          NaN
# low_tide_comp_20p     blue                            NaN
#                       green                           NaN
#                       red                             NaN
#                       nir                             NaN
#                       swir1                           NaN
# ...                                                   ...
# s2b_ard_granule       nbart_nir_1                     NaN
#                       nbart_nir_2                     NaN
#                       nbart_swir_2                    NaN
#                       nbart_swir_3                    NaN
# s2b_level1c_granule   B01                             NaN
#                       B02                             NaN
#                       B03                             NaN
#                       B04                             NaN
#                       B05                             NaN
#                       B06                             NaN
#                       B07                             NaN
#                       B08                             NaN
#                       B8A                             NaN
#                       B09                             NaN
#                       B10                             NaN
#                       B11                             NaN
#                       B12                             NaN
# srtm_dem1sv1_0        dem                             NaN
#                       dem_s                           NaN
#                       dem_h                           NaN
# urban_areas           band1                           NaN
# wofs_albers           water                           NaN
# wofs_annual_summary   count_wet                       NaN
#                       count_clear                     NaN
#                       frequency                       NaN
# wofs_filtered_summary confidence                      NaN
#                       wofs_filtered_summary           NaN
# wofs_summary          count_wet                       NaN
#                       count_clear                     NaN
#                       frequency                       NaN
#
#                                                                                   spectral_definition  \
# product               measurement
# bom_rainfall_grids    rainfall                                                                    NaN
# dsm                   elevation                                                                   NaN
#                       slope                                                                       NaN
# dsm1sv10              elevation                                                                   NaN
# gamma_ray             rad_air_dose_rate_unfiltered                                                NaN
#                       rad_k_equiv_conc_unfiltered                                                 NaN
#                       rad_u_equiv_conc_unfiltered                                                 NaN
#                       rad_th_equiv_conc_unfiltered                                                NaN
#                       rad_air_dose_rate_filtered                                                  NaN
#                       rad_k_equiv_conc_filtered                                                   NaN
#                       rad_u_equiv_conc_filtered                                                   NaN
#                       rad_th_equiv_conc_filtered                                                  NaN
#                       rad_ratio_tk                                                                NaN
#                       rad_ratio_u2t                                                               NaN
#                       rad_ratio_uk                                                                NaN
#                       rad_ratio_ut                                                                NaN
# high_tide_comp_20p    blue                                                                        NaN
#                       green                                                                       NaN
#                       red                                                                         NaN
#                       nir                                                                         NaN
#                       swir1                                                                       NaN
#                       swir2                                                                       NaN
# high_tide_comp_count  count_observations                                                          NaN
# item_v2               relative                                                                    NaN
# item_v2_conf          stddev                                                                      NaN
# low_tide_comp_20p     blue                                                                        NaN
#                       green                                                                       NaN
#                       red                                                                         NaN
#                       nir                                                                         NaN
#                       swir1                                                                       NaN
# ...                                                                                               ...
# s2b_ard_granule       nbart_nir_1                   {'response': [0.000386696, 0.003018401, 0.0166...
#                       nbart_nir_2                   {'response': [0.001661751, 0.01602581, 0.03225...
#                       nbart_swir_2                  {'response': [1.15e-05, 2.6996e-05, 8.1157e-05...
#                       nbart_swir_3                  {'response': [0.000227567, 0.000739283, 0.0016...
# s2b_level1c_granule   B01                           {'response': [0.015297, 0.067133, 0.19593, 0.3...
#                       B02                           {'response': [0.001206, 0.00204, 0.002623, 0.0...
#                       B03                           {'response': [0.00084, 0.016372, 0.037688, 0.0...
#                       B04                           {'response': [0.002584, 0.034529, 0.14997, 0.4...
#                       B05                           {'response': [0.001187, 0.04126, 0.167712, 0.4...
#                       B06                           {'response': [0.005331, 0.085006, 0.345714, 0....
#                       B07                           {'response': [0.001595, 0.014731, 0.067032, 0....
#                       B08                           {'response': [0.000451, 0.007614, 0.019072, 0....
#                       B8A                           {'response': [0.001651, 0.013242, 0.02471, 0.0...
#                       B09                           {'response': [0.018022, 0.065698, 0.184737, 0....
#                       B10                           {'response': [0.000238, 5.4e-05, 3.1e-05, 2.9e...
#                       B11                           {'response': [7e-06, 7e-06, 8e-06, 2.8e-05, 3....
#                       B12                           {'response': [0.000639, 0.001023, 0.002885, 0....
# srtm_dem1sv1_0        dem                                                                         NaN
#                       dem_s                                                                       NaN
#                       dem_h                                                                       NaN
# urban_areas           band1                                                                       NaN
# wofs_albers           water                                                                       NaN
# wofs_annual_summary   count_wet                                                                   NaN
#                       count_clear                                                                 NaN
#                       frequency                                                                   NaN
# wofs_filtered_summary confidence                                                                  NaN
#                       wofs_filtered_summary                                                       NaN
# wofs_summary          count_wet                                                                   NaN
#                       count_clear                                                                 NaN
#                       frequency                                                                   NaN
#
#                                                           units
# product               measurement
# bom_rainfall_grids    rainfall                               mm
# dsm                   elevation                               1
#                       slope                                   1
# dsm1sv10              elevation                           metre
# gamma_ray             rad_air_dose_rate_unfiltered         nG/h
#                       rad_k_equiv_conc_unfiltered            %K
#                       rad_u_equiv_conc_unfiltered           ppm
#                       rad_th_equiv_conc_unfiltered          ppm
#                       rad_air_dose_rate_filtered           nG/h
#                       rad_k_equiv_conc_filtered              %K
#                       rad_u_equiv_conc_filtered             ppm
#                       rad_th_equiv_conc_filtered            ppm
#                       rad_ratio_tk                      ppm / %
#                       rad_ratio_u2t                 ppm^2 / ppm
#                       rad_ratio_uk                      ppm / %
#                       rad_ratio_ut                    ppm / ppm
# high_tide_comp_20p    blue                                    1
#                       green                                   1
#                       red                                     1
#                       nir                                     1
#                       swir1                                   1
#                       swir2                                   1
# high_tide_comp_count  count_observations                      1
# item_v2               relative                              0.1
# item_v2_conf          stddev                                  1
# low_tide_comp_20p     blue                                    1
#                       green                                   1
#                       red                                     1
#                       nir                                     1
#                       swir1                                   1
# ...                                                         ...
# s2b_ard_granule       nbart_nir_1                             1
#                       nbart_nir_2                             1
#                       nbart_swir_2                            1
#                       nbart_swir_3                            1
# s2b_level1c_granule   B01                                     1
#                       B02                                     1
#                       B03                                     1
#                       B04                                     1
#                       B05                                     1
#                       B06                                     1
#                       B07                                     1
#                       B08                                     1
#                       B8A                                     1
#                       B09                                     1
#                       B10                                     1
#                       B11                                     1
#                       B12                                     1
# srtm_dem1sv1_0        dem                                 metre
#                       dem_s                               metre
#                       dem_h                               metre
# urban_areas           band1                                   1
# wofs_albers           water                                   1
# wofs_annual_summary   count_wet                               1
#                       count_clear                             1
#                       frequency                               1
# wofs_filtered_summary confidence                              1
#                       wofs_filtered_summary                   1
# wofs_summary          count_wet                               1
#                       count_clear                             1
#                       frequency                               1
#
# [363 rows x 8 columns]

# %%
# Load Sentinel
s2a_ds = dc.load(product='s2a_ard_granule', group_by='solar_day', 
                          measurements = ['nbart_swir_2', 'nbart_nir_1', 'nbart_green', 'fmask'], like=ls578_ds)

s2b_ds = dc.load(product='s2b_ard_granule', group_by='solar_day', 
                          measurements = ['nbart_swir_2', 'nbart_nir_1', 'nbart_green', 'fmask'], like=ls578_ds)

# %%
# Keep only cloud-free Sentinel 2A data
PQmask = s2a_ds.where(s2a_ds.fmask == 1)
threshold = s2a_ds.x.count() * s2a_ds.y.count() * (1.0 - sentinel_masked_prop)
KeepTimeMask = PQmask.nbart_green.isnull().sum(axis=(1, 2)) <= int(threshold)
s2a_ds = s2a_ds.where(KeepTimeMask).dropna(dim='time')

# Keep only cloud-free Sentinel 2B data
PQmask = s2b_ds.where(s2b_ds.fmask == 1)
threshold = s2b_ds.x.count() * s2b_ds.y.count() * (1.0 - sentinel_masked_prop)
KeepTimeMask = PQmask.nbart_green.isnull().sum(axis=(1, 2)) <= int(threshold)
s2b_ds = s2b_ds.where(KeepTimeMask).dropna(dim='time')
# Out:
# /g/data/v10/public/modules/dea/20181015/lib/python3.6/site-packages/datacube/api/query.py:93: FutureWarning: casting an xarray.Dataset to a boolean will change in xarray v0.11 to only include data variables, not coordinates. Cast the Dataset.variables property instead to preserve existing behavior in a forwards compatible manner.
#   if like:
# /g/data/v10/public/modules/dea/20181015/lib/python3.6/site-packages/datacube/api/query.py:93: FutureWarning: casting an xarray.Dataset to a boolean will change in xarray v0.11 to only include data variables, not coordinates. Cast the Dataset.variables property instead to preserve existing behavior in a forwards compatible manner.
#   if like:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-68639adf90d2> in <module>
#       7
#       8 # Keep only cloud-free Sentinel 2A data
# ----> 9 PQmask = s2a_ds.where(s2a_ds.pixel_quality == 1)
#      10 threshold = s2a_ds.x.count() * s2a_ds.y.count() * (1.0 - sentinel_masked_prop)
#      11 KeepTimeMask = PQmask.green.isnull().sum(axis=(1, 2)) <= int(threshold)
#
# /g/data/v10/public/modules/dea-env/20181015/lib/python3.6/site-packages/xarray/core/common.py in __getattr__(self, name)
#     175                     return source[name]
#     176         raise AttributeError("%r object has no attribute %r" %
# --> 177                              (type(self).__name__, name))
#     178
#     179     def __setattr__(self, name, value):
#
# AttributeError: 'Dataset' object has no attribute 'pixel_quality'

# %% [markdown]
# ## Import flow data
# This is used to plot a line on the right panel of the animation. Must be imported as a geopandas dataframe with a datetime index column

# %%
# Set area over which index values should be averaged
line_df = pd.read_csv('/g/data/r78/rt1527/dea-notebooks/Enviroflows/raw_data/macmarsh/FlowData.csv', index_col='Date', usecols=[0,1,2,3], parse_dates=True, dayfirst=True)

# Subset to time covered by datacube query
date_min, date_max = query['time']
line_df = line_df[(line_df.index >= date_min) & (line_df.index <= date_max)]

# Give informative name
# line_df['Max discharge (Ml/d)'] = line_df['mean'] * 2
line_df.rename(columns={'mean':'Mean discharge (Ml/d)'}, inplace=True)
line_df.plot()

# %% [markdown]
# ## Plot data as animation

# %%
# Combine into single dataset
#s2a_ds.rename({'nir1': 'nir'}, inplace=True)
#s2b_ds.rename({'nir1': 'nir'}, inplace=True)
combined_ds = xr.auto_combine([ls578_ds, s2a_ds, s2b_ds])
combined_ds = combined_ds.sortby('time')
combined_ds

# Create animation
DEAPlotting.animated_timeseriesline(ds=combined_ds, # .isel(time=[0,1,2,3,4,5]), 
                        df=line_df, 
                        output_path='{}_sentinel2.mp4'.format(study_area), 
                        bands=['swir1', 'nir', 'green'], 
                        interval=220, 
                        annotation_kwargs={'fontsize':17},
                        reflect_stand=4200)
