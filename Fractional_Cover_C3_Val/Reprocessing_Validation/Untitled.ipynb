# %%
import pandas as pd
import os
import sys

# %%
star_short=pd.read_csv('star_transects.csv', nrows=10)

# %%
star_short
# Out:
#                                               FID           site    obs_time  \
# 0  star_transects.fid--4082306b_169795d9ed3_-1028         tas006  2011-12-07
# 1  star_transects.fid--4082306b_169795d9ed3_-1027   sa_e_saal_23  2012-04-24
# 2  star_transects.fid--4082306b_169795d9ed3_-1026   sa_e_saal_1a  2011-05-12
# 3  star_transects.fid--4082306b_169795d9ed3_-1025   sa_w_saal_07  2011-04-15
# 4  star_transects.fid--4082306b_169795d9ed3_-1024         nsw035  2011-06-19
# 5  star_transects.fid--4082306b_169795d9ed3_-1023    wa_pilb_028  2011-08-25
# 6  star_transects.fid--4082306b_169795d9ed3_-1022       sa_aw_05  2012-12-02
# 7  star_transects.fid--4082306b_169795d9ed3_-1021  sa_w_saal_35a  2012-12-04
# 8  star_transects.fid--4082306b_169795d9ed3_-1020         nsw063  2012-04-20
# 9  star_transects.fid--4082306b_169795d9ed3_-101f     kal_wa_049  2011-05-30
#
#    longitude  latitude  live_basal_area  total_basal_area  persist  crust  \
# ...
