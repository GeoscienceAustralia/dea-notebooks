# %%
import sys
sys.path.insert(1, '../Tools/')
from dea_tools.app.wetlands_insight_tool import wit_app

wit_app()
# Out:
# <Client: 'tcp://127.0.0.1:43367' processes=1 threads=2, memory=12.21 GiB>
# wit_app(children=(GridspecLayout(children=(HTML(value='<h3><h3>Digital Earth Australia Wetlands Insight Tool</…
