# %% [markdown]
# # Get dam time history and flag for rainfall

# %%
# %pylab notebook

from datacube import Datacube
from datacube.utils import geometry
from datacube.storage import masking
import fiona
import rasterio.features
import numpy as np

dc = Datacube(app = 'Polygon drill')
dc_rf = Datacube(config='/g/data/r78/bom_grids/rainfall.conf')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Load in the shapefile of the dams

# %%
# shape_file = '/g/data/r78/cek156/dea-notebooks/Crop_mapping/OFS201617Edit.shp'
shape_file = '/g/data/r78/cek156/dea-notebooks/Dams/NewDam2014.shp'

with fiona.open(shape_file) as shapes:
        crs = geometry.CRS(shapes.crs_wkt)
        first_geometry = next(iter(shapes))['geometry']
        geom = geometry.Geometry(first_geometry, crs=crs)

# %%
## Set up the query, and load in all of the WOFS layers
query = {'geopolygon': geom}
WOFL = dc.load(product='wofs_albers', **query)

# %%
queryRain = {'geopolygon': geom,
            'time' : ('1988-01-01', '2018-07-01')}

rf_data = dc_rf.load(product = 'rainfall_grids_1901_2017',**queryRain)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-10e384523b81> in <module>()
#       2             'time' : ('1988-01-01', '2018-07-01')}
#       3
# ----> 4 rf_data = dc_rf.load(product = 'rainfall_grids_1901_2017',**queryRain)
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/api/core.py in load(self, product, measurements, output_crs, resolution, resampling, dask_chunks, like, fuse_func, align, datasets, use_threads, **query)
#     309                                 fuse_func=fuse_func,
#     310                                 dask_chunks=dask_chunks,
# --> 311                                 use_threads=use_threads)
#     312
#     313         return apply_aliases(result, datacube_product, measurements)
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/api/core.py in load_data(sources, geobox, measurements, fuse_func, dask_chunks, skip_broken_datasets, use_threads)
#     523
#     524         return Datacube.create_storage(OrderedDict((dim, sources.coords[dim]) for dim in sources.dims),
# --> 525                                        geobox, measurements, data_func, use_threads)
#     526
#     527     @staticmethod
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/api/core.py in create_storage(coords, geobox, measurements, data_func, use_threads)
#     438             results = pool.map(work_measurements, measurements, repeat(data_func))
#     439         else:
# --> 440             results = [data_func(a) for a in measurements]
#     441
#     442         for measurement in measurements:
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/api/core.py in <listcomp>(.0)
#     438             results = pool.map(work_measurements, measurements, repeat(data_func))
#     439         else:
# --> 440             results = [data_func(a) for a in measurements]
#     441
#     442         for measurement in measurements:
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/api/core.py in data_func(measurement)
#     499                     for index, datasets in numpy.ndenumerate(sources.values):
#     500                         _fuse_measurement(data[index], datasets, geobox, measurement, fuse_func=fuse_func,
# --> 501                                           skip_broken_datasets=skip_broken_datasets)
#     502                 else:
#     503                     def work_load_data(array_name, index, datasets):
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/api/core.py in _fuse_measurement(dest, datasets, geobox, measurement, skip_broken_datasets, fuse_func)
#     639                        resampling=measurement.get('resampling_method', 'nearest'),
#     640                        fuse_func=fuse_func,
# --> 641                        skip_broken_datasets=skip_broken_datasets)
#     642
#     643
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/storage/storage.py in reproject_and_fuse(datasources, destination, dst_transform, dst_projection, dst_nodata, resampling, fuse_func, skip_broken_datasets)
#     204     elif len(datasources) == 1:
#     205         with ignore_exceptions_if(skip_broken_datasets):
# --> 206             read_from_source(datasources[0], destination, dst_transform, dst_nodata, dst_projection, resampling)
#     207         return destination
#     208     else:
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/storage/storage.py in read_from_source(source, dest, dst_transform, dst_nodata, dst_projection, resampling)
#     144     :param numpy.ndarray dest: Data destination
#     145     """
# --> 146     with source.open() as src:
#     147         array_transform = ~src.transform * dst_transform
#     148         # if the CRS is the same use decimated reads if possible (NN or 1:1 scaling)
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/storage/storage.py in open(self)
#     329         try:
#     330             _LOG.debug("opening %s", self.filename)
# --> 331             with rasterio.open(self.filename) as src:
#     332                 override = False
#     333
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/rasterio/env.py in wrapper(*args, **kwds)
#     401             else:
#     402                 pass
# --> 403             return f(*args, **kwds)
#     404
#     405     return wrapper
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/rasterio/__init__.py in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, **kwargs)
#     215         # None.
#     216         if mode == 'r':
# --> 217             s = DatasetReader(path, driver=driver, **kwargs)
#     218         elif mode == 'r+':
#     219             s = get_writer_for_path(path)(path, mode, driver=driver, **kwargs)
#
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/rasterio/path.py in name(self)
#      98     path = attr.ib()
#      99
# --> 100     @property
#     101     def name(self):
#     102         """The unparsed path's original path"""
#
# KeyboardInterrupt:

# %% [markdown]
# ## Turn the rainfall into a flag
#
# The flag is `True` if there has been more than 2mm rainfall in the five days prior

# %%
rainflag = [False,False,False,False,False]
for i in range(5,len(rf_data.time)):
    FiveDayRainfallTotal = rf_data.rainfall[i-5:i].values.sum()
    if FiveDayRainfallTotal >= 2:
        rainflag.append(True)
    else:
        rainflag.append(False)

WOFL['rainFlag'] = rainflag

# %%
rainflag

# %%
# Make a mask based on the polygon (to remove extra data outside of the polygon)
mask = rasterio.features.geometry_mask([geom.to_crs(WOFL.geobox.crs) for geoms in [geom]],
                                       out_shape=WOFL.geobox.shape,
                                       transform=WOFL.geobox.affine,
                                       all_touched=False,
                                       invert=True)

# %%
## Work out how full the dam is at every time step
DamCapacity = []
DryObserved = []
InvalidObservations = []
for ix, times in enumerate(WOFL.time):
    # Grab the data for our timestep
    AllTheBitFlags = WOFL.water.isel(time = ix)
    # Find all the wet/dry pixels for that timestep
    WetPixels = masking.make_mask(AllTheBitFlags, wet=True)
    DryPixels = masking.make_mask(AllTheBitFlags, dry=True)
    # Apply the mask and count the number of observations
    MaskedAll = AllTheBitFlags.where(mask).count().item()
    MaskedWet = WetPixels.where(mask).sum().item()
    MaskedDry = DryPixels.where(mask).sum().item()
    # Turn our counts into percents
    try:
        WaterPercent = MaskedWet / MaskedAll * 100
        DryPercent = MaskedDry / MaskedAll * 100
        UnknownPercent = (MaskedAll - (MaskedWet + MaskedDry)) / MaskedAll *100
    except ZeroDivisionError:
        WaterPercent = 0.0
        DryPercent = 0.0
        UnknownPercent = 100.0
    # Append the percentages to a list for each timestep
    DamCapacity.append(WaterPercent)
    InvalidObservations.append(UnknownPercent)
    DryObserved.append(DryPercent)

# %%
## Filter out timesteps with less than 90% valid observations 
ValidMask = [i for i, x in enumerate(InvalidObservations) if x < 10]
ValidObs = WOFL.time[ValidMask].dropna(dim = 'time')
# RainFlag = WOFL.rainFlag[ValidMask].dropna(dim = 'rainFlag')
ValidCapacity = [DamCapacity[i] for i in ValidMask]

# %%
RainValue = RainFlag * ValidCapacity
RainValue = [np.nan if x == 0 else x for x in RainValue]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-44adfe4f469d> in <module>()
# ----> 1 RainValue = RainFlag * ValidCapacity
#       2 RainValue = [np.nan if x == 0 else x for x in RainValue]
#
# NameError: name 'RainFlag' is not defined

# %%
## Plot up the timeseries
fig = plt.figure(figsize=(10, 7)) 
plt.plot(ValidObs.time.values, ValidCapacity, '.-', color = 'royalblue', linewidth = 2)
#plt.plot(ValidObs.time.values, RainValue, '.--', color = 'k', linewidth = 3)
#plt.title('Dam ID : {0}, Surface Area = {1} m2'.format(polyName, polyArea))
plt.ylabel('Percentage of surface area classified as \'water\'')
plt.xlabel('Date of Landsat observation')
#savefig('{}_Timeseries.jpg'.format(polyName.replace(" ", "")))
# plt.close()
# Out:
# <img src="data:image/png;base64,..." width="999.75">
# Text(0.5,0,'Date of Landsat observation')

# %%
## Plot up the timeseries
fig = plt.figure(figsize=(10, 7)) 
plt.plot(ValidObs.time.values, [DamCapacity[i] for i in ValidMask], '.-', color = 'royalblue', linewidth = 2)
#plt.plot(ValidObs.time.values, RainValue, '.--', color = 'k', linewidth = 3)
plt.xlim(['2010-01-01', '2018-07-01'])
#plt.title('Dam ID : {0}, Surface Area = {1} m2'.format(polyName, polyArea))
plt.ylabel('Percentage of surface area classified as \'water\'')
plt.xlabel('Date of Landsat observation')
#savefig('{}_Timeseries_Zoom.jpg'.format(polyName.replace(" ", "")))
# Out:
# <img src="data:image/png;base64,..." width="999.75">
# Text(0.5,0,'Date of Landsat observation')
