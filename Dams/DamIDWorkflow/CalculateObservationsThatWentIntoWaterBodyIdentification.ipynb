# %% [markdown]
# ## Calculation of number of observations

# %%
# %pylab notebook

import xarray as xr
import pandas as pd
import glob
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
TimeseriesDir = '/g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/'

# %% [markdown]
# ## Get a list of all of the csv files

# %%
CSVFiles = glob.glob(f'{TimeseriesDir}/**/*.csv', recursive=True)

# %% [markdown]
# ## Open each file, then work out how many observations occur between 2000 and 2018

# %%
AllObs = []
for FileName in CSVFiles:
    TimeHistory = pd.read_csv(FileName)
    TimeHistory['Observation Date'] = pd.to_datetime(TimeHistory['Observation Date'])
    NumObs = len(TimeHistory[(TimeHistory['Observation Date'] > '2000-01-01') & (TimeHistory['Observation Date'] < '2019-01-01')])
    if NumObs < 30:
        print(FileName)
    AllObs.append(NumObs)
# Out:
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/0841/084146.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/0841/084138.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/0445/044595.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/0445/044594.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/0260/026039.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/0104/010428.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/1022/102287.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/1075/107501.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/1021/102130.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/1021/102134.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/1021/102133.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/1021/102128.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/0345/034535.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/0262/026278.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/0465/046539.csv
# /g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018NSWMDB/Timeseries/1018/101821.csv

# %%
AllObs.sort()

# %%
AllObsNP = np.array(AllObs)

# %%
AllObsNP.std()
# Out:
# 194.96702341385236

# %%
AllObs
# Out:
# [2,
#  2,
#  9,
#  9,
#  13,
#  13,
#  15,
#  19,
#  20,
#  21,
#  21,
#  21,
#  23,
#  26,
#  27,
#  29,
#  32,
#  32,
#  32,
#  33,
#  34,
#  35,
#  35,
#  36,
#  37,
#  37,
#  37,
#  37,
#  38,
#  39,
#  40,
#  40,
#  40,
#  42,
#  42,
#  43,
#  44,
#  44,
#  44,
#  46,
#  46,
#  47,
#  47,
#  47,
#  48,
#  48,
#  49,
#  49,
#  49,
#  50,
#  52,
#  52,
#  52,
#  53,
#  54,
#  54,
#  55,
#  55,
#  55,
#  55,
#  56,
#  58,
#  59,
#  60,
#  60,
#  60,
#  60,
#  60,
#  61,
#  61,
#  61,
#  61,
#  61,
#  63,
#  63,
#  63,
#  63,
#  63,
#  63,
#  64,
#  65,
#  65,
#  65,
#  66,
#  66,
#  66,
#  67,
#  67,
#  67,
#  67,
#  68,
#  68,
#  68,
#  69,
#  69,
#  69,
#  69,
#  69,
#  69,
#  69,
#  70,
#  70,
#  70,
#  70,
#  70,
#  70,
#  71,
#  71,
#  72,
#  72,
#  72,
#  72,
#  72,
#  72,
#  72,
#  73,
#  73,
#  73,
#  73,
#  73,
#  74,
#  74,
#  74,
#  74,
#  74,
#  74,
#  74,
#  75,
#  75,
#  75,
#  75,
#  75,
#  75,
#  76,
#  76,
#  76,
#  76,
#  77,
#  77,
#  77,
#  77,
#  77,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  79,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  82,
#  82,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  83,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  84,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  87,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  89,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  91,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  92,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  93,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  94,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  95,
#  96,
#  96,
#  96,
#  96,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  97,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  101,
#  101,
#  101,
#  101,
#  101,
#  101,
#  101,
#  101,
#  101,
#  101,
#  101,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  103,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  104,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  105,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  106,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  108,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  109,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  111,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  112,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  114,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  116,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  117,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  118,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  119,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  121,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  122,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  123,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  ...]
