# %% [markdown]
# # Water Level Snapshot - pick time

# %%
import subprocess
import glob
import geopandas as gp
import re
import pandas as pd
from dateutil.relativedelta import relativedelta

# %% [markdown]
# ## Set up the file paths, date to be extracted and output file names
#
# `Timeseries_dir` is the folder where all the .txt files are located from which the snapshot will be created.
#
# `Shapefile_to_append` is the shapefile which the snapshot will be added to as an attribute

# %%
#Timeseries_dir = '/g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018/Timeseries/'
Timeseries_dir = '/g/data/r78/vmn547/Dams/Timeseries_new/'
Shapefile_to_append = '/g/data/r78/vmn547/Dams/AllNSW2000to201810LatestSnapshot.shp'

SnapshotShp = gp.read_file(Shapefile_to_append)

# %% [markdown]
# ### Choose when you want the snapshot for
#
# Note that there is a filter built in here that excludes observations that are more than a month from the chosen date.

# %%
DateToExtractStr = '20181001'
DateToExtract = pd.to_datetime(DateToExtractStr, format='%Y%m%d')

# Create filter range which only includes observations of +/- 1 month
DateFilterA = DateToExtract + relativedelta(months=-1)
DateFilterB = DateToExtract + relativedelta(months=1)

# %% [markdown]
# ## Get a list of all of the files in the folder to loop through

# %%
TimeSeriesFiles = glob.glob(f'{Timeseries_dir}*.txt')

# %% [markdown]
# ## Loop through and extract the relevant date from all the .txt files

# %%
for file in TimeSeriesFiles:
    # Get the ID
    NameComponents = re.split('\.|/', file)  # Splitting on '.' and '/'
    PolyID = NameComponents[-2]
    PolyID = int(PolyID)
    try:
        AllObs = pd.read_csv(file, parse_dates=[
                             'Observation Date'], index_col='Observation Date')
        x = AllObs.iloc[AllObs.index.get_loc(DateToExtract, method='nearest')]
        if(x.name > DateFilterA and x.name < DateFilterB):
            ObsDate = str(x.name)
            Pct = float(x['Wet pixel percentage'])
            FindPolyIndex = SnapshotShp.where(
                SnapshotShp['ID'] == PolyID).dropna(how='all').index.values[0]
            SnapshotShp.loc[(FindPolyIndex, f'{DateToExtractStr}')] = ObsDate
            SnapshotShp.loc[(FindPolyIndex, f'PctArea{DateToExtractStr[2:4]}')] = Pct
        else:
            print(x.name, 'is out of snapshot range.')
    except:
        print(f'Bad {PolyID}')
        continue
# Out:
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-27 00:12:32.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-17 00:26:25 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-28 00:06:22 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-17 00:25:37 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-22 23:50:11 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-04-24 23:50:51.500000 is out of snapshot range.
# 2018-03-30 00:02:07 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-19 00:13:16.500000 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-04-07 23:56:15.500000 is out of snapshot range.
# 2018-08-28 00:07:58 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-22 23:56:47 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-05 00:01:59 is out of snapshot range.
# 2018-08-31 23:43:16 is out of snapshot range.
# 2018-08-31 23:44:04 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-04-12 00:21:59.500000 is out of snapshot range.
# 2018-08-17 00:25:37 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-17 00:26:49 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-14 23:49:15.500000 is out of snapshot range.
# 2018-08-13 23:55:53.500000 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-08-28 00:07:34 is out of snapshot range.
# 2018-03-31 23:50:08 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-04-06 00:09:02 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-04-08 23:51:08 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-05-03 23:44:30.500000 is out of snapshot range.
# 2018-08-28 00:06:22 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-28 00:07:58 is out of snapshot range.
# 2018-04-20 00:20:27 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-15 23:43:09 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-21 23:53:18.500000 is out of snapshot range.
# 2018-04-20 00:20:27 is out of snapshot range.
# 2018-02-04 23:44:22 is out of snapshot range.
# 2018-04-24 23:50:51.500000 is out of snapshot range.
# 2018-04-22 00:07:41 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-22 23:48:35 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-22 23:48:59 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-04-23 23:55:42 is out of snapshot range.
# 2018-08-28 00:07:34 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-05 00:01:59 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-22 23:48:59 is out of snapshot range.
# 2018-08-22 23:48:59 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-26 00:20:42.500000 is out of snapshot range.
# 2018-08-26 00:20:42.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-31 23:42:28 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-08-21 00:02:08 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-04-07 23:56:15.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-04-24 23:50:51.500000 is out of snapshot range.
# 2018-08-22 23:50:11 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-04-07 23:56:15.500000 is out of snapshot range.
# 2018-04-23 23:56:06 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-04-16 23:50:23 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2008-02-09 23:35:35 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-22 23:50:11 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-13 23:54:18 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-22 23:48:35 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-04-09 23:43:05 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-17 00:26:25 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-13 23:54:18 is out of snapshot range.
# 2018-08-05 00:01:59 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-23 23:41:42.500000 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-04-15 00:02:22 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-22 23:49:47 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-22 23:48:11 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-29 23:56:25 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-31 23:43:16 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-03-15 23:50:39 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-23 23:40:54.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-04-08 23:51:32 is out of snapshot range.
# 2018-08-31 23:43:16 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-13 23:54:18 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-04-23 23:56:06 is out of snapshot range.
# 2018-08-22 23:49:47 is out of snapshot range.
# 2018-08-21 00:02:08 is out of snapshot range.
# 2018-08-14 23:48:51.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-04-17 23:45:36.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-05-24 00:08:08 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-21 23:53:18.500000 is out of snapshot range.
# 2018-04-16 23:49:59 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-04-16 23:49:59 is out of snapshot range.
# 2018-08-17 00:25:37 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-23 23:42:06.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-23 23:42:30.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-26 00:19:54.500000 is out of snapshot range.
# 2018-08-22 23:48:59 is out of snapshot range.
# 2018-08-15 23:41:33 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:07:58 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-08-22 23:48:35 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-06 23:56:55 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-28 00:07:34 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-31 23:43:16 is out of snapshot range.
# 2018-08-23 23:42:06.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-23 23:42:06.500000 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-04-29 00:13:24 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-28 00:07:58 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-23 23:40:54.500000 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-04-06 00:08:38 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-15 23:43:09 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-21 00:00:32 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-23 23:40:54.500000 is out of snapshot range.
# 2018-08-31 23:42:28 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-22 23:48:59 is out of snapshot range.
# 2018-08-28 00:06:22 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-04-07 23:56:15.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-31 23:42:28 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-04-07 23:56:15.500000 is out of snapshot range.
# 2008-02-09 23:35:35 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-08-31 23:41:40 is out of snapshot range.
# 2018-08-05 00:01:59 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-04-24 23:50:51.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-04-22 00:07:41 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-14 23:48:27.500000 is out of snapshot range.
# 2018-08-23 23:42:06.500000 is out of snapshot range.
# 2018-04-24 23:50:27.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-04-08 23:51:08 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-31 23:44:28 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-28 00:07:34 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-31 23:42:04 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-31 23:44:04 is out of snapshot range.
# 2018-04-16 23:49:11 is out of snapshot range.
# 2018-08-22 23:49:47 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-28 00:06:22 is out of snapshot range.
# 2018-03-30 00:02:07 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-14 23:48:51.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-03-30 00:01:43 is out of snapshot range.
# 2018-05-03 23:44:30.500000 is out of snapshot range.
# 2018-08-28 00:07:58 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-02-28 23:45:53 is out of snapshot range.
# 2018-04-07 23:55:51.500000 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-31 23:44:04 is out of snapshot range.
# 2018-08-31 23:42:28 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-04-24 23:50:51.500000 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-28 00:06:22 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-08-18 00:19:42.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-05-03 23:44:30.500000 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-14 23:48:27.500000 is out of snapshot range.
# 2018-08-23 23:41:42.500000 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-04-23 23:56:06 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2008-02-09 23:35:11.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-22 23:48:59 is out of snapshot range.
# 2018-04-20 00:20:27 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-22 23:48:35 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-23 23:42:06.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-04-17 23:44:48.500000 is out of snapshot range.
# 2018-04-22 00:08:52.500000 is out of snapshot range.
# 2018-04-28 00:21:42.500000 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-31 23:43:16 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-31 23:42:28 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-22 23:48:59 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2008-02-09 23:34:47.500000 is out of snapshot range.
# 2018-05-01 00:02:37 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-17 00:25:13 is out of snapshot range.
# 2018-08-23 23:42:30.500000 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-04-17 23:45:12.500000 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-04-16 23:49:59 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-04-20 00:20:27 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-04-07 23:56:15.500000 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-23 23:40:54.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-04-07 23:55:51.500000 is out of snapshot range.
# 2018-08-13 23:54:18 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:07:34 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:07:58 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-30 00:02:55 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-23 23:42:30.500000 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-03-23 23:50:58.500000 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-04-28 00:21:42.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-14 23:48:51.500000 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-04-28 00:21:42.500000 is out of snapshot range.
# 2018-08-31 23:43:16 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-23 23:40:54.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-26 00:19:54.500000 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2008-02-09 23:34:47.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-21 23:54:54.500000 is out of snapshot range.
# 2018-08-28 00:07:34 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-22 23:48:59 is out of snapshot range.
# 2018-08-23 23:40:54.500000 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-26 00:20:42.500000 is out of snapshot range.
# 2018-04-07 23:56:39 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-21 00:00:32 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-30 00:02:07 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-30 00:02:55 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-26 00:19:54.500000 is out of snapshot range.
# 2018-08-23 23:40:54.500000 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-22 23:48:11 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-23 23:42:06.500000 is out of snapshot range.
# 2018-08-28 00:07:58 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-03-30 00:02:07 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-30 00:02:55 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-21 23:53:18.500000 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-15 23:41:57 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-31 23:44:04 is out of snapshot range.
# 2018-08-21 00:02:08 is out of snapshot range.
# 2018-08-21 00:02:08 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-30 23:47:44.500000 is out of snapshot range.
# 2018-03-30 00:02:07 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-05-01 00:02:37 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-21 23:53:18.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:06:22 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-14 23:48:51.500000 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-31 23:43:16 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-14 23:48:51.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-08-31 23:42:28 is out of snapshot range.
# 2018-04-28 00:21:42.500000 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-28 00:06:22 is out of snapshot range.
# 2018-03-30 00:02:55 is out of snapshot range.
# 2018-08-31 23:43:16 is out of snapshot range.
# 2018-08-12 00:07:26 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-22 23:56:47 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-22 23:48:35 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2007-08-17 23:37:28 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-22 23:48:35 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-04-22 00:08:52.500000 is out of snapshot range.
# 2018-08-31 23:43:16 is out of snapshot range.
# 2018-08-31 23:43:16 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-22 23:48:35 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-23 23:42:30.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-03-23 23:51:22.500000 is out of snapshot range.
# 2018-08-07 23:42:25 is out of snapshot range.
# 2018-04-20 00:20:27 is out of snapshot range.
# 2018-03-31 23:49:20.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-22 23:48:35 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-15 23:43:09 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2008-02-09 23:35:35 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-31 23:44:04 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-23 23:41:18.500000 is out of snapshot range.
# 2018-08-22 23:48:59 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-30 00:02:55 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-04-07 23:56:39 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-13 23:56:17.500000 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-04-16 23:49:59 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-26 00:19:54.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-02-10 23:58:25.500000 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-15 23:43:33 is out of snapshot range.
# 2018-08-28 00:07:58 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-15 23:41:33 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-31 23:41:40 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-04-16 23:49:35 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-04-16 23:50:23 is out of snapshot range.
# 2018-08-17 00:25:37 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-08-21 00:00:32 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-23 23:42:06.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-14 23:48:27.500000 is out of snapshot range.
# 2008-02-09 23:35:11.500000 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-15 23:41:57 is out of snapshot range.
# 2018-08-28 00:07:58 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-12 00:07:50 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-05-01 00:02:37 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-05-06 00:20:18.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-03-21 00:09:09.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-15 23:41:57 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-04-20 00:20:27 is out of snapshot range.
# 2018-08-21 00:00:32 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-03-30 00:01:43 is out of snapshot range.
# 2018-08-22 23:48:35 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-30 23:47:44.500000 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2007-08-17 23:37:28 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-26 00:19:54.500000 is out of snapshot range.
# 2018-03-31 23:50:08 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-31 23:43:16 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-22 23:48:11 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-07-30 23:43:00 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-04-22 00:07:17 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-31 23:49:44 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-04-07 23:55:27.500000 is out of snapshot range.
# 2018-08-22 23:48:11 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-05 00:02:23 is out of snapshot range.
# 2018-08-17 00:25:37 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-22 23:48:35 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-22 23:48:35 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-14 23:48:51.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-31 23:43:16 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-28 00:07:34 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-31 23:41:40 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-15 23:43:09 is out of snapshot range.
# 2018-08-26 00:19:54.500000 is out of snapshot range.
# 2018-08-23 23:42:06.500000 is out of snapshot range.
# 2018-08-31 23:44:04 is out of snapshot range.
# 2018-08-31 23:42:28 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-04-27 00:26:10.500000 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-22 23:48:59 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-14 23:48:51.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2007-08-17 23:37:51.500000 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-04-06 00:08:38 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-21 00:02:08 is out of snapshot range.
# 2018-08-07 23:42:49 is out of snapshot range.
# 2018-08-21 23:54:06.500000 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-25 00:25:44.500000 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-23 23:42:06.500000 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-28 00:06:22 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-04-24 23:50:51.500000 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-03-30 00:02:55 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-22 23:48:59 is out of snapshot range.
# 2018-05-02 23:49:02 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-21 00:02:08 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-23 23:43:18.500000 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-13 23:55:53.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-04-04 00:19:49 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2008-02-09 23:35:11.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-31 23:42:28 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-13 23:55:53.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-04-23 23:56:06 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-15 23:43:09 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-03-31 23:49:44 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-15 23:41:57 is out of snapshot range.
# 2018-04-28 00:21:42.500000 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-31 23:42:28 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-22 23:48:11 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# ...
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-22 23:48:59 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:07:58 is out of snapshot range.
# 2018-08-28 00:07:34 is out of snapshot range.
# 2018-08-23 23:41:42.500000 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-14 23:48:27.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-08-23 23:42:06.500000 is out of snapshot range.
# 2018-08-28 00:06:22 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2008-02-09 23:35:11.500000 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-04-01 23:44:40 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-23 23:42:06.500000 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-31 23:44:04 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-23 23:42:30.500000 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-23 23:40:54.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-04-15 00:02:22 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-31 23:41:40 is out of snapshot range.
# 2008-01-15 23:42:12.500000 is out of snapshot range.
# 2018-08-15 23:43:09 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-03-30 00:02:55 is out of snapshot range.
# 2018-08-22 23:48:35 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-04-23 23:56:06 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-15 23:41:57 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-04-28 00:21:42.500000 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-04-15 00:02:22 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-22 23:50:11 is out of snapshot range.
# 2018-04-24 23:50:51.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-15 23:43:09 is out of snapshot range.
# 2018-03-05 00:09:18 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-14 23:48:51.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-22 23:48:59 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-14 23:48:51.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-30 23:47:44.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-28 00:06:22 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-14 23:48:51.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-04-07 23:55:51.500000 is out of snapshot range.
# 2018-08-22 23:48:11 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-15 23:43:09 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-08-31 23:44:04 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-04-08 23:51:32 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-26 00:19:54.500000 is out of snapshot range.
# 2018-08-23 23:42:06.500000 is out of snapshot range.
# 2018-04-07 23:56:39 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-31 23:42:52 is out of snapshot range.
# 2018-08-27 00:11:45 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-14 23:48:51.500000 is out of snapshot range.
# 2018-08-22 23:48:11 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-04-07 23:56:15.500000 is out of snapshot range.
# 2018-04-22 00:08:28.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-14 23:49:15.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-22 23:50:11 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-23 23:41:18.500000 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-04-08 23:50:20.500000 is out of snapshot range.
# 2018-08-31 23:44:04 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-04-08 23:50:44.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-14 23:48:27.500000 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:06:22 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-14 23:48:51.500000 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-03-24 23:43:13 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-21 00:02:08 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-19 00:12:53 is out of snapshot range.
# 2018-02-11 23:49:43 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-08-15 23:43:09 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:08:21.500000 is out of snapshot range.
# 2018-08-17 00:25:37 is out of snapshot range.
# 2018-04-08 23:51:08 is out of snapshot range.
# 2018-04-06 00:09:02 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-12 00:07:50 is out of snapshot range.
# 2018-03-30 00:02:07 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-22 23:50:11 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-30 23:47:20.500000 is out of snapshot range.
# 2018-08-31 23:43:16 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-31 23:42:28 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-08-28 00:07:34 is out of snapshot range.
# 2018-04-23 23:56:06 is out of snapshot range.
# 2018-04-07 23:56:15.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-15 23:43:09 is out of snapshot range.
# 2018-08-22 23:48:35 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-04-22 00:08:28.500000 is out of snapshot range.
# 2018-08-22 23:49:47 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-14 23:49:15.500000 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2008-03-12 23:34:11 is out of snapshot range.
# 2018-08-29 23:55:37 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:09:09.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-31 23:42:28 is out of snapshot range.
# 2018-08-29 23:55:13 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-12 00:07:26 is out of snapshot range.
# 2018-08-31 23:44:04 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-15 23:43:09 is out of snapshot range.
# 2018-08-31 23:41:40 is out of snapshot range.
# 2018-08-30 23:46:56.500000 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-26 00:19:30.500000 is out of snapshot range.
# 2018-08-31 23:42:28 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-21 00:02:08 is out of snapshot range.
# 2018-08-30 23:47:44.500000 is out of snapshot range.
# 2018-08-05 00:01:59 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-31 23:49:44 is out of snapshot range.
# 2018-08-30 23:47:44.500000 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-12 00:07:26 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-29 23:54:49 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-29 23:56:01 is out of snapshot range.
# 2018-04-07 23:56:15.500000 is out of snapshot range.
# 2018-08-21 00:00:32 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-21 00:01:20 is out of snapshot range.
# 2018-05-02 23:49:26 is out of snapshot range.
# 2008-01-15 23:42:12.500000 is out of snapshot range.
# 2018-05-01 00:02:13 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-21 00:01:44 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-31 23:44:04 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-03-30 00:02:55 is out of snapshot range.
# 2018-08-31 23:44:04 is out of snapshot range.
# 2018-08-28 00:07:58 is out of snapshot range.
# 2018-08-28 00:07:10 is out of snapshot range.
# 2018-08-26 00:19:54.500000 is out of snapshot range.
# 2018-08-22 23:49:23 is out of snapshot range.
# 2018-08-26 00:20:18.500000 is out of snapshot range.
# 2018-08-31 23:43:40 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-31 23:44:28 is out of snapshot range.
# 2018-08-28 00:08:45.500000 is out of snapshot range.
# 2018-08-26 00:19:07 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-29 23:54:25 is out of snapshot range.
# 2018-08-21 00:00:56 is out of snapshot range.
# 2018-08-21 23:53:18.500000 is out of snapshot range.
# 2018-05-01 00:01:49 is out of snapshot range.
# 2018-08-23 23:42:30.500000 is out of snapshot range.
# 2018-03-30 00:02:31 is out of snapshot range.
# 2018-08-28 00:06:46 is out of snapshot range.
# 2018-08-26 00:20:42.500000 is out of snapshot range.

# %% [markdown]
# ## Write out the appended shapefile

# %%
schema = gp.io.file.infer_schema(SnapshotShp)
schema['properties'][f'{DateToExtractStr}'] = 'str'
schema['properties'][f'PctArea{DateToExtractStr[2:4]}'] = 'float' 
SnapshotShp.to_file(Shapefile_to_append, schema = schema)
