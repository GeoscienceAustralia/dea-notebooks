# %% [markdown]
# # Coregistration of two Sentinel-2 scenes with a Landsat-8 reference scene <img align="right" src="../Supplementary_data/dea_logo.jpg">
#
# * **[Sign up to the DEA Sandbox](https://app.sandbox.dea.ga.gov.au/)** to run this notebook interactively from a browser
# * **Compatibility:** Notebook currently compatible with `DEA Sandbox` environments
# * **Products used:**
# [landsat-c2l2-sr](https://landsatlook.usgs.gov/stac-server/collections/landsat-c2l2-sr)
# [sentinel-2-l2a](https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a)

# %% [markdown]
# ## Background
# Satellite image co-registration ensures the accurate geometric alignment of multi-temporal or multi-sensor images. It is critical for applications like change detection, data fusion, and displacement mapping. Co-registration of satellite images is a critical process in remote sensing, enabling accurate multi-temporal and multi-sensoral analysis. This process aligns images taken at different times or by different sensors to a common coordinate system, reducing misalignment caused by geometric errors. For more details on co-registration and its available tools please see the references below:
#
# [Satellite Image Co-Registration](https://geoscienceau.sharepoint.com/:b:/s/DEAnt/ERAjz6UbYLJGh20wvObq2YwBZ-QNrGk37Qz5ObjLQNJQfA?e=lKubfl)
#
# [Co-Registration Tools Comparison](https://geoscienceau.sharepoint.com/:b:/s/DEAnt/Efz-tYil3pVDv3nrvMIYBHoBlZbvUwKTc1aOOpVYPPX7Ig?e=0hMtWp)

# %% [markdown]
# ## Description
# This notebooks tests a optical images cor-registration of two Sentinel-2 target scenes with a Landsat-8 reference one, using three different tools and compares their results. `Co-register` , `Karios` and `AROSICS`. The first two are mainly based on Optical Flow tracking of the features in the scenes and the last one mainly uses Phase Correlation. `Co-register` is built in-house in GA and is compared with the other two.
#
# For more information about Karios ansd AROSICS, refer to the links below:
#
# [Karios](https://github.com/telespazio-tim/karios)
#
# [AROSICS](https://github.com/GFZ/arosics)
#
# 1. First we download and prepare the reference and target scenes.
# 2. Second, we run three different co-registration tools using the input scenes.
# 3. Finally we compare the results using the available metrics for image similarity.
#
# >**Note:**
# >* All parameters are default parameters, except for AROSICS, where the min reliability was dropped to 30%.
# >* Shifts are translation shifts only. Mean shifts (Average shifts in both x and y directions from all detected features) are used for final co-registration.
# ***

# %% [markdown]
# ## Getting started
#
# AROSICS and Karios should be installed in your environment.
#
# [AROSICS installation](https://danschef.git-pages.gfz-potsdam.de/arosics/doc/installation.html)
#
# For Karios, you can follow the link below:
#
# [Karios installation](https://github.com/telespazio-tim/karios?tab=readme-ov-file#installation)
#
# or you can just install from the main branch of the repo by running:
#
#
# ```pip install git+https://github.com/telespazio-tim/karios.git@main```
#
# **NOTE:** Karios requires Python 3.12 an above and given the current Python version on the Sandbox, we skip it for now.
#
#
# ### Installing the required packages

# %%
# required by AROSICS
# %pip install pykrige

# %%
# %pip install arosics

# %% [markdown]
# ### Load packages
# Import Python packages that are used for the analysis.

# %%
# %matplotlib inline

import glob
import os
import sys

import boto3
import cv2 as cv
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import planetary_computer
import rasterio as rio
from pystac_client import Client
from rasterio.plot import show
from skimage.exposure import rescale_intensity

sys.path.insert(1, "../Tools/")
from dea_tools.coreg import coreg, reproject_tif, stream_scene

# %% [markdown]
# ### Querying data using PyStac
#
# We use landsat-8 with scene id `LC08_L2SR_128111_20200228_02_T2` as the reference image and Sentinel-2 scenes with ids `S2B_42CVE_20250124_0_L2A`, `S2B_42CVE_20250110_0_L2A`, as target or monitored scenes to be co-registered with the reference scene. These scenes are all from the Amery ice shelf in Antarctica.
#
# Co-registration can be run on single bands or on multi-band images. For this test we use an averaged greyscale image of a RGB composite of the three visual bands, with contrast stretching as input image pre-enhancement step.

# %%
ref_ids = ["LC08_L2SR_128111_20200228_02_T2"]
tgt_ids = ["S2B_42CVE_20250124_0_L2A", "S2B_42CVE_20250110_0_L2A"]

# %% [markdown]
# ### Create input and outpur folders

# %%
input_dirs = "../dea_coreg/inputs"
output_dirs = "../dea_coreg/outputs"
os.makedirs(input_dirs, exist_ok=True)
os.makedirs(output_dirs, exist_ok=True)

# %% [markdown]
# ### Querying and downloading the scenes

# %%
# Planetary Computer assets are held in private Azure blobs. We need to sign the assets to access them. This is done via the right modifier passed to pystac client.
server_url = "https://planetarycomputer.microsoft.com/api/stac/v1"
query = {"ids": ref_ids, "collections": ["landsat-8-c2-l2"]}
client = Client.open(server_url, modifier=planetary_computer.sign_inplace)
search = client.search(**query)
ref_items = search.item_collection()
print(len(ref_items))
# Out:
# 1

# %% [markdown]
# Downloading the reference scene bands from the cloud using rasterio.
#
# Planetary Computer scenes are hosted on Azure. The Urls for them need to be signed before we can download them. We have already signed the assets in place when opening the pystac client.
#
# `stream_scene` function is defined in `tools.coregister` library , and it returns the data as a numpy array and its metadata. We can scale the data while streaming to reduce memory usage. Here we set the output resolution to 200.0 meters.

# %%
bands = ["SR_B4", "SR_B3", "SR_B2"]  # specifying the bands to be used for RGB composite in Planetary Computer Landsat-8 COGs
bands_data = []  # stores data for each band
for band in bands:
    band_url = ref_items[0].assets[band].href
    data = stream_scene(band_url, resolution=200.0, round_transform=False)
    bands_data.append(data)

# %%
# merging the bands into a single RGB image
bands_images = [np.nan_to_num(np.squeeze(datum[0])) for datum in bands_data]
composite_image = cv.merge(bands_images)

# %%
# plotting the composite image for inspection
plt.imshow(composite_image / composite_image.max())

# %% [markdown]
# ### Pre-processing
# We now create a grayscale image and apply contrast enhancement on it to create a more informative reference image.
# Karios and AROSICS work on a single band only (even if the input is a multi-band image), therefore we use the code below to create a grey reference image by averaging the bands in the true colour image. Please note, this is not the usual grayscale image that image processing tools such as OpenCV generate. The normal conversion is according NTSC formula which preserves the relationship between bands to align better with human perception.
# Also we stretch the contrast of the composite images. This will reveal more information about the features in the images, potentially.

# %%
# Creating a grayscale version of the reference image for use in registration
# using the 2nd and 98th percentiles to stretch the contrast for image enhancement
# and saving it to disk

grey_image = np.mean(composite_image, axis=2)
p2, p98 = np.percentile(grey_image, (0, 98))
ref_grey = rescale_intensity(grey_image, in_range=(p2, p98), out_range="uint8")
ref_profile = bands_data[0][1]["profile"]
ref_profile["dtype"] = "uint8"
with rio.open(f"{input_dirs}/ref_image.tif", "w", **ref_profile) as dst:
    dst.write(ref_grey, 1)

# %% [markdown]
# Downloading and processing the target scenes

# %%
server_url = "https://earth-search.aws.element84.com/v1"
query = {"ids": tgt_ids}
client = Client.open(server_url)
search = client.search(**query)
tgt_items = search.item_collection()
print(len(tgt_items))
# Out:
# 2

# %%
bands = ["red", "green", "blue"]  # specifying the bands to be used for RGB composite for Element 84 Sentinel-2 COGs
aws_session = rio.session.AWSSession(boto3.Session())
items_data = []
for item in tgt_items:
    print(item.id)
    bands_data = []
    for band in bands:
        band_url = item.assets[band].href
        data = stream_scene(
            band_url, aws_session=aws_session, resolution=200.0, round_transform=False
        )
        bands_data.append(data)
    items_data.append({"id": item.id, "bands": bands_data})
# Out:
# S2B_42CVE_20250124_0_L2A
# S2B_42CVE_20250110_0_L2A

# %%
tgt_composite_images = []
for idx, item_data in enumerate(items_data):
    bands_data = item_data["bands"]
    bands_images = [np.nan_to_num(np.squeeze(datum[0])) for datum in bands_data]
    composite_image = cv.merge(bands_images)
    tgt_composite_images.append(composite_image)

plt.imshow(tgt_composite_images[0] / tgt_composite_images[0].max())

# %% [markdown]
# Converting the targets to grayscale images and applying contrast enhancement.

# %%
## grayscale target images

tgt_greys = []
for idx, composite_image in enumerate(tgt_composite_images):
    grey_image = np.mean(composite_image, axis=2)
    p0, p98 = np.percentile(grey_image, (0, 98))
    tgt_image = rescale_intensity(grey_image, in_range=(p0, p98), out_range="uint8")
    tgt_greys.append(tgt_image)
    tgt_profile = items_data[idx]["bands"][0][1]["profile"]
    tgt_profile["dtype"] = "uint8"
    with rio.open(f"{input_dirs}/tgt_image_{idx}.tif", "w", **tgt_profile) as dst:
        dst.write(tgt_image, 1)

# %% [markdown]
# Plotting the reference and target images next to each  other

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 36), dpi=200)
show(
    rio.open(f"{input_dirs}/ref_image.tif"),
    ax=axes[0],
    title="Reference Image",
    cmap="gray",
)
for idx in range(len(tgt_greys)):
    show(
        rio.open(f"{input_dirs}/tgt_image_{idx}.tif"),
        ax=axes[idx + 1],
        title=f"Target Image {idx}",
        cmap="gray",
    )
plt.tight_layout()

# %%
# some data exploration using geopandas
gdf = gpd.GeoDataFrame.from_features(ref_items + tgt_items)
ids = [item.id for item in ref_items + tgt_items]
gdf["id"] = ids
gdf.plot(
    column="id",
    cmap="viridis",
    alpha=0.7,
    edgecolor="black",
    legend=True,
    figsize=(10, 10),
)
# Out:
# <Axes: >

# %% [markdown]
# ### Reading the file names into input variables

# %%
ref_file = f"{input_dirs}/ref_image.tif"
tgt_files = glob.glob(f"{input_dirs}/tgt_image_*.tif")

# %%
rio.open(ref_file).profile
# Out:
# {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': 0.0, 'width': 1071, 'height': 1084, 'count': 1, 'crs': CRS.from_epsg(3031), 'transform': Affine(200.0280112044818, 0.0, 1694985.0,
#        0.0, -200.11992619926198, 848415.0), 'blockxsize': 256, 'blockysize': 256, 'tiled': True, 'compress': 'deflate', 'interleave': 'band'}

# %% [markdown]
# ### Reprojecting targets
#
# Reference file has polar stereographic projection (Landsat-8), whereas the target Sentinel-2 files are in UTM coordinates. We must reproject the targets to the reference coordinate system.

# %%
# reproject_tif function from tools.coregister library reprojects a tif file to a specified CRS
ref_epsg = rio.open(
    ref_file
).crs.to_epsg()  # getting the EPSG code of the reference image
for i, tgt in enumerate(tgt_files):
    tgt_epsg = rio.open(tgt).crs.to_epsg()
    print(f"Target image {i} EPSG: {tgt_epsg}")
    if tgt_epsg != ref_epsg:
        reproj_dir = os.path.join(input_dirs, "reprojected")
        os.makedirs(reproj_dir, exist_ok=True)
        print(f"Reprojecting target image {i} to match reference EPSG {ref_epsg}...")
        reprojected_tgt = os.path.join(reproj_dir, os.path.basename(tgt))
        reproject_tif(tgt, reprojected_tgt, rio.open(ref_file).crs)
        tgt_files[i] = reprojected_tgt
# Out:
# Target image 0 EPSG: 32742
# Reprojecting target image 0 to match reference EPSG 3031...
# reprojecting from EPSG:32742 to EPSG:3031
# saving - ../dea_coreg/inputs/reprojected/tgt_image_0.tif
# Target image 1 EPSG: 32742
# Reprojecting target image 1 to match reference EPSG 3031...
# reprojecting from EPSG:32742 to EPSG:3031
# saving - ../dea_coreg/inputs/reprojected/tgt_image_1.tif

# %% [markdown]
# ## Running Co-Registration tools
#
# We will run `co-register`, `karios` and `arosics` functions from the `tools.coregister` library.

# %% [markdown]
# ### Co-Register

# %%
output_dir = f"{output_dirs}/Co_Register"
shifts, target_ids = coreg(
    ref_file,
    tgt_files,
    output_dir,
    method="co_register",
)
print("\nCo-register shifts:")
for i, shift in enumerate(shifts):
    print(
        f"Target {target_ids[i]}: {tuple([np.round(el.tolist(), 3).tolist() for el in shift])} pixels"
    )
# Out:
# Using overlapping regions of the reference and target images.
# For target 0 (tgt_image_0.tif), found 131 initial features.
# Filtering features based on distance...
# Applying RANSAC filter....
# Applying phase correlation filter...
# WARNING: 7 points were found with the given correlation threshold (fewer than accepted 10), turning off phase correlation filter...
# For target 0 (tgt_image_0.tif), Num features: 80
# For target 0 (tgt_image_0.tif), shifts => x: -0.2351184309471234, y: -0.7220394103715346 pixels.
#
# For target 1 (tgt_image_1.tif), found 128 initial features.
# Filtering features based on distance...
# Applying RANSAC filter....
# Applying phase correlation filter...
# WARNING: 3 points were found with the given correlation threshold (fewer than accepted 10), turning off phase correlation filter...
# For target 1 (tgt_image_1.tif), Num features: 61
# For target 1 (tgt_image_1.tif), shifts => x: -0.05277065700262545, y: -0.5380266880876331 pixels.
#
# Ground resolutions are different for datasets. The mosaicing process might fail if adding large datasets.
#               Please use `resolution_adjustment` flag first if you encounter memory related issues.
# Ground resolutions are different for datasets. The mosaicing process might fail if adding large datasets.
#               Please use `resolution_adjustment` flag first if you encounter memory related issues.
# Run time: 0.9173998832702637 seconds
# Total time: 4.018897533416748 seconds
#
# Co-register shifts:
# Target 0: (-0.235, -0.722) pixels
# Target 1: (-0.053, -0.538) pixels

# %% [markdown]
# ### Karios

# %%
# KARIOS requires Python 3.12 and above

# output_dir = f"{output_dirs}/Karios"
# shifts, target_ids = coreg(
#     ref_file,
#     tgt_files,
#     output_dir,
#     method="Karios",
# )
# print("\nKarios shifts:")
# for i, shift in enumerate(shifts):
#     print(
#         f"Target {target_ids[i]}: {tuple([np.round(el, 3).tolist() for el in shifts[shift]])} pixels"
#     )

# %% [markdown]
# ### AROSICS

# %%
output_dir = f"{output_dirs}/Arosics"
shifts, target_ids = coreg(
    ref_file,
    tgt_files,
    output_dir,
    method="AROSICS",
    grid_res=50,
)
print("\nAROSICS shifts:")
for i, shift in enumerate(shifts):
    print(
        f"Target {target_ids[i]}: {tuple([np.round(el.tolist(), 3).tolist() for el in shift])} pixels"
    )
# Out:
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:00
# Polygonize progress     |==================================================| 99.1% Complete  => 0:00:00
# Reference image: ../dea_coreg/inputs/ref_image.tif
# Coregistering ../dea_coreg/inputs/reprojected/tgt_image_0.tif
# Calculating footprint polygon and actual data corner coordinates for reference image...
# Bounding box of calculated footprint for reference image:
# 	(1695385.056022409, 634486.7988929889, 1909014.9719887956, 846413.8007380074)
# Calculating footprint polygon and actual data corner coordinates for image to be shifted...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:00
# Warping progress     |==================================================| 100.0% Complete  => 0:00:00
# Warping progress     |================================------------------| 63.8% Complete  => 0:00:00
# Bounding box of calculated footprint for image to be shifted:
# 	(1692255.5640388196, 654386.6967493036, 1833481.1200132237, 795612.2527237076)
# Matching window position (X,Y): 1764200.535461941/724409.0579148728
# Initializing tie points grid...
# Equalizing pixel grids and projections of reference and target image...
# Warping progress     |==================================================| 100.0% Complete  => 0:00:00
# 	progress: |==------------------------------------------------| 4.2% Complete  => 0:00:00
# Calculating tie point grid (118 points) using 64 CPU cores...
# 	progress: |==================================================| 100.0% Complete  => 0:00:01
# Found 100 matches.
# Performing validity checks...
# 17 tie points flagged by level 1 filtering (reliability).
# 21 tie points flagged by level 2 filtering (SSIM).
# /env/lib/python3.10/site-packages/arosics/DeShifter.py:289: UserWarning:
# The coordinate grid of tgt_image_0 cannot be aligned to the desired grid because their pixel sizes are not exact multiples of each other (input [X/Y]: 199.18978275656417/199.18978275656417; desired [X/Y]: 200.028011204442/200.11992619931698). Therefore the original grid is chosen for the resampled output image. If you don´t like that you can use the 'out_gsd' or 'match_gsd' parameters to set an appropriate output pixel size or to allow changing the pixel size.
#
#   warnings.warn(f"\nThe coordinate grid of {self.im2shift.basename} cannot be aligned to the desired "
# Translating progress |==================================================| 100.0% Complete  => 0:00:00
# Warping progress     |==================================================| 100.0% Complete  => 0:00:00
# Polygonize progress     |=================================================-| 97.0% Complete  => 0:00:00
# 14 tie points flagged by level 3 filtering (RANSAC)
# 55 valid tie points remain after filtering.
# Correcting geometric shifts...
# Writing GeoArray of size (710, 710) to ../dea_coreg/outputs/Arosics/Aligned/tgt_image_0.tif.
# Coregistering ../dea_coreg/inputs/reprojected/tgt_image_1.tif
# Calculating footprint polygon and actual data corner coordinates for reference image...
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:00
# Polygonize progress     |==================================================| 100.0% Complete  => 0:00:00
# Warping progress     |==============================--------------------| 59.3% Complete  => 0:00:00
# Bounding box of calculated footprint for reference image:
# 	(1695385.056022409, 634486.7988929889, 1909014.9719887956, 846413.8007380074)
# Calculating footprint polygon and actual data corner coordinates for image to be shifted...
# Bounding box of calculated footprint for image to be shifted:
# 	(1692255.5640388196, 672313.7771973944, 1833481.1200132237, 795612.2527237076)
# Matching window position (X,Y): 1765347.5156811192/727655.3140471694
# Initializing tie points grid...
# Equalizing pixel grids and projections of reference and target image...
# Warping progress     |==================================================| 100.0% Complete  => 0:00:00
# Warping progress     |==================================================| 100.0% Complete  => 0:00:00
# 	progress: |===-----------------------------------------------| 5.4% Complete  => 0:00:00
# Calculating tie point grid (112 points) using 64 CPU cores...
# 	progress: |==================================================| 100.0% Complete  => 0:00:01
# Found 89 matches.
# Performing validity checks...
# 15 tie points flagged by level 1 filtering (reliability).
# 17 tie points flagged by level 2 filtering (SSIM).
# /env/lib/python3.10/site-packages/arosics/DeShifter.py:289: UserWarning:
# The coordinate grid of tgt_image_1 cannot be aligned to the desired grid because their pixel sizes are not exact multiples of each other (input [X/Y]: 199.18978275656417/199.18978275656417; desired [X/Y]: 200.028011204442/200.11992619931698). Therefore the original grid is chosen for the resampled output image. If you don´t like that you can use the 'out_gsd' or 'match_gsd' parameters to set an appropriate output pixel size or to allow changing the pixel size.
#
#   warnings.warn(f"\nThe coordinate grid of {self.im2shift.basename} cannot be aligned to the desired "
# Translating progress |==================================================| 100.0% Complete  => 0:00:00
# Warping progress     |==================================================| 100.0% Complete  => 0:00:00
# 14 tie points flagged by level 3 filtering (RANSAC)
# 48 valid tie points remain after filtering.
# Correcting geometric shifts...
# Writing GeoArray of size (710, 710) to ../dea_coreg/outputs/Arosics/Aligned/tgt_image_1.tif.
# Ground resolutions are different for datasets. The mosaicing process might fail if adding large datasets.
#               Please use `resolution_adjustment` flag first if you encounter memory related issues.
# Ground resolutions are different for datasets. The mosaicing process might fail if adding large datasets.
#               Please use `resolution_adjustment` flag first if you encounter memory related issues.
# Run time: 36.2231867313385 seconds
# Total time: 39.431771755218506 seconds
#
# AROSICS shifts:
# Target 0: (-0.149, -0.008) pixels
# Target 1: (-0.163, -0.014) pixels

# %% [markdown]
# ### Comparing Results
#
# Output gifs are generated in the outputs folder under each tool's name. `outputs_raw.gif` is the file generated from the raw inputs before co-registration. `outputs.gif` is the final gif generated after co-registration. `output.csv` is the generated csv file for the performance metrics and other reported values.

# %% [markdown]
# #### Results table
#
# SSIM (Structural Similarity Index), MSE (Mean Squared Error), and ZNCC (Zero-mean Normalised Cross-Correlation) are the used metrics for assessing image quality and similarity. SSIM evaluates perceived changes in structural information between two images, providing a value between 0 and 1, where 1 indicates identical images. MSE measures the average squared difference between corresponding pixel values, with lower values signifying higher similarity. ZNCC assesses the correlation between two images after removing their mean values, with results close to 1 indicating strong similarity and values near 0 or negative suggesting weak or inverse relationships. A good point about ZNCC is that it is invariant to affine changes in image intensity (brightness offset and scale)

# %%
# output_subdirs = ["Co_Register", "Karios", "Arosics"]
output_subdirs = ["Co_Register", "Arosics"]
output_pd = pd.DataFrame({"Title": ["target 0", "target 1"]})
for i, output_subdir in enumerate(output_subdirs):
    output_csv = f"{output_dirs}/{output_subdir}/output.csv"
    temp_pd = pd.read_csv(output_csv)
    if i == 0:
        output_pd["SSIM Raw"] = temp_pd["SSIM Raw"]
        output_pd["MSE Raw"] = temp_pd["MSE Raw"]
        output_pd["ZNCC Raw"] = temp_pd["ZNCC Raw"]
    output_pd[f"{output_subdir} SSIM"] = temp_pd["SSIM Aligned"]
    output_pd[f"{output_subdir} MSE"] = temp_pd["MSE Aligned"]
    output_pd[f"{output_subdir} ZNCC"] = temp_pd["ZNCC Aligned"]
    output_pd[f"{output_subdir} Shifts"] = temp_pd["Shifts"]
display(output_pd)
# Out:
#       Title  SSIM Raw    MSE Raw  ZNCC Raw  Co_Register SSIM  Co_Register MSE  \
# 0  target 0     0.481  18014.167     0.196             0.486        17990.634
# 1  target 1     0.468  19767.866     0.149             0.472        19738.461
#
#    Co_Register ZNCC Co_Register Shifts  Arosics SSIM  Arosics MSE  \
# 0             0.197   (-0.235, -0.722)         0.481    18034.632
# 1             0.150   (-0.053, -0.538)         0.470    19709.436
#
#    Arosics ZNCC    Arosics Shifts
# 0         0.196  (-0.149, -0.008)
# 1         0.150  (-0.163, -0.014)

# %% [markdown]
# ### Results plots

# %%
shifts_pd = output_pd.copy()[
    ["Title"] + [f"{subdir} Shifts" for subdir in output_subdirs]
]
for subdir in output_subdirs:
    shifts_pd[f"{subdir} Shifts x"] = shifts_pd[f"{subdir} Shifts"].apply(
        lambda x: float(x.split(",")[0].replace("(", "").strip())
    )
    shifts_pd[f"{subdir} Shifts y"] = shifts_pd[f"{subdir} Shifts"].apply(
        lambda x: float(x.split(",")[1].replace(")", "").strip())
    )
shifts_pd.drop(columns=[f"{subdir} Shifts" for subdir in output_subdirs], inplace=True)
shifts_pd[["Title"] + [f"{subdir} Shifts x" for subdir in output_subdirs]].plot(
    kind="bar", x="Title", figsize=(10, 6), title="Shifts in x in pixels"
)
shifts_pd[["Title"] + [f"{subdir} Shifts y" for subdir in output_subdirs]].plot(
    kind="bar", x="Title", figsize=(10, 6), title="Shifts in y in pixels"
)
# Out:
# <Axes: title={'center': 'Shifts in y in pixels'}, xlabel='Title'>

# %% [markdown]
# ***
#
# ## Additional information
#
# **License:** The code in this notebook is licensed under the [Apache License, Version 2.0](https://www.apache.org/licenses/LICENSE-2.0).
# Digital Earth Australia data is licensed under the [Creative Commons by Attribution 4.0](https://creativecommons.org/licenses/by/4.0/) license.
#
# **Contact:** If you need assistance, please post a question on the [Open Data Cube Discord chat](https://discord.com/invite/4hhBQVas5U) or on the [GIS Stack Exchange](https://gis.stackexchange.com/questions/ask?tags=open-data-cube) using the `open-data-cube` tag (you can view previously asked questions [here](https://gis.stackexchange.com/questions/tagged/open-data-cube)).
# If you would like to report an issue with this notebook, you can file one on [GitHub](https://github.com/GeoscienceAustralia/dea-notebooks).
#
# **Last modified:** September 2025

# %% [markdown]
# ## Tags
# <!-- Browse all available tags on the DEA User Guide's [Tags Index](https://knowledge.dea.ga.gov.au/genindex/) -->

# %% [raw]
# **Tags**: :index:`co-register`, :index:`arosics`, :index:`sandbox compatible`,
