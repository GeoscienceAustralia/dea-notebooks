# %%
from datacube import Datacube
from datacube.storage.masking import mask_invalid_data
# %matplotlib inline

# %%
dc = Datacube(config='/g/data/u46/users/dra547/modis_oc.conf')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     790         if not fairy:
# --> 791             fairy = _ConnectionRecord.checkout(pool)
#     792
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1195                 with util.safe_reraise():
# -> 1196                     self._dec_overflow()
#    1197         else:
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1192             try:
# -> 1193                 return self._create_connection()
#    1194             except:
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     673             self.starttime = time.time()
# --> 674             connection = pool._invoke_creator(self)
#     675             pool.logger.debug("Created new connection %r", connection)
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#
# OperationalError: ERROR:  no such user
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-4148ebe1fd84> in <module>()
# ----> 1 dc = Datacube(config='/g/data/u46/users/dra547/modis_oc.conf')
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/api/core.py in __init__(self, index, config, app, env, validate_connection)
#      92             index = index_connect(normalise_config(config),
#      93                                   application_name=app,
# ---> 94                                   validate_connection=validate_connection)
#      95
#      96         self.index = index
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/index/_api.py in index_connect(local_config, application_name, validate_connection)
#      42     return index_driver.connect_to_index(local_config,
#      43                                          application_name=application_name,
# ---> 44                                          validate_connection=validate_connection)
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/index/index.py in connect_to_index(config, application_name, validate_connection)
#      90     @staticmethod
#      91     def connect_to_index(config, application_name=None, validate_connection=True):
# ---> 92         return Index.from_config(config, application_name, validate_connection)
#      93
#      94
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/index/index.py in from_config(cls, config, application_name, validate_connection)
#      53     def from_config(cls, config, application_name=None, validate_connection=True):
#      54         db = PostgresDb.from_config(config, application_name=application_name,
# ---> 55                                     validate_connection=validate_connection)
#      56         return cls(db)
#      57
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/drivers/postgres/_connections.py in from_config(cls, config, application_name, validate_connection)
#      74             application_name=app_name,
#      75             validate=validate_connection,
# ---> 76             pool_timeout=int(config.get('db_connection_timeout', 60))
#      77         )
#      78
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/drivers/postgres/_connections.py in create(cls, hostname, database, username, password, port, application_name, validate, pool_timeout)
#      89             pool_timeout=pool_timeout)
#      90         if validate:
# ---> 91             if not _core.database_exists(engine):
#      92                 raise IndexSetupError('\n\nNo DB schema exists. Have you run init?\n\t{init_command}'.format(
#      93                     init_command='datacube system init'
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/drivers/postgres/_core.py in database_exists(engine)
#     116     Have they init'd this database?
#     117     """
# --> 118     return has_schema(engine, engine)
#     119
#     120
#
# /g/data/v10/public/modules/dea/20180815/lib/python3.6/site-packages/datacube/drivers/postgres/_core.py in has_schema(engine, connection)
#     217
#     218 def has_schema(engine, connection):
# --> 219     return engine.dialect.has_schema(connection, SCHEMA_NAME)
#     220
#     221
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/dialects/postgresql/base.py in has_schema(self, connection, schema)
#    2321                     sql.bindparam(
#    2322                         'schema', util.text_type(schema.lower()),
# -> 2323                         type_=sqltypes.Unicode)]
#    2324             )
#    2325         )
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2072         """
#    2073
# -> 2074         connection = self.contextual_connect(close_with_result=True)
#    2075         return connection.execute(statement, *multiparams, **params)
#    2076
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/engine/base.py in contextual_connect(self, close_with_result, **kwargs)
#    2121         return self._connection_cls(
#    2122             self,
# -> 2123             self._wrap_pool_connect(self.pool.connect, None),
#    2124             close_with_result=close_with_result,
#    2125             **kwargs)
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in connect(self)
#     401         """
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#     405         try:
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     789     def _checkout(cls, pool, threadconns=None, fairy=None):
#     790         if not fairy:
# --> 791             fairy = _ConnectionRecord.checkout(pool)
#     792
#     793             fairy._pool = pool
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     530     @classmethod
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#     534             dbapi_connection = rec.get_connection()
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1194             except:
#    1195                 with util.safe_reraise():
# -> 1196                     self._dec_overflow()
#    1197         else:
#    1198             return self._do_get()
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     247         if value.__traceback__ is not tb:
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#     251 else:
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1191         if self._inc_overflow():
#    1192             try:
# -> 1193                 return self._create_connection()
#    1194             except:
#    1195                 with util.safe_reraise():
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     348         """Called by subclasses to create a new ConnectionRecord."""
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#     352     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     475         self.__pool = pool
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#     479
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     672         try:
#     673             self.starttime = time.time()
# --> 674             connection = pool._invoke_creator(self)
#     675             pool.logger.debug("Created new connection %r", connection)
#     676             self.connection = connection
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     410
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#     414     def create_connect_args(self, url):
#
# /g/data/v10/public/modules/dea-env/20180728/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     128
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#     132         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) ERROR:  no such user
#  (Background on this error at: http://sqlalche.me/e/e3q8)
