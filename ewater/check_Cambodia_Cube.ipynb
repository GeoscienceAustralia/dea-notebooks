# %%
# %pylab notebook

from datacube import Datacube
# from matplotlib import pyplot as plt
import numpy as np
# from skimage import exposure
# import pickle
#from rasterio import *
from datacube_stats.statistics import GeoMedian
cdc = Datacube(config='/g/data/u46/users/ext547/ewater/cambodia_cube/cambodia.conf')
from datacube.storage import masking
from datacube.storage.masking import mask_to_dict
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cdc.list_products()##
# Out:
#                            name  \
# id
# 17              alos_fnf_mosaic
# 16              alos_sar_mosaic
# 10          dem_3sec_hydrosheds
# 6             ls5_usgs_sr_scene
# 2             ls7_usgs_sr_scene
# 1             ls8_usgs_sr_scene
# 5    ls_level2_geomedian_annual
# 9           pet_grids_1979_2016
# 18               rainfall_grids
# 20                   spei_grids
# 8   temperature_grids_1979_2016
# 11         wofs_grids_1987_2017
#
#                                           description   lat   format label  \
# id
# 17  PALSAR-2/PALSAR/JERS-1 Mosaic and Forest/Non-F...  None   NETCDF  None
# 16  PALSAR-2/PALSAR/JERS-1 Mosaic and Forest/Non-F...  None   NETCDF  None
# 10  three sec hydrologically conditioned Digital E...  None   NETCDF  None
# 6   Landsat 5 USGS Collection 1 Level2 Surface Ref...  None  GeoTiff  None
# 2   Landsat 7 USGS Collection 1 Level2 Surface Ref...  None  GeoTiff  None
# 1   Landsat 8 USGS Collection 1 Level2 Surface Ref...  None  GeoTiff  None
# 5                    Landsat Level-2 Annual GeoMedian  None  GeoTiff  None
# 9   Daily potential evapo-transpiration (PET) for ...  None   NETCDF  None
# 18  bias corrected rainfall data for Cambodia prov...  None   NETCDF  None
# 20  The Standardised Precipitation-Evapotranspirat...  None   NETCDF  None
# 8   Near surface air temperature at 2 m at three h...  None   NETCDF  None
# 11  Water Observations from Space (WOfS) for Cambo...  None  GeoTiff  None
#
#           instrument  time creation_time  \
# id
# 17  PALSAR, PALSAR-2  None          None
# 16  PALSAR, PALSAR-2  None          None
# 10     shuttle radar  None          None
# 6                 TM  None          None
# 2                ETM  None          None
# 1           OLI_TIRS  None          None
# 5    TM,ETM,OLI_TIRS  None          None
# 9           modelled  None          None
# 18        rain gauge  None          None
# 20          modelled  None          None
# 8           modelled  None          None
# 11              None  None          None
#
#                                product_type   lon  \
# id
# 17                                  SAR_fnf  None
# 16                                      SAR  None
# 10                                elevation  None
# 6                                    LEDAPS  None
# 2                                    LEDAPS  None
# 1                                     LaSRC  None
# 5   surface_reflectance_statistical_summary  None
# 9                                       PET  None
# 18                                 rainfall  None
# 20                                     spei  None
# 8                               temperature  None
# 11     water_classifier_statistical_summary  None
#
#                          platform  \
# id
# 17                           ALOS
# 16                           ALOS
# 10                      elevation
# 6                       LANDSAT_5
# 2                       LANDSAT_7
# 1                       LANDSAT_8
# 5   LANDSAT_5,LANDSAT_7,LANDSAT_8
# 9                             PET
# 18                           rain
# 20                           spei
# 8                     temperature
# 11                           None
#
#                                                   crs  \
# id
# 17                                          EPSG:4326
# 16                                          EPSG:4326
# 10                                          EPSG:4326
# 6   PROJCS["WGS 84",GEOGCS["WGS 84",DATUM["WGS_198...
# 2   PROJCS["WGS 84",GEOGCS["WGS 84",DATUM["WGS_198...
# 1   PROJCS["WGS 84",GEOGCS["WGS 84",DATUM["WGS_198...
# 5                                          EPSG:32648
# 9                                           EPSG:4326
# 18                                          EPSG:4326
# 20                                          EPSG:4326
# 8                                           EPSG:4326
# 11                                         EPSG:32648
#
#                                  resolution           tile_size  \
# id
# 17  (-0.000222222222222, 0.000222222222222)                None
# 16  (-0.000222222222222, 0.000222222222222)                None
# 10                      (-0.00083, 0.00083)                None
# 6                                 (-30, 30)                None
# 2                                 (-30, 30)                None
# 1                                 (-30, 30)                None
# 5                                 (-30, 30)  (30720.0, 30720.0)
# 9                               (-0.5, 0.5)                None
# 18                            (-0.25, 0.25)                None
# 20                              (-0.5, 0.5)                None
# 8                               (-0.5, 0.5)                None
# 11                                (-30, 30)                None
#
#        spatial_dimensions
# id
# 17  (latitude, longitude)
# 16  (latitude, longitude)
# 10  (latitude, longitude)
# 6                  (y, x)
# 2                  (y, x)
# 1                  (y, x)
# 5                  (y, x)
# 9   (latitude, longitude)
# 18  (latitude, longitude)
# 20  (latitude, longitude)
# 8   (latitude, longitude)
# 11                 (y, x)

# %%
cdc.list_measurements()
# Out:
#                                                                            aliases  \
# product                     measurement
# alos_fnf_mosaic             SAR_fnf                                            NaN
# alos_sar_mosaic             hh                                                 NaN
#                             hv                                                 NaN
# dem_3sec_hydrosheds         elevation                                          NaN
# ls5_usgs_sr_scene           blue                                [band_1, sr_band1]
#                             green                               [band_2, sr_band2]
#                             red                                 [band_3, sr_band3]
#                             nir                                 [band_4, sr_band4]
#                             swir1                               [band_5, sr_band5]
#                             swir2                               [band_7, sr_band7]
#                             pixel_qa                                    [pixel_qa]
# ls7_usgs_sr_scene           blue                                [band_1, sr_band1]
#                             green                               [band_2, sr_band2]
#                             red                                 [band_3, sr_band3]
#                             nir                                 [band_4, sr_band4]
#                             swir1                               [band_5, sr_band5]
#                             swir2                               [band_7, sr_band7]
#                             sr_atmos_opacity                            [atmos_op]
#                             pixel_qa                                    [pixel_qa]
#                             radsat_qa                                  [radsat_qa]
#                             sr_cloud_qa                                 [cloud_qa]
# ls8_usgs_sr_scene           coastal_aerosol                     [band_1, sr_band1]
#                             blue                                [band_2, sr_band2]
#                             green                               [band_3, sr_band3]
#                             red                                 [band_4, sr_band4]
#                             nir                                 [band_5, sr_band5]
#                             swir1                               [band_6, sr_band6]
#                             swir2                               [band_7, sr_band7]
#                             pixel_qa                                    [pixel_qa]
#                             sr_aerosol        [sr_aerosol_qa, aerosol_qa, aerosol]
#                             radsat_qa                                  [radsat_qa]
# ls_level2_geomedian_annual  blue                                [band_2, sr_band2]
#                             green                               [band_3, sr_band3]
#                             red                                 [band_4, sr_band4]
#                             nir                                 [band_5, sr_band5]
#                             swir1                               [band_6, sr_band6]
#                             swir2                               [band_7, sr_band7]
# pet_grids_1979_2016         PET                                                NaN
# rainfall_grids              rainfall                                           NaN
# spei_grids                  spei_gamma_03                                      NaN
#                             spei_gamma_06                                      NaN
#                             spei_gamma_12                                      NaN
#                             spei_pearson_03                                    NaN
#                             spei_pearson_06                                    NaN
#                             spei_pearson_12                                    NaN
# temperature_grids_1979_2016 temperature                                        NaN
# wofs_grids_1987_2017        wofs                                               NaN
#
#                                                 dtype  \
# product                     measurement
# alos_fnf_mosaic             SAR_fnf            uint16
# alos_sar_mosaic             hh                 uint16
#                             hv                 uint16
# dem_3sec_hydrosheds         elevation           int16
# ls5_usgs_sr_scene           blue                int16
#                             green               int16
#                             red                 int16
#                             nir                 int16
#                             swir1               int16
#                             swir2               int16
#                             pixel_qa           uint16
# ls7_usgs_sr_scene           blue                int16
#                             green               int16
#                             red                 int16
#                             nir                 int16
#                             swir1               int16
#                             swir2               int16
#                             sr_atmos_opacity    uint8
#                             pixel_qa           uint16
#                             radsat_qa           uint8
#                             sr_cloud_qa         uint8
# ls8_usgs_sr_scene           coastal_aerosol     int16
#                             blue                int16
#                             green               int16
#                             red                 int16
#                             nir                 int16
#                             swir1               int16
#                             swir2               int16
#                             pixel_qa           uint16
#                             sr_aerosol          uint8
#                             radsat_qa          uint16
# ls_level2_geomedian_annual  blue                int16
#                             green               int16
#                             red                 int16
#                             nir                 int16
#                             swir1               int16
#                             swir2               int16
# pet_grids_1979_2016         PET               float32
# rainfall_grids              rainfall          float32
# spei_grids                  spei_gamma_03     float32
#                             spei_gamma_06     float32
#                             spei_gamma_12     float32
#                             spei_pearson_03   float32
#                             spei_pearson_06   float32
#                             spei_pearson_12   float32
# temperature_grids_1979_2016 temperature       float32
# wofs_grids_1987_2017        wofs              float64
#
#                                                                                flags_definition  \
# product                     measurement
# alos_fnf_mosaic             SAR_fnf                                                         NaN
# alos_sar_mosaic             hh                                                              NaN
#                             hv                                                              NaN
# dem_3sec_hydrosheds         elevation                                                       NaN
# ls5_usgs_sr_scene           blue                                                            NaN
#                             green                                                           NaN
#                             red                                                             NaN
#                             nir                                                             NaN
#                             swir1                                                           NaN
#                             swir2                                                           NaN
#                             pixel_qa          {'snow': {'bits': 4, 'values': {'0': 'no_snow'...
# ls7_usgs_sr_scene           blue                                                            NaN
#                             green                                                           NaN
#                             red                                                             NaN
#                             nir                                                             NaN
#                             swir1                                                           NaN
#                             swir2                                                           NaN
#                             sr_atmos_opacity                                                NaN
#                             pixel_qa          {'snow': {'bits': 4, 'values': {'0': 'no_snow'...
#                             radsat_qa         {'radsat_qa': {'bits': [0, 1, 2, 3, 4, 5, 6, 7...
#                             sr_cloud_qa       {'cloud_qa': {'bits': [0, 1, 2, 3, 4, 5, 6, 7]...
# ls8_usgs_sr_scene           coastal_aerosol                                                 NaN
#                             blue                                                            NaN
#                             green                                                           NaN
#                             red                                                             NaN
#                             nir                                                             NaN
#                             swir1                                                           NaN
#                             swir2                                                           NaN
#                             pixel_qa          {'snow': {'bits': 4, 'values': {'0': 'no_snow'...
#                             sr_aerosol        {'aerosol_qa': {'bits': [0, 1, 2, 3, 4, 5, 6, ...
#                             radsat_qa         {'radsat_qa': {'bits': [0, 1, 2, 3, 4, 5, 6, 7...
# ls_level2_geomedian_annual  blue                                                            NaN
#                             green                                                           NaN
#                             red                                                             NaN
#                             nir                                                             NaN
#                             swir1                                                           NaN
#                             swir2                                                           NaN
# pet_grids_1979_2016         PET                                                             NaN
# rainfall_grids              rainfall                                                        NaN
# spei_grids                  spei_gamma_03                                                   NaN
#                             spei_gamma_06                                                   NaN
#                             spei_gamma_12                                                   NaN
#                             spei_pearson_03                                                 NaN
#                             spei_pearson_06                                                 NaN
#                             spei_pearson_12                                                 NaN
# temperature_grids_1979_2016 temperature                                                     NaN
# wofs_grids_1987_2017        wofs                                                            NaN
#
#                                                           name  nodata   units
# product                     measurement
# alos_fnf_mosaic             SAR_fnf                    SAR_fnf       0
# alos_sar_mosaic             hh                              hh       0
#                             hv                              hv       0
# dem_3sec_hydrosheds         elevation                elevation   -9999       m
# ls5_usgs_sr_scene           blue                          blue   -9999       1
#                             green                        green   -9999       1
#                             red                            red   -9999       1
#                             nir                            nir   -9999       1
#                             swir1                        swir1   -9999       1
#                             swir2                        swir2   -9999       1
#                             pixel_qa                  pixel_qa       1       1
# ls7_usgs_sr_scene           blue                          blue   -9999       1
#                             green                        green   -9999       1
#                             red                            red   -9999       1
#                             nir                            nir   -9999       1
#                             swir1                        swir1   -9999       1
#                             swir2                        swir2   -9999       1
#                             sr_atmos_opacity  sr_atmos_opacity       0       1
#                             pixel_qa                  pixel_qa       1       1
#                             radsat_qa                radsat_qa       1       1
#                             sr_cloud_qa            sr_cloud_qa       0       1
# ls8_usgs_sr_scene           coastal_aerosol    coastal_aerosol   -9999       1
#                             blue                          blue   -9999       1
#                             green                        green   -9999       1
#                             red                            red   -9999       1
#                             nir                            nir   -9999       1
#                             swir1                        swir1   -9999       1
#                             swir2                        swir2   -9999       1
#                             pixel_qa                  pixel_qa       1       1
#                             sr_aerosol              sr_aerosol       0       1
#                             radsat_qa                radsat_qa       1       1
# ls_level2_geomedian_annual  blue                          blue   -9999       1
#                             green                        green   -9999       1
#                             red                            red   -9999       1
#                             nir                            nir   -9999       1
#                             swir1                        swir1   -9999       1
#                             swir2                        swir2   -9999       1
# pet_grids_1979_2016         PET                            PET     NaN  mm/day
# rainfall_grids              rainfall                  rainfall -9999.9  mm/day
# spei_grids                  spei_gamma_03        spei_gamma_03     NaN
#                             spei_gamma_06        spei_gamma_06     NaN
#                             spei_gamma_12        spei_gamma_12     NaN
#                             spei_pearson_03    spei_pearson_03     NaN
#                             spei_pearson_06    spei_pearson_06     NaN
#                             spei_pearson_12    spei_pearson_12     NaN
# temperature_grids_1979_2016 temperature            temperature   -9999       C
# wofs_grids_1987_2017        wofs                          wofs     NaN       %

# %%
 len(cdc.find_datasets(product='spei_grids'))
# Out:
# 156

# %%
#define temporal range ()
start_of_epoch = '2001-01-01'
end_of_epoch =  '2002-01-01'
query = {}

query = {'time': (start_of_epoch, end_of_epoch),}
# lat_min = 13.151 #down
# lat_max = 13.564 #up
# lon_min = 103.668 #left
# lon_max = 104.115 #right 

# # lat_min = 11.246 #down
# # lat_max = 11.532 #up
# # lon_min = 105.141 #left
# # lon_max = 105.380 #right

# query['x'] = (lon_min, lon_max)
# query['y'] = (lat_max, lat_min)
# query['crs'] = 'EPSG:4326'

print(query)

#Total number of scenes in Cambodia Cube
#pet_datasets = cdc.find_datasets(product='pet_grids_1979_2016')#,**query)
# rain_datasets = cdc.find_datasets(product='rainfall_grids_1998_2017')#,**query)
# wofs_datasets = cdc.find_datasets(product='wofs_grids_1987_2017',**query)
# temp_datasets = cdc.find_datasets(product='temperature_grids_1979_2016',**query)
# gm_datasets = cdc.find_datasets(product='ls_level2_geomedian_annual',**query)
# ls8_datasets = cdc.find_datasets(product='ls8_usgs_sr_scene',**query)
# ls7_datasets = cdc.find_datasets(product='ls7_usgs_sr_scene',**query)
# ls5_datasets = cdc.find_datasets(product='ls5_usgs_sr_scene',**query)
# # print(len(ls8_datasets))
# print(len(ls7_datasets))
# print(len(ls5_datasets))
# print()

# print (len(ls8_datasets)+len(ls7_datasets)+len(ls5_datasets))
# print(len(wofs_datasets))

# [x.id for x in ls7_datasets]
# ls5_datasets[0].metadata_doc
# Out:
# {'time': ('2001-01-01', '2002-01-01')}

# %%
# test = cdc.load(product='wofs_grids_1987_2017')

# %%
# test

# %%
# test02= cdc.load(product='ls5_usgs_sr_scene',group_by='solar_day', **query)
#test02= cdc.load(product='wofs_grids_1987_2017',**query)
ds = cdc.load(product='rainfall_grids',**query)
# test = cdc.load(product='alos_fnf_mosaic',**query)

#test02= cdc.load(product='spei_monthly_grids_1998_2017',**query)
# test02= cdc.load(product='temperature_grids_1979_2016',**query)

# %%
ds.time
# Out:
# <xarray.DataArray 'time' (time: 366)>
# array(['2001-01-01T00:00:00.000000000', '2001-01-02T00:00:00.000000000',
#        '2001-01-03T00:00:00.000000000', ..., '2001-12-30T00:00:00.000000000',
#        '2001-12-31T00:00:00.000000000', '2002-01-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2001-01-01 2001-01-02 ... 2002-01-01
# Attributes:
#     units:    seconds since 1970-01-01 00:00:00

# %%
# ds.spei_pearson_03.isel(time=0).plot()

# %%
ds.spei_gamma_03.isel(time=0).plot()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
rad = test02

# %%
# rad.hh.plot()

# %%
rad_bounds = [0, 500, 1000, 1500,2000, 3000, 4000,
              5000,6000,7000, 8000,9000,
               10_000, 12_000,14_000, 
               16_000, 18_000,20_000,
               30_000, 70_000]

# %%
rad_bounds = [0, 500, 1000, 3000,5000, 70_000]

# %%
len(rad_bounds)
# Out:
# 6

# %%
#Set up the WOfS colour ramp and corresponding thresholds
rad_cmap = mpl.colors.ListedColormap(['#e6194b', '#3cb44b', '#ffe119', 
                                      '#4363d8', '#f58231', '#911eb4',]) 
#                                       '#46f0f0', '#f032e6', '#bcf60c', 
#                                       '#fabebe', '#008080', '#e6beff', 
#                                       '#9a6324', '#fffac8', '#800000', 
#                                       '#aaffc3', '#808000', '#ffd8b1', 
#                                       '#000075', '#808080', '#ffffff',])
                                      #'#000000'])##User should format as required
rad_bounds = [0, 500, 1000, 3000,5000, 70_000]
    # rad_bounds = list(range(0,65000,4000))
rad_norm = mpl.colors.BoundaryNorm(rad_bounds, rad_cmap.N)

# %%
plt.imshow(rad.hv.isel(time=0),cmap = rad_cmap, norm = rad_norm)
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.2666666666667">

# %%
# test02.hv.plot()

# %%
#plt.plot(test02.SAR.isel(time=0))
plt.imshow(test02.SAR.isel(time = 0), interpolation = 'nearest')
plt.colorbar()
plt.show()

# %%
# test02['temperature'] = test02.temperature.where(test02.temperature<1000)

# %%
test02

# %%
from matplotlib import pyplot as plt

test02.spei_gamma_03.isel(longitude = 0).plot()

# %%
# test02.spei_gamma_03.isel(longitude = 0).plot()

# %%
# test03=test02
# test03.temperature.attrs['nodata'] = 'nan'
# test03['temperature'] = test03.temperature.where(test03.temperature<1000)
# # test03 = test03.fillna(-9999)

# %%
# test03.to_netcdf(path = '/g/data/u46/users/ext547/ewater/input_data/test/output.nc')

# %%
# con.Tair.attrs['nodata'] = 'nan'
con02['Tair'] = con.Tair.where(con.Tair<1000)
# con02 = con02.fillna(-9999)

# %%
test03.temperature

# %%
int(test02.temperature.isel(time = 0, latitude = 12, longitude =13 ).values)

# %%
#plt.imshow(test02.temperature.isel(time = 0))
test01.PET.isel(time = 0).plot()

# %%
#define wavelengths/bands of interest
bands_of_interest = ['blue',
                     'green',
                     'red', 
                     'nir',
                     'swir1', 
                     'pixel_qa',
                     'swir2',
                     ]

start_of_epoch = '2016-01-01'
end_of_epoch =  '2018-01-01'

lat_max = 12.919 #up
lat_min = 12.855 #down
lon_min = 101.721 #left
lon_max = 101.804 #right  1

query = {'time': (start_of_epoch, end_of_epoch),}

query['x'] = (lon_min, lon_max)
query['y'] = (lat_max, lat_min)
# query['crs'] = 'EPSG:4326'

print(query)

# %%
# #Total number of scenes in Cambodia Cube
# ls8_datasets = cdc.find_datasets(product='ls8_usgs_sr_scene',**query)
# ls7_datasets = cdc.find_datasets(product='ls7_usgs_sr_scene',**query)
# ls5_datasets = cdc.find_datasets(product='ls5_usgs_sr_scene',**query)
# print(len(ls8_datasets))
# print(len(ls7_datasets))
# print(len(ls5_datasets))


# print (len(ls8_datasets)+len(ls7_datasets)+len(ls5_datasets))

# %%
# test02 = test02.where(test02.temperature<1000)

# %%
test02

# %%
# plt.imshow(test02.isel(time=0).temperature.values)
# plt.show()

# %%
# test02.elevation.isel(time = 0).plot()

# %%
# plt.imshow(test02.isel(time=0).elevation)

# %%
# rgb = test02.isel(time=0).to_array(dim='color').sel(color=['swir1',
#                                                          'nir', 'green']).transpose('y', 
#                                                                                     'x', 'color')
# fake_saturation = 6000.0
# rgb = rgb.astype('double')
# clipped_visible = rgb.where(rgb<fake_saturation).fillna(fake_saturation)
# max_val = clipped_visible.max(['y', 'x'])
# scaled = (clipped_visible / max_val)

# plt.imshow(scaled)

# %%
#Total number of scenes in Cambodia Cube
ls8_datasets = cdc.find_datasets(product='ls8_usgs_sr_scene',**query)
ls7_datasets = cdc.find_datasets(product='ls7_usgs_sr_scene',**query)
ls5_datasets = cdc.find_datasets(product='ls5_usgs_sr_scene',**query)
print(len(ls8_datasets)+len(ls7_datasets)+len(ls5_datasets))
# ls8_datasets[0].metadata_doc

# %%
# #query number of scenes in certain gm as per year query
# gm_datasets = cdc.find_datasets(product='ls5_usgs_sr_scene',**query)
# len(gm_datasets)

# %%
temp_datasets = cdc.find_datasets(product='temperature_grids_1979_2016')#,**query)

# %%
len(temp_datasets)

# %%
# set cloud threshold. This value defines the amount of lansdcape/cloud allowed in each scene. 
# Scenes will not be retrieved that have less than the cloud threshold worth of image.
#The default value is "0.90" or >90% image and <10% cloud cover
cloud_free_threshold = 0.20


# lat_min = 13.000 #down
# lat_max = 13.500 #up
# lon_min = 103.000 #left
# lon_max = 103.500 #right  


#define temporal range ()
# start_of_epoch = '2014-01-01'
# end_of_epoch =  '2015-01-01'

# #define first time of interest
# start_of_time01 = '2015-01-01'
# end_of_time01 = '2016-05-01'

# #define second time of interest
# start_of_time02 = '2016-05-02'
# end_of_time02 = '2017-12-31'

# start_of_epoch = '2014-01-01'
# end_of_epoch =  '2014-01-02'

#define wavelengths/bands of interest
bands_of_interest = ['blue',
                     'green',
                     'red', 
                     'nir',
                     'swir1', 
                     'pixel_qa',
                     'swir2',
                     ]

#define Landsat sensors of interest
sensors = ['ls5',]
#        'ls7',] 

#query is created
# query = {'time': (start_of_epoch, end_of_epoch),}
# query['x'] = (lon_min, lon_max)
# query['y'] = (lat_max, lat_min)
# query['crs'] = 'EPSG:4326'

print(query)

# %%
# #define temporal range ()
# start_of_epoch = '2014-01-01'
# end_of_epoch =  '2014-02-01'
# query = {'time': (start_of_epoch, end_of_epoch),}

# %%
test.y[0]

# %%
test02.isel(time=0).pixel_qa

# %%
# plt.imshow(test02.isel(time=0).pixel_qa)

# %%
test= cdc.load(product='ls_level2_geomedian_annual',**query)

# %%
test

# %%
test.isel(time=0).to_array(dim='color').sel(color=['swir1','nir', 'green']).transpose('y', 'x', 'color')

# %%
# rgb = test.isel(time=0).to_array(dim='color').sel(color=['swir1',
#                                                          'nir', 'green']).transpose('y', 
#                                                                                     'x', 'color')
# fake_saturation = 6000.0
# rgb = rgb.astype('double')
# clipped_visible = rgb.where(rgb<fake_saturation).fillna(fake_saturation)
# max_val = clipped_visible.max(['y', 'x'])
# scaled = (clipped_visible / max_val)

# plt.imshow(scaled)

# %%
test.rainfall.max()

# %%
test.latitude.min()

# %%
test= cdc.load(product='ls8_usgs_sr_scene',**query)
# test= test.squeeze()
test

# %%
# three_band_image_subplots(test, ['red','green','blue'], 2, figsize = [30,50])

# %%
# sensor_nbar[0].metadata_doc

# %%
# cdc.load(product='ls7_usgs_sr_scene')

# %%
blah=list(cdc.index.products.search())[1]

# %%
blah.definition

# %%
gm_all_datasets = cdc.find_datasets(product='ls_level2_geomedian_annual')
len(gm_all_datasets)

# %%
ls7_datasets = cdc.find_datasets(product='ls7_usgs_sr_scene',**query)
len(ls7_datasets)

# %%
# list(cdc.index.users.list_users())

# %%
#define temporal range ()
start_of_epoch = '1969-01-01'
end_of_epoch =  '2018-01-01'
query = {'time': (start_of_epoch, end_of_epoch),}
print(query)

# %%
ls8_datasets = cdc.find_datasets(product='ls8_usgs_sr_scene',**query)
ls7_datasets = cdc.find_datasets(product='ls7_usgs_sr_scene',**query)
ls5_datasets = cdc.find_datasets(product='ls5_usgs_sr_scene',**query)
print(len(ls5_datasets)+len(ls7_datasets)+len(ls8_datasets))
# ls8_datasets[0].metadata_doc

# %%
del_datasets = cdc.find_datasets(product='pet_grids_1979_2016')#,**query)
len(del_datasets)

# %%
# # #Remove all/certain files from database. WARNING.
del_eager=[d.id for d in del_datasets]
cdc.index.datasets.archive(del_eager)
del_datasets = cdc.find_datasets(product='pet_grids_1979_2016')

print(len(del_datasets))

# %%
# # #Remove all files from database. WARNING.
# ls7_eager=[d.id for d in ls7_datasets]
# cdc.index.datasets.archive(ls7_eager)
# print(len(ls7_datasets))

# %%
# # #Remove all files from database. WARNING.
# ls5_eager=[d.id for d in ls5_datasets]
# cdc.index.datasets.archive(ls5_eager)
# print(len(ls5_datasets))

# %%
# # # Remove specific files from database. WARNING.
# gm_eager=[d.id for d in cdc.index.datasets.search_eager(product='ls_level2_geomedian_annual')]#,**query)]
# cdc.index.datasets.archive(gm_eager)

# %%
# # Remove specific files from database. WARNING.
# gm_eager=[d.id for d in gm_datasets]#cdc.index.datasets.search_eager(product='ls_level2_geomedian_annual',**query)]
# cdc.index.datasets.archive(gm_eager)

# %%
gm_eager

# %%
# # Remove all files from database. WARNING.
# ls7_eager=[d.id for d in cdc.index.datasets.search_eager(product='ls7_usgs_sr_scene')]
# cdc.index.datasets.archive(ls7_eager)

# %%
# # Remove all files from database. WARNING.
# ls8_eager=[d.id for d in cdc.index.datasets.search_eager(product='ls8_usgs_sr_scene')]
# cdc.index.datasets.archive(ls8_eager)

# %%
# cdc_ls7= cdc.load(product='ls7_usgs_sr_scene')
# cdc_ls8 = cdc.load(product='ls8_usgs_sr_scene')

# %%
# print(cdc_ls8.time)
# print(cdc_ls7.time)

# %%
# dc = Datacube(app='dc-show changes in annual mean NDVI values')
# dc.list_products()

# %% [markdown]
# # New heading
