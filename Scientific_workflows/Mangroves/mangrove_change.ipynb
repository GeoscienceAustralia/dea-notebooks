# %%
import boto3
import sys
import numpy as np
import time
import os
import subprocess
import xarray as xr
import rioxarray
import dask.array as da
from os import path
import pandas as pd
from datacube.utils.dask import start_local_dask
from pathlib import Path
from datacube.utils.cog import write_cog

# %%
def categorize_damage(bc_canopy, ac_canopy):
    """
    The function to categorize the change
    inputs:
        bc_canopy: the canopy class of previous year
        ac_canopy: the canopy class of current year
    output:
        an xarray of canopy change
    """
    nodata = int(bc_canopy.attrs.get('_FillValue'))
    reduction = bc_canopy.copy(deep=True, data=da.zeros(bc_canopy.data.shape, dtype='uint8'))
    reduction.attrs.pop('_FillValue')
    reduction.attrs['nodata'] = 0
    reduction.data = da.where((bc_canopy.values == 0) | (ac_canopy.values == 0), 101, reduction.data)
    reduction.data = da.where(bc_canopy.values == ac_canopy.values, 101, reduction.data)
    reduction.data = da.where((bc_canopy.values >= 2) & (ac_canopy.values == nodata), 105, reduction.data)
    reduction.data = da.where((bc_canopy.values == 1) & (ac_canopy.values == nodata), 104, reduction.data)
    reduction.data = da.where((bc_canopy.values == 3) & (ac_canopy.values == 1), 103, reduction.data)
    reduction.data = da.where((bc_canopy.values == 3) & (ac_canopy.values == 2), 102, reduction.data)
    reduction.data = da.where((bc_canopy.values == 2) & (ac_canopy.values == 1), 102, reduction.data)
    reduction.data = da.where((bc_canopy.values == nodata) & (ac_canopy.values >= 1), 201, reduction.data)
    reduction.data = da.where((bc_canopy.values == 1) & (ac_canopy.values == 2), 202, reduction.data)
    reduction.data = da.where((bc_canopy.values == 2) & (ac_canopy.values == 3), 202, reduction.data)
    reduction.data = da.where((bc_canopy.values == 1) & (ac_canopy.values == 3), 203, reduction.data)
    reduction.data = da.where((bc_canopy.values == nodata) & (ac_canopy.values == nodata), 0, reduction.data)
    return reduction

# %%
# bucket and prefix is where the C3 mangroves sit currently
bucket = "dea-public-data-dev"
prefix = "derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/"
# profile_name is the aws credential name, change it accordingly
session = boto3.Session(profile_name='dev')
s3_client = session.client("s3")
paginator = s3_client.get_paginator('list_objects')

# %%
# spin up a dask cluster, change the thread and memory accordingly
client = start_local_dask(n_workers=1, threads_per_worker=8, memory_limit='62GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:40723' processes=1 threads=8, memory=62.00 GB>

# %%
# grid_list.csv contains a list of grids where the mangroves exist
grid_list = pd.read_csv("grid_list.csv", header=None, dtype="str")
for row in grid_list.iterrows():
    # iterate over all the grids
    print(row)
    bc_canopy = None
    for year in range(1987, 2022):
        # iterate over all the years
        print(year)
        # make up the prefix/path of mangroves imagery sitting in s3
        ac_prefix = prefix+"/".join(["x"+row[1][0], "y"+row[1][1], str(year)+"--P1Y"])
        page_iterator = paginator.paginate(Bucket=bucket, Prefix=ac_prefix)
        # filter the objects and get only .tif file (omit all the files of metadata)
        filtered_iterator = page_iterator.search("Contents[?contains(Key, '.tif') == `true`].Key")
        for o in filtered_iterator:
            print(o)
            # read in the data as dask array
            ac_canopy = rioxarray.open_rasterio("s3://"+"/".join([bucket, o]), chunks={"x": -1, "y": -1})
        if bc_canopy is not None:
            # compute the change
            canopy_change = categorize_damage(bc_canopy, ac_canopy)
            # save the data locally as geotiff
            file_name = "ga_ls_mangrove_change_cyear_3_" + "_".join([ "x" + row[1][0]+"y" + row[1][1], str(year-1), str(year)]) + ".tif" 
            write_cog(canopy_change.compute(), file_name)
            # upload the local file to s3 bucket
            key = "test/mangroves_change/" + "/".join(["x" + row[1][0], "y" + row[1][1], file_name])
            response = s3_client.upload_file(file_name, bucket, key)
            print(file_name)
            # remove the local file (too many files will use up the quota of sandbox)
            os.remove(file_name)
        bc_canopy = ac_canopy
# Out:
# (0, 0    08
# 1    26
# Name: 0, dtype: object)
# 1987
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/1987--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_1987--P1Y_final_canopy_cover_class.tif
# 1988
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/1988--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_1988--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_1987_1988.tif
# 1989
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/1989--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_1989--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_1988_1989.tif
# 1990
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/1990--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_1990--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_1989_1990.tif
# 1991
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/1991--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_1991--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_1990_1991.tif
# 1992
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/1992--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_1992--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_1991_1992.tif
# 1993
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/1993--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_1993--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_1992_1993.tif
# 1994
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/1994--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_1994--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_1993_1994.tif
# 1995
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/1995--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_1995--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_1994_1995.tif
# 1996
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/1996--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_1996--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_1995_1996.tif
# 1997
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/1997--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_1997--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_1996_1997.tif
# 1998
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/1998--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_1998--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_1997_1998.tif
# 1999
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/1999--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_1999--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_1998_1999.tif
# 2000
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2000--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2000--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_1999_2000.tif
# 2001
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2001--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2001--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2000_2001.tif
# 2002
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2002--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2002--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2001_2002.tif
# 2003
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2003--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2003--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2002_2003.tif
# 2004
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2004--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2004--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2003_2004.tif
# 2005
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2005--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2005--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2004_2005.tif
# 2006
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2006--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2006--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2005_2006.tif
# 2007
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2007--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2007--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2006_2007.tif
# 2008
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2008--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2008--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2007_2008.tif
# 2009
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2009--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2009--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2008_2009.tif
# 2010
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2010--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2010--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2009_2010.tif
# 2011
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2011--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2011--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2010_2011.tif
# 2012
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2012--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2012--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2011_2012.tif
# 2013
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2013--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2013--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2012_2013.tif
# 2014
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2014--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2014--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2013_2014.tif
# 2015
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2015--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2015--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2014_2015.tif
# 2016
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2016--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2016--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2015_2016.tif
# 2017
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2017--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2017--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2016_2017.tif
# 2018
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2018--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2018--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2017_2018.tif
# 2019
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2019--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2019--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2018_2019.tif
# 2020
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2020--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2020--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2019_2020.tif
# 2021
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y26/2021--P1Y/ga_ls_mangrove_cover_cyear_3_x08y26_2021--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y26_2020_2021.tif
# (1, 0    08
# 1    27
# Name: 1, dtype: object)
# 1987
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y27/1987--P1Y/ga_ls_mangrove_cover_cyear_3_x08y27_1987--P1Y_final_canopy_cover_class.tif
# 1988
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y27/1988--P1Y/ga_ls_mangrove_cover_cyear_3_x08y27_1988--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y27_1987_1988.tif
# 1989
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y27/1989--P1Y/ga_ls_mangrove_cover_cyear_3_x08y27_1989--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y27_1988_1989.tif
# 1990
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y27/1990--P1Y/ga_ls_mangrove_cover_cyear_3_x08y27_1990--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y27_1989_1990.tif
# 1991
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y27/1991--P1Y/ga_ls_mangrove_cover_cyear_3_x08y27_1991--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y27_1990_1991.tif
# 1992
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y27/1992--P1Y/ga_ls_mangrove_cover_cyear_3_x08y27_1992--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y27_1991_1992.tif
# 1993
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y27/1993--P1Y/ga_ls_mangrove_cover_cyear_3_x08y27_1993--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y27_1992_1993.tif
# 1994
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y27/1994--P1Y/ga_ls_mangrove_cover_cyear_3_x08y27_1994--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y27_1993_1994.tif
# 1995
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y27/1995--P1Y/ga_ls_mangrove_cover_cyear_3_x08y27_1995--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y27_1994_1995.tif
# 1996
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y27/1996--P1Y/ga_ls_mangrove_cover_cyear_3_x08y27_1996--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y27_1995_1996.tif
# 1997
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y27/1997--P1Y/ga_ls_mangrove_cover_cyear_3_x08y27_1997--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y27_1996_1997.tif
# 1998
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y27/1998--P1Y/ga_ls_mangrove_cover_cyear_3_x08y27_1998--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y27_1997_1998.tif
# 1999
# derivative/ga_ls_mangrove_cover_cyear_3/2-0-2/x08/y27/1999--P1Y/ga_ls_mangrove_cover_cyear_3_x08y27_1999--P1Y_final_canopy_cover_class.tif
# dask.array<zeros, shape=(1, 3200, 3200), dtype=uint8, chunksize=(1, 3200, 3200), chunktype=numpy.ndarray>
# ga_ls_mangrove_change_cyear_3_x08y27_