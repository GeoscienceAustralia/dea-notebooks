# %%
# Ayr
x = (1500000, 1600000)
y = (-2200000, -2100000)
min_x = 1500000
max_x = 1600000
min_y = -2200000
max_y = -2100000
res_x = 100
res_y = -100

# Diamantina
x = (800000, 900000)
y = (-2800000, -2700000)
min_x = 800000
max_x = 900000
min_y = -2800000
max_y = -2700000
res_x = 100
res_y = -100

# Gwydir
x = (1600000, 1700000)
y = (-3400000, -3300000)
min_x = 1600000
max_x = 1700000
min_y = -3400000
max_y = -3300000
res_x = 100
res_y = -100

# Leichhardt
x = (800000, 900000)
y = (-2000000, -1900000)
min_x = 800000
max_x = 900000
min_y = -2000000
max_y = -1900000
res_x = 100
res_y = -100

# Kakadu
x = (0, 100000)
y = (-1350000, -1250000)
min_x = 0
max_x = 100000
min_y = -1350000
max_y = -1250000
res_x = 100
res_y = -100

# Hobart
x = (1200000, 1300000)
y = (-4800000, -4700000)
min_x = 1200000
max_x = 1300000
min_y = -4800000
max_y = -4700000
res_x = 100
res_y = -100

# Perth
x = (-1550000, -1450000)
y = (-3650000, -3550000)
min_x = -1550000
max_x = -1450000
min_y = -3650000
max_y = -3550000
res_x = 100
res_y = -100

# Murray Valley
x = (1100000, 1200000)
y = (-4000000, -3900000)
min_x = 1100000
max_x = 1200000
min_y = -4000000
max_y = -3900000
res_x = 100
res_y = -100

# Adelaide
x = (550000, 650000)
y = (-3850000, -3750000)
min_x = 550000
max_x = 650000
min_y = -3850000
max_y = -3750000
res_x = 100
res_y = -100

# Lake Eyre
x = (500000, 600000)
y = (-3000000, -2900000)
min_x = 500000
max_x = 600000
min_y = -3000000
max_y = -2900000
res_x = 100
res_y = -100

# Blue mountains
x = (1600000, 1700000)
y = (-3900000, -3800000)
min_x = 1600000
max_x = 1700000
min_y = -3900000
max_y = -3800000
res_x = 100
res_y = -100

# Australian Alps
x = (1400000, 1500000)
y = (-4100000, -4000000)
min_x = 1400000
max_x = 1500000
min_y = -4100000
max_y = -4000000
res_x = 100
res_y = -100

# Collier Range
x = (-1300000, -1200000)
y = (-2700000, -2600000)
min_x = -1300000
max_x = -1200000
min_y = -2700000
max_y = -2600000
res_x = 100
res_y = -100

location = 'Coorong'
x = (600000, 700000)
y = (-3950000, -3850000)
min_x = 600000
max_x = 700000
min_y = -3950000
max_y = -3850000
res_x = 100
res_y = -100

location = 'Brisbane'
x = (2000000, 2100000)
y = (-3200000, -3100000)
min_x = 2000000
max_x = 2100000
min_y = -3200000
max_y = -3100000
res_x = 100
res_y = -100

location = 'Dundas'
x = (-1000000, -900000)
y = (-3650000, -3550000)
min_x = -1000000
max_x = -900000
min_y = -3650000
max_y = -3550000
res_x = 100
res_y = -100
